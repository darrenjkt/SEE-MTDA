# %%
import sys
sys.path.append('/SEE-MTDA/see')
from sc.mesher.mesher import Mesher
import numpy as np
import os
import glob
from pathlib import Path
from sc.datasets.shared_utils import *
import open3d as o3d
from easydict import EasyDict
import yaml
from PIL import Image

def cfg_from_yaml_file(cfg_file):
    cfg = EasyDict()
    print("\n----- Cfgs -----")
    with open(cfg_file, 'r') as f:
        yaml_config = yaml.safe_load(f)
        print(yaml.dump(yaml_config))

    cfg.update(EasyDict(yaml_config))

    return cfg

cfg_file = '/SEE-MTDA/see/sc/cfgs/KIT-DM-ORH005.yaml'
cfg = cfg_from_yaml_file(cfg_file)
mesher = Mesher(cfg=cfg, cfg_path=cfg_file)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
#
# ----- Cfgs -----
# DATASET:
#   CAMERA_CHANNELS:
#   - image_2
#   CLASSES:
#   - Car
#   DET2D_MASK: true
#   DET2D_MODEL: htc
#   NAME: kitti
#   POINT_CLOUD_RANGE:
#   - -70
#   - -70
#   - -2
#   - 70
#   - 70
#   - 4
#   SHRINK_MASK_PERCENTAGE: 2
# DATA_PATH: /SEE-MTDA/data/kitti
# MESHER:
#   CLUSTERING:
#     EPS_SCALING: 5
#     NAME: db_scan
#   MESH_ALGORITHM:
#     LOWER_RADIUS: 0.01
#     NAME: ball_pivoting
#     UPPER_RADIUS: 1.155
#   MIN_LIDAR_PTS_TO_MESH: 30
#   NAME: det_mesh
#   REPLACE_OBJECT_WITH_MESH:
#     POINT_DISTANCE_THRESH: 0.1
#   SAMPLING:
#     NAME: vres_ring_based_sampling
#     OPTIMAL_RING_HEIGHT: 0.05
#     TYPE: poisson
#   VRES: 0.4
#
# Loading masks...
# loading annotations into memory...
# Done (t=3.11s)
# creating index...
# index created!
# KittiObjects initialised!
#
# Mesher Initialised!

# %% [markdown]
# # Export points in GT box
#
# This is to assess shape completion with perfect data

# %%
mesher.min_lidar_pts_to_mesh = 5

for sample_idx in range(mesher.data_obj.__len__()):
    pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx)

    for object_id in range(len(pcd_gtboxes['gt_boxes'])):    

        object_pcd = pcd_gtboxes['pcd'].crop(pcd_gtboxes['gt_boxes'][object_id])

        if len(object_pcd.points) < mesher.min_lidar_pts_to_mesh:
            continue

        box_pts = np.asarray(pcd_gtboxes['gt_boxes'][object_id].get_box_points())

        if mesher.data_obj.dataset_name == 'nuscenes':
            fname = f'nsweeps-{mesher.data_obj.nsweeps}_frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'
        else:
            fname = f'frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'

        car_dir = Path(f'{mesher.data_obj.root_dir}/exported/cars')
        car_dir.mkdir(parents=True, exist_ok=True)
        o3d.io.write_point_cloud(str(car_dir / f'{fname}.pcd'), object_pcd)

        box_dir = Path(f'{mesher.data_obj.root_dir}/exported/bboxes')    
        box_dir.mkdir(parents=True, exist_ok=True)
        np.savetxt(str(box_dir / f'{fname}.txt'), box_pts, delimiter=' ')

        print(f"frame-{sample_idx}: Exported {object_id}/{len(pcd_gtboxes['gt_boxes'])} | car_pts-{len(object_pcd.points)}")
# Out:
# frame-1: Exported 0/1 | car_pts-9
# frame-2: Exported 0/1 | car_pts-53
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1814/870191404.py in <module>
#       2
#       3 for sample_idx in range(mesher.data_obj.__len__()):
# ----> 4     pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx)
#       5
#       6     for object_id in range(len(pcd_gtboxes['gt_boxes'])):
#
# /SEE-MTDA/see/sc/mesher/mesher.py in get_pcd_gtboxes(self, idx, add_ground_lift)
#      77         """
#      78         sample_infos = self.data_obj.get_infos(idx)
# ---> 79         o3dpcd = convert_to_o3dpcd(self.data_obj.get_pointcloud(idx))
#      80         pcd_gtboxes = populate_gtboxes(sample_infos, self.data_obj.dataset_name, self.classes, add_ground_lift=add_ground_lift)
#      81         pcd_gtboxes['pcd'] = o3dpcd
#
# /SEE-MTDA/see/sc/datasets/shared_utils.py in convert_to_o3dpcd(points)
#     232     else:
#     233         pcd = o3d.geometry.PointCloud()
# --> 234         pcd.points = o3d.utility.Vector3dVector(points[:,:3])
#     235         return pcd
#     236
#
# KeyboardInterrupt:

# %% [markdown]
# # Export points in mask/bbox
#
# This is to test out lidar segmentation on the points within a box

# %%
from PIL import Image

camera_channel = 'image_2'

export_tag = 'bbox'
if export_tag == 'bbox':
    use_bbox = True
else:
    use_bbox = False

instance_dataset_id = 0
for sample_idx in range(mesher.data_obj.__len__()):
    
    i_clouds = mesher.data_obj.get_mask_instance_clouds(sample_idx, use_bbox=use_bbox)
    pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx, add_ground_lift=True)    
    inst_labels = mesher.data_obj.get_camera_instances(sample_idx, channel=camera_channel)
        
    for object_id, i_cloud in enumerate(i_clouds):
        mask_pcd = convert_to_o3dpcd(i_clouds[object_id])
        cropped_pcds, num_pts_in_gt_for_mask = [], []        
        
        if len(i_cloud) < 5:
            continue
            
        for i in range(len(pcd_gtboxes['gt_boxes'])):    
            cropped = mask_pcd.crop(pcd_gtboxes['gt_boxes'][i])
            num_pts_in_gt_for_mask.append(len(cropped.points))
            cropped_pcds.append(cropped)            
            
        if not num_pts_in_gt_for_mask or max(num_pts_in_gt_for_mask) == 0:
            labelled_pts = np.hstack([i_cloud[:,:3], np.zeros((len(i_cloud),1))])
            box_pts = np.zeros((8,3))
            num_points_in_gt = 0
        else:
            gtbox_idx = np.argmax(np.array(num_pts_in_gt_for_mask)) 
            
            cropped_np = np.array(cropped_pcds[gtbox_idx].points)
            obj_pts_labelled = np.hstack([cropped_np, 10*np.ones((len(cropped_np),1))])

            dist = mask_pcd.compute_point_cloud_distance(cropped_pcds[gtbox_idx])
            cropped_inds = np.where(np.asarray(dist) < 0.01)[0]
            mask_without_obj = np.asarray(mask_pcd.select_by_index(cropped_inds, invert=True).points)
            mask_pts_labelled = np.hstack([mask_without_obj, np.zeros((len(mask_without_obj),1))])

            labelled_pts = np.vstack([mask_pts_labelled, obj_pts_labelled])
            box_pts = np.asarray(pcd_gtboxes['gt_boxes'][gtbox_idx].get_box_points())
            num_points_in_gt = len(cropped_np)
               
        # Save pcl
        fname = f"{instance_dataset_id:06}"
        car_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data_groundlift/points_in_{export_tag}/pointcloud')
        car_dir.mkdir(parents=True, exist_ok=True)
        car_fname = str(car_dir / f'{fname}.bin')
        points = np.float32(labelled_pts)
        points.tofile(car_fname)
        
        # Save points labels
        label_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data_groundlift/points_in_{export_tag}/labels')
        label_dir.mkdir(parents=True, exist_ok=True)
        label_fname = str(label_dir / f'{fname}.label')
        labels = np.uint32(labelled_pts[:,3])
        labels.tofile(label_fname)
        
        # Save gt bboxes
        box_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data_groundlift/points_in_{export_tag}/gt_bboxes')    
        box_dir.mkdir(parents=True, exist_ok=True)
        np.savetxt(str(box_dir / f'{fname}.txt'), box_pts, delimiter=' ')
        
        # Save img
        img_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data_groundlift/points_in_{export_tag}/image')    
        img_dir.mkdir(parents=True, exist_ok=True)
        img = mesher.data_obj.get_image(sample_idx, channel=camera_channel)
        imglabels = inst_labels[object_id]
        ann_img = draw_lidar_on_image([], img, instances=[imglabels], display=False)
        Image.fromarray(ann_img).save(str(img_dir / f'{fname}.png'))

        # Save original filepath of input pointcloud
        origpath_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data_groundlift/points_in_{export_tag}/fpath')
        origpath_dir.mkdir(parents=True, exist_ok=True)
        with open(str(origpath_dir / f'{fname}.txt'), 'w') as f:
              f.write(f'{sample_idx:06}')
        
        print(f"car #{instance_dataset_id}: Exported {object_id+1}/{len(i_clouds)} | total pts-{len(labelled_pts)}, gt pts - {num_points_in_gt}")
        instance_dataset_id = instance_dataset_id + 1
# Out:
# car #0: Exported 1/1 | total pts-10, gt pts - 9
# car #1: Exported 1/1 | total pts-110, gt pts - 53
# car #2: Exported 1/4 | total pts-408, gt pts - 0
# car #3: Exported 2/4 | total pts-952, gt pts - 618
# car #4: Exported 4/4 | total pts-15, gt pts - 0
# car #5: Exported 1/3 | total pts-120, gt pts - 65
# car #6: Exported 2/3 | total pts-33, gt pts - 25
# car #7: Exported 1/5 | total pts-666, gt pts - 282
# car #8: Exported 2/5 | total pts-138, gt pts - 53
# car #9: Exported 3/5 | total pts-98, gt pts - 15
# car #10: Exported 4/5 | total pts-10, gt pts - 0
# car #11: Exported 5/5 | total pts-16, gt pts - 0
# car #12: Exported 1/3 | total pts-213, gt pts - 156
# car #13: Exported 2/3 | total pts-25, gt pts - 18
# car #14: Exported 3/3 | total pts-7, gt pts - 5
# car #15: Exported 1/10 | total pts-2959, gt pts - 1445
# car #16: Exported 2/10 | total pts-1579, gt pts - 843
# car #17: Exported 3/10 | total pts-3099, gt pts - 1529
# car #18: Exported 4/10 | total pts-1038, gt pts - 590
# car #19: Exported 5/10 | total pts-298, gt pts - 154
# car #20: Exported 6/10 | total pts-85, gt pts - 39
# car #21: Exported 7/10 | total pts-12, gt pts - 0
# car #22: Exported 8/10 | total pts-19, gt pts - 2
# car #23: Exported 10/10 | total pts-6, gt pts - 0
# car #24: Exported 1/3 | total pts-237, gt pts - 171
# car #25: Exported 2/3 | total pts-29, gt pts - 0
# car #26: Exported 1/14 | total pts-986, gt pts - 242
# car #27: Exported 2/14 | total pts-1503, gt pts - 910
# car #28: Exported 3/14 | total pts-526, gt pts - 300
# car #29: Exported 4/14 | total pts-282, gt pts - 198
# car #30: Exported 5/14 | total pts-111, gt pts - 40
# car #31: Exported 6/14 | total pts-19, gt pts - 16
# car #32: Exported 7/14 | total pts-61, gt pts - 18
# car #33: Exported 8/14 | total pts-15, gt pts - 0
# car #34: Exported 9/14 | total pts-83, gt pts - 40
# car #35: Exported 10/14 | total pts-58, gt pts - 27
# car #36: Exported 11/14 | total pts-9, gt pts - 0
# car #37: Exported 12/14 | total pts-43, gt pts - 5
# car #38: Exported 13/14 | total pts-6, gt pts - 2
# car #39: Exported 14/14 | total pts-11, gt pts - 11
# car #40: Exported 1/2 | total pts-332, gt pts - 216
# car #41: Exported 2/2 | total pts-231, gt pts - 148
# car #42: Exported 1/1 | total pts-16, gt pts - 13
# car #43: Exported 1/1 | total pts-450, gt pts - 235
# car #44: Exported 1/1 | total pts-20, gt pts - 7
# car #45: Exported 1/1 | total pts-2383, gt pts - 1601
# car #46: Exported 1/14 | total pts-3040, gt pts - 1644
# car #47: Exported 2/14 | total pts-100, gt pts - 37
# car #48: Exported 3/14 | total pts-26, gt pts - 9
# car #49: Exported 4/14 | total pts-9, gt pts - 0
# car #50: Exported 5/14 | total pts-16, gt pts - 0
# car #51: Exported 6/14 | total pts-39, gt pts - 14
# car #52: Exported 7/14 | total pts-5, gt pts - 0
# car #53: Exported 8/14 | total pts-12, gt pts - 0
# car #54: Exported 9/14 | total pts-5, gt pts - 0
# car #55: Exported 10/14 | total pts-7, gt pts - 0
# car #56: Exported 11/14 | total pts-5, gt pts - 0
# car #57: Exported 13/14 | total pts-10, gt pts - 0
# car #58: Exported 1/1 | total pts-50, gt pts - 7
# car #59: Exported 1/13 | total pts-43, gt pts - 0
# car #60: Exported 2/13 | total pts-23, gt pts - 0
# car #61: Exported 3/13 | total pts-27, gt pts - 0
# car #62: Exported 4/13 | total pts-28, gt pts - 0
# car #63: Exported 5/13 | total pts-34, gt pts - 0
# car #64: Exported 6/13 | total pts-41, gt pts - 0
# car #65: Exported 7/13 | total pts-29, gt pts - 29
# car #66: Exported 8/13 | total pts-34, gt pts - 0
# car #67: Exported 9/13 | total pts-27, gt pts - 0
# car #68: Exported 11/13 | total pts-16, gt pts - 0
# car #69: Exported 1/6 | total pts-1701, gt pts - 1034
# car #70: Exported 2/6 | total pts-21, gt pts - 19
# car #71: Exported 3/6 | total pts-16, gt pts - 0
# car #72: Exported 5/6 | total pts-5, gt pts - 0
# car #73: Exported 1/1 | total pts-937, gt pts - 444
# car #74: Exported 1/8 | total pts-1227, gt pts - 720
# car #75: Exported 2/8 | total pts-509, gt pts - 199
# car #76: Exported 3/8 | total pts-221, gt pts - 143
# car #77: Exported 4/8 | total pts-158, gt pts - 91
# car #78: Exported 5/8 | total pts-145, gt pts - 64
# car #79: Exported 6/8 | total pts-96, gt pts - 56
# car #80: Exported 7/8 | total pts-9, gt pts - 7
# car #81: Exported 1/2 | total pts-161, gt pts - 39
# car #82: Exported 2/2 | total pts-101, gt pts - 56
# car #83: Exported 1/1 | total pts-16, gt pts - 13
# car #84: Exported 1/4 | total pts-143, gt pts - 75
# car #85: Exported 2/4 | total pts-64, gt pts - 29
# car #86: Exported 3/4 | total pts-24, gt pts - 11
# car #87: Exported 4/4 | total pts-6, gt pts - 0
# car #88: Exported 1/9 | total pts-2054, gt pts - 0
# car #89: Exported 2/9 | total pts-1150, gt pts - 135
# car #90: Exported 3/9 | total pts-1807, gt pts - 1053
# car #91: Exported 4/9 | total pts-442, gt pts - 299
# car #92: Exported 5/9 | total pts-104, gt pts - 52
# car #93: Exported 6/9 | total pts-500, gt pts - 176
# car #94: Exported 7/9 | total pts-89, gt pts - 25
# car #95: Exported 8/9 | total pts-16, gt pts - 0
# car #96: Exported 9/9 | total pts-22, gt pts - 0
# car #97: Exported 1/1 | total pts-12, gt pts - 12
# car #98: Exported 1/1 | total pts-86, gt pts - 48
# car #99: Exported 1/1 | total pts-26, gt pts - 20
# car #100: Exported 1/5 | total pts-1863, gt pts - 891
# car #101: Exported 2/5 | total pts-792, gt pts - 0
# car #102: Exported 3/5 | total pts-1425, gt pts - 966
# car #103: Exported 4/5 | total pts-883, gt pts - 484
# car #104: Exported 5/5 | total pts-204, gt pts - 123
# car #105: Exported 1/7 | total pts-2083, gt pts - 1216
# car #106: Exported 2/7 | total pts-2435, gt pts - 1371
# car #107: Exported 3/7 | total pts-792, gt pts - 381
# car #108: Exported 4/7 | total pts-413, gt pts - 203
# car #109: Exported 5/7 | total pts-91, gt pts - 0
# car #110: Exported 6/7 | total pts-51, gt pts - 26
# car #111: Exported 7/7 | total pts-75, gt pts - 0
# car #112: Exported 1/2 | total pts-940, gt pts - 349
# car #113: Exported 2/2 | total pts-17, gt pts - 9
# car #114: Exported 1/6 | total pts-1335, gt pts - 569
# car #115: Exported 2/6 | total pts-49, gt pts - 22
# car #116: Exported 3/6 | total pts-15, gt pts - 0
# car #117: Exported 5/6 | total pts-19, gt pts - 0
# car #118: Exported 1/3 | total pts-766, gt pts - 479
# car #119: Exported 2/3 | total pts-244, gt pts - 87
# car #120: Exported 3/3 | total pts-18, gt pts - 14
# car #121: Exported 1/9 | total pts-1524, gt pts - 954
# car #122: Exported 2/9 | total pts-423, gt pts - 166
# car #123: Exported 3/9 | total pts-268, gt pts - 78
# car #124: Exported 4/9 | total pts-198, gt pts - 81
# car #125: Exported 5/9 | total pts-20, gt pts - 5
# car #126: Exported 6/9 | total pts-62, gt pts - 35
# car #127: Exported 7/9 | total pts-14, gt pts - 12
# car #128: Exported 8/9 | total pts-16, gt pts - 8
# car #129: Exported 9/9 | total pts-13, gt pts - 11
# car #130: Exported 1/4 | total pts-449, gt pts - 321
# car #131: Exported 2/4 | total pts-84, gt pts - 44
# car #132: Exported 3/4 | total pts-47, gt pts - 20
# car #133: Exported 4/4 | total pts-27, gt pts - 3
# car #134: Exported 1/10 | total pts-2846, gt pts - 1489
# car #135: Exported 2/10 | total pts-774, gt pts - 496
# car #136: Exported 3/10 | total pts-858, gt pts - 368
# car #137: Exported 4/10 | total pts-526, gt pts - 309
# car #138: Exported 5/10 | total pts-273, gt pts - 191
# car #139: Exported 6/10 | total pts-163, gt pts - 134
# car #140: Exported 7/10 | total pts-91, gt pts - 46
# car #141: Exported 8/10 | total pts-62, gt pts - 19
# car #142: Exported 9/10 | total pts-27, gt pts - 16
# car #143: Exported 10/10 | total pts-26, gt pts - 7
# car #144: Exported 1/6 | total pts-3206, gt pts - 1148
# car #145: Exported 2/6 | total pts-613, gt pts - 208
# car #146: Exported 3/6 | total pts-115, gt pts - 49
# car #147: Exported 4/6 | total pts-122, gt pts - 77
# car #148: Exported 5/6 | total pts-18, gt pts - 16
# car #149: Exported 6/6 | total pts-33, gt pts - 15
# car #150: Exported 1/2 | total pts-85, gt pts - 59
# car #151: Exported 2/2 | total pts-17, gt pts - 8
# car #152: Exported 1/5 | total pts-93, gt pts - 56
# car #153: Exported 2/5 | total pts-27, gt pts - 0
# car #154: Exported 3/5 | total pts-14, gt pts - 0
# car #155: Exported 5/5 | total pts-8, gt pts - 0
# car #156: Exported 1/1 | total pts-25, gt pts - 16
# car #157: Exported 1/2 | total pts-2440, gt pts - 1593
# car #158: Exported 2/2 | total pts-840, gt pts - 456
# car #159: Exported 1/7 | total pts-1064, gt pts - 519
# car #160: Exported 2/7 | total pts-345, gt pts - 160
# car #161: Exported 3/7 | total pts-113, gt pts - 60
# car #162: Exported 4/7 | total pts-102, gt pts - 26
# car #163: Exported 5/7 | total pts-44, gt pts - 18
# car #164: Exported 6/7 | total pts-25, gt pts - 20
# car #165: Exported 7/7 | total pts-10, gt pts - 0
# car #166: Exported 1/6 | total pts-3209, gt pts - 1829
# car #167: Exported 2/6 | total pts-640, gt pts - 389
# car #168: Exported 3/6 | total pts-128, gt pts - 102
# car #169: Exported 4/6 | total pts-136, gt pts - 94
# car #170: Exported 5/6 | total pts-55, gt pts - 21
# car #171: Exported 6/6 | total pts-49, gt pts - 22
# car #172: Exported 1/9 | total pts-1543, gt pts - 931
# car #173: Exported 2/9 | total pts-527, gt pts - 202
# car #174: Exported 3/9 | total pts-190, gt pts - 119
# car #175: Exported 4/9 | total pts-138, gt pts - 23
# car #176: Exported 5/9 | total pts-169, gt pts - 134
# car #177: Exported 6/9 | total pts-153, gt pts - 88
# car #178: Exported 7/9 | total pts-25, gt pts - 12
# car #179: Exported 8/9 | total pts-74, gt pts - 29
# car #180: Exported 9/9 | total pts-14, gt pts - 12
# car #181: Exported 1/12 | total pts-1388, gt pts - 523
# car #182: Exported 2/12 | total pts-904, gt pts - 0
# car #183: Exported 3/12 | total pts-1352, gt pts - 829
# car #184: Exported 4/12 | total pts-1181, gt pts - 418
# car #185: Exported 5/12 | total pts-185, gt pts - 20
# car #186: Exported 6/12 | total pts-726, gt pts - 404
# car #187: Exported 7/12 | total pts-523, gt pts - 280
# car #188: Exported 8/12 | total pts-466, gt pts - 203
# car #189: Exported 9/12 | total pts-273, gt pts - 176
# car #190: Exported 10/12 | total pts-137, gt pts - 48
# car #191: Exported 11/12 | total pts-283, gt pts - 134
# car #192: Exported 12/12 | total pts-104, gt pts - 54
# car #193: Exported 1/4 | total pts-1426, gt pts - 155
# car #194: Exported 2/4 | total pts-1906, gt pts - 1000
# car #195: Exported 3/4 | total pts-992, gt pts - 623
# car #196: Exported 4/4 | total pts-104, gt pts - 52
# car #197: Exported 1/10 | total pts-312, gt pts - 0
# car #198: Exported 2/10 | total pts-73, gt pts - 45
# car #199: Exported 3/10 | total pts-155, gt pts - 0
# car #200: Exported 4/10 | total pts-100, gt pts - 0
# car #201: Exported 5/10 | total pts-96, gt pts - 0
# car #202: Exported 6/10 | total pts-67, gt pts - 0
# car #203: Exported 7/10 | total pts-60, gt pts - 0
# car #204: Exported 8/10 | total pts-64, gt pts - 0
# car #205: Exported 9/10 | total pts-42, gt pts - 0
# car #206: Exported 10/10 | total pts-24, gt pts - 0
# car #207: Exported 1/11 | total pts-2624, gt pts - 14
# car #208: Exported 2/11 | total pts-651, gt pts - 349
# car #209: Exported 3/11 | total pts-319, gt pts - 228
# car #210: Exported 4/11 | total pts-131, gt pts - 10
# car #211: Exported 5/11 | total pts-270, gt pts - 174
# car #212: Exported 6/11 | total pts-150, gt pts - 0
# car #213: Exported 7/11 | total pts-222, gt pts - 117
# car #214: Exported 8/11 | total pts-50, gt pts - 0
# car #215: Exported 9/11 | total pts-103, gt pts - 3
# car #216: Exported 10/11 | total pts-13, gt pts - 8
# car #217: Exported 1/8 | total pts-1698, gt pts - 608
# car #218: Exported 2/8 | total pts-980, gt pts - 494
# car #219: Exported 3/8 | total pts-334, gt pts - 107
# car #220: Exported 4/8 | total pts-102, gt pts - 36
# car #221: Exported 5/8 | total pts-141, gt pts - 61
# car #222: Exported 6/8 | total pts-37, gt pts - 13
# car #223: Exported 7/8 | total pts-18, gt pts - 0
# car #224: Exported 8/8 | total pts-14, gt pts - 0
# car #225: Exported 1/5 | total pts-103, gt pts - 20
# car #226: Exported 2/5 | total pts-72, gt pts - 17
# car #227: Exported 3/5 | total pts-55, gt pts - 14
# car #228: Exported 4/5 | total pts-14, gt pts - 4
# car #229: Exported 5/5 | total pts-7, gt pts - 0
# car #230: Exported 1/1 | total pts-20, gt pts - 19
# car #231: Exported 1/2 | total pts-434, gt pts - 184
# car #232: Exported 2/2 | total pts-157, gt pts - 84
# car #233: Exported 1/4 | total pts-265, gt pts - 76
# car #234: Exported 2/4 | total pts-255, gt pts - 120
# car #235: Exported 3/4 | total pts-148, gt pts - 67
# car #236: Exported 4/4 | total pts-52, gt pts - 52
# car #237: Exported 1/3 | total pts-286, gt pts - 183
# car #238: Exported 2/3 | total pts-9, gt pts - 1
# car #239: Exported 3/3 | total pts-12, gt pts - 0
# car #240: Exported 1/5 | total pts-196, gt pts - 130
# car #241: Exported 2/5 | total pts-164, gt pts - 97
# car #242: Exported 3/5 | total pts-23, gt pts - 13
# car #243: Exported 4/5 | total pts-31, gt pts - 0
# car #244: Exported 5/5 | total pts-27, gt pts - 0
# car #245: Exported 1/7 | total pts-615, gt pts - 403
# car #246: Exported 2/7 | total pts-160, gt pts - 69
# car #247: Exported 3/7 | total pts-60, gt pts - 13
# car #248: Exported 4/7 | total pts-33, gt pts - 6
# car #249: Exported 5/7 | total pts-11, gt pts - 6
# car #250: Exported 7/7 | total pts-5, gt pts - 0
# car #251: Exported 1/3 | total pts-1454, gt pts - 272
# car #252: Exported 2/3 | total pts-473, gt pts - 273
# car #253: Exported 3/3 | total pts-140, gt pts - 3
# car #254: Exported 1/4 | total pts-1151, gt pts - 748
# car #255: Exported 2/4 | total pts-163, gt pts - 108
# car #256: Exported 3/4 | total pts-71, gt pts - 31
# car #257: Exported 4/4 | total pts-19, gt pts - 0
# car #258: Exported 1/4 | total pts-111, gt pts - 96
# car #259: Exported 2/4 | total pts-56, gt pts - 18
# car #260: Exported 3/4 | total pts-7, gt pts - 1
# car #261: Exported 4/4 | total pts-6, gt pts - 0
# car #262: Exported 1/12 | total pts-1654, gt pts - 629
# car #263: Exported 2/12 | total pts-1531, gt pts - 735
# car #264: Exported 3/12 | total pts-52, gt pts - 17
# car #265: Exported 4/12 | total pts-33, gt pts - 21
# car #266: Exported 5/12 | total pts-7, gt pts - 0
# car #267: Exported 6/12 | total pts-20, gt pts - 0
# car #268: Exported 7/12 | total pts-6, gt pts - 0
# car #269: Exported 8/12 | total pts-12, gt pts - 0
# car #270: Exported 9/12 | total pts-5, gt pts - 0
# car #271: Exported 1/10 | total pts-2856, gt pts - 1675
# car #272: Exported 2/10 | total pts-584, gt pts - 206
# car #273: Exported 3/10 | total pts-1384, gt pts - 114
# car #274: Exported 4/10 | total pts-395, gt pts - 206
# car #275: Exported 5/10 | total pts-154, gt pts - 107
# car #276: Exported 6/10 | total pts-103, gt pts - 66
# car #277: Exported 7/10 | total pts-70, gt pts - 37
# car #278: Exported 8/10 | total pts-57, gt pts - 9
# car #279: Exported 9/10 | total pts-13, gt pts - 8
# car #280: Exported 10/10 | total pts-11, gt pts - 0
# car #281: Exported 1/3 | total pts-1069, gt pts - 598
# car #282: Exported 2/3 | total pts-45, gt pts - 13
# car #283: Exported 3/3 | total pts-9, gt pts - 3
# car #284: Exported 1/1 | total pts-360, gt pts - 249
# car #285: Exported 1/3 | total pts-1469, gt pts - 782
# car #286: Exported 2/3 | total pts-125, gt pts - 59
# car #287: Exported 3/3 | total pts-74, gt pts - 55
# car #288: Exported 1/5 | total pts-325, gt pts - 39
# car #289: Exported 2/5 | total pts-729, gt pts - 451
# car #290: Exported 3/5 | total pts-294, gt pts - 163
# car #291: Exported 4/5 | total pts-206, gt pts - 88
# car #292: Exported 5/5 | total pts-20, gt pts - 2
# car #293: Exported 1/2 | total pts-54, gt pts - 36
# car #294: Exported 2/2 | total pts-11, gt pts - 0
# car #295: Exported 1/7 | total pts-2182, gt pts - 35
# car #296: Exported 2/7 | total pts-1433, gt pts - 876
# car #297: Exported 3/7 | total pts-186, gt pts - 0
# car #298: Exported 4/7 | total pts-93, gt pts - 31
# car #299: Exported 5/7 | total pts-27, gt pts - 1
# car #300: Exported 1/14 | total pts-1574, gt pts - 582
# car #301: Exported 2/14 | total pts-1958, gt pts - 874
# car #302: Exported 3/14 | total pts-45, gt pts - 11
# car #303: Exported 4/14 | total pts-7, gt pts - 0
# car #304: Exported 5/14 | total pts-36, gt pts - 21
# car #305: Exported 6/14 | total pts-21, gt pts - 0
# car #306: Exported 7/14 | total pts-6, gt pts - 0
# car #307: Exported 8/14 | total pts-17, gt pts - 2
# car #308: Exported 9/14 | total pts-12, gt pts - 0
# car #309: Exported 11/14 | total pts-6, gt pts - 0
# car #310: Exported 13/14 | total pts-10, gt pts - 0
# car #311: Exported 1/6 | total pts-268, gt pts - 195
# car #312: Exported 2/6 | total pts-101, gt pts - 88
# car #313: Exported 3/6 | total pts-13, gt pts - 10
# car #314: Exported 4/6 | total pts-33, gt pts - 0
# car #315: Exported 6/6 | total pts-5, gt pts - 4
# car #316: Exported 1/1 | total pts-19, gt pts - 0
# car #317: Exported 1/1 | total pts-11, gt pts - 10
# car #318: Exported 1/8 | total pts-1433, gt pts - 223
# car #319: Exported 2/8 | total pts-1854, gt pts - 60
# car #320: Exported 3/8 | total pts-1318, gt pts - 399
# car #321: Exported 4/8 | total pts-201, gt pts - 46
# car #322: Exported 5/8 | total pts-216, gt pts - 53
# car #323: Exported 6/8 | total pts-77, gt pts - 30
# car #324: Exported 7/8 | total pts-48, gt pts - 8
# car #325: Exported 8/8 | total pts-31, gt pts - 0
# car #326: Exported 1/2 | total pts-156, gt pts - 120
# car #327: Exported 2/2 | total pts-14, gt pts - 2
# car #328: Exported 1/7 | total pts-1646, gt pts - 645
# car #329: Exported 2/7 | total pts-156, gt pts - 48
# car #330: Exported 3/7 | total pts-476, gt pts - 324
# car #331: Exported 4/7 | total pts-451, gt pts - 176
# car #332: Exported 5/7 | total pts-357, gt pts - 182
# car #333: Exported 6/7 | total pts-184, gt pts - 76
# car #334: Exported 7/7 | total pts-97, gt pts - 25
# car #335: Exported 1/6 | total pts-844, gt pts - 424
# car #336: Exported 2/6 | total pts-77, gt pts - 53
# car #337: Exported 3/6 | total pts-89, gt pts - 0
# car #338: Exported 4/6 | total pts-65, gt pts - 0
# car #339: Exported 5/6 | total pts-39, gt pts - 18
# car #340: Exported 6/6 | total pts-19, gt pts - 0
# car #341: Exported 1/3 | total pts-883, gt pts - 484
# car #342: Exported 2/3 | total pts-153, gt pts - 18
# car #343: Exported 3/3 | total pts-28, gt pts - 0
# car #344: Exported 1/5 | total pts-1316, gt pts - 761
# car #345: Exported 2/5 | total pts-402, gt pts - 190
# car #346: Exported 3/5 | total pts-399, gt pts - 229
# car #347: Exported 4/5 | total pts-232, gt pts - 127
# car #348: Exported 5/5 | total pts-37, gt pts - 19
# car #349: Exported 1/2 | total pts-385, gt pts - 182
# car #350: Exported 2/2 | total pts-77, gt pts - 9
# car #351: Exported 1/8 | total pts-119, gt pts - 0
# car #352: Exported 2/8 | total pts-133, gt pts - 0
# car #353: Exported 3/8 | total pts-73, gt pts - 46
# car #354: Exported 4/8 | total pts-67, gt pts - 0
# car #355: Exported 5/8 | total pts-59, gt pts - 0
# car #356: Exported 6/8 | total pts-44, gt pts - 0
# car #357: Exported 7/8 | total pts-45, gt pts - 0
# car #358: Exported 1/5 | total pts-255, gt pts - 90
# car #359: Exported 2/5 | total pts-215, gt pts - 123
# car #360: Exported 3/5 | total pts-137, gt pts - 99
# car #361: Exported 4/5 | total pts-21, gt pts - 10
# car #362: Exported 5/5 | total pts-12, gt pts - 0
# car #363: Exported 1/13 | total pts-2705, gt pts - 1732
# car #364: Exported 2/13 | total pts-962, gt pts - 537
# car #365: Exported 3/13 | total pts-516, gt pts - 339
# car #366: Exported 4/13 | total pts-549, gt pts - 278
# car #367: Exported 5/13 | total pts-75, gt pts - 0
# car #368: Exported 6/13 | total pts-40, gt pts - 5
# car #369: Exported 7/13 | total pts-51, gt pts - 11
# car #370: Exported 8/13 | total pts-65, gt pts - 27
# car #371: Exported 9/13 | total pts-14, gt pts - 0
# car #372: Exported 10/13 | total pts-10, gt pts - 10
# car #373: Exported 1/1 | total pts-455, gt pts - 263
# car #374: Exported 1/13 | total pts-1101, gt pts - 514
# car #375: Exported 2/13 | total pts-1139, gt pts - 586
# car #376: Exported 3/13 | total pts-441, gt pts - 100
# car #377: Exported 4/13 | total pts-437, gt pts - 334
# car #378: Exported 5/13 | total pts-343, gt pts - 222
# car #379: Exported 6/13 | total pts-148, gt pts - 94
# car #380: Exported 7/13 | total pts-102, gt pts - 34
# car #381: Exported 8/13 | total pts-97, gt pts - 54
# car #382: Exported 9/13 | total pts-65, gt pts - 21
# car #383: Exported 10/13 | total pts-184, gt pts - 102
# car #384: Exported 11/13 | total pts-22, gt pts - 11
# car #385: Exported 12/13 | total pts-7, gt pts - 6
# car #386: Exported 13/13 | total pts-16, gt pts - 5
# car #387: Exported 1/7 | total pts-3035, gt pts - 1859
# car #388: Exported 2/7 | total pts-2351, gt pts - 1149
# car #389: Exported 3/7 | total pts-462, gt pts - 0
# car #390: Exported 4/7 | total pts-123, gt pts - 55
# car #391: Exported 5/7 | total pts-194, gt pts - 106
# car #392: Exported 6/7 | total pts-61, gt pts - 0
# car #393: Exported 7/7 | total pts-25, gt pts - 0
# car #394: Exported 1/3 | total pts-12, gt pts - 9
# car #395: Exported 2/3 | total pts-13, gt pts - 9
# car #396: Exported 3/3 | total pts-9, gt pts - 0
# car #397: Exported 1/7 | total pts-935, gt pts - 550
# car #398: Exported 2/7 | total pts-345, gt pts - 226
# car #399: Exported 3/7 | total pts-392, gt pts - 239
# car #400: Exported 4/7 | total pts-60, gt pts - 28
# car #401: Exported 5/7 | total pts-34, gt pts - 25
# car #402: Exported 6/7 | total pts-89, gt pts - 67
# car #403: Exported 7/7 | total pts-18, gt pts - 2
# car #404: Exported 1/16 | total pts-1770, gt pts - 502
# car #405: Exported 2/16 | total pts-2033, gt pts - 1275
# car #406: Exported 3/16 | total pts-1046, gt pts - 587
# car #407: Exported 4/16 | total pts-853, gt pts - 616
# car #408: Exported 5/16 | total pts-356, gt pts - 150
# car #409: Exported 6/16 | total pts-201, gt pts - 159
# car #410: Exported 7/16 | total pts-81, gt pts - 0
# car #411: Exported 8/16 | total pts-390, gt pts - 242
# car #412: Exported 9/16 | total pts-47, gt pts - 0
# car #413: Exported 10/16 | total pts-10, gt pts - 0
# car #414: Exported 11/16 | total pts-12, gt pts - 0
# car #415: Exported 12/16 | total pts-17, gt pts - 4
# car #416: Exported 13/16 | total pts-30, gt pts - 12
# car #417: Exported 14/16 | total pts-33, gt pts - 0
# car #418: Exported 15/16 | total pts-39, gt pts - 0
# car #419: Exported 16/16 | total pts-14, gt pts - 0
# car #420: Exported 1/5 | total pts-114, gt pts - 40
# car #421: Exported 2/5 | total pts-178, gt pts - 58
# car #422: Exported 3/5 | total pts-406, gt pts - 292
# car #423: Exported 4/5 | total pts-9, gt pts - 0
# car #424: Exported 1/3 | total pts-268, gt pts - 42
# car #425: Exported 2/3 | total pts-96, gt pts - 44
# car #426: Exported 3/3 | total pts-44, gt pts - 12
# car #427: Exported 1/7 | total pts-1152, gt pts - 355
# car #428: Exported 2/7 | total pts-173, gt pts - 124
# car #429: Exported 3/7 | total pts-229, gt pts - 110
# car #430: Exported 4/7 | total pts-93, gt pts - 40
# car #431: Exported 5/7 | total pts-23, gt pts - 3
# car #432: Exported 6/7 | total pts-17, gt pts - 8
# car #433: Exported 7/7 | total pts-7, gt pts - 0
# car #434: Exported 1/5 | total pts-97, gt pts - 0
# car #435: Exported 2/5 | total pts-51, gt pts - 0
# car #436: Exported 3/5 | total pts-56, gt pts - 0
# car #437: Exported 4/5 | total pts-7, gt pts - 7
# car #438: Exported 5/5 | total pts-5, gt pts - 0
# car #439: Exported 1/4 | total pts-910, gt pts - 312
# car #440: Exported 2/4 | total pts-326, gt pts - 179
# car #441: Exported 3/4 | total pts-44, gt pts - 20
# car #442: Exported 4/4 | total pts-13, gt pts - 13
# car #443: Exported 1/8 | total pts-2875, gt pts - 1519
# car #444: Exported 2/8 | total pts-1272, gt pts - 579
# car #445: Exported 3/8 | total pts-545, gt pts - 299
# car #446: Exported 4/8 | total pts-323, gt pts - 191
# car #447: Exported 5/8 | total pts-138, gt pts - 50
# car #448: Exported 6/8 | total pts-80, gt pts - 56
# car #449: Exported 7/8 | total pts-56, gt pts - 17
# car #450: Exported 8/8 | total pts-71, gt pts - 34
# car #451: Exported 1/1 | total pts-856, gt pts - 114
# car #452: Exported 1/13 | total pts-1813, gt pts - 527
# car #453: Exported 2/13 | total pts-640, gt pts - 386
# car #454: Exported 3/13 | total pts-328, gt pts - 149
# car #455: Exported 4/13 | total pts-499, gt pts - 322
# car #456: Exported 5/13 | total pts-143, gt pts - 112
# car #457: Exported 6/13 | total pts-75, gt pts - 0
# car #458: Exported 7/13 | total pts-111, gt pts - 60
# car #459: Exported 8/13 | total pts-33, gt pts - 17
# car #460: Exported 9/13 | total pts-42, gt pts - 30
# car #461: Exported 10/13 | total pts-45, gt pts - 34
# car #462: Exported 11/13 | total pts-65, gt pts - 23
# car #463: Exported 12/13 | total pts-15, gt pts - 3
# car #464: Exported 1/9 | total pts-1246, gt pts - 425
# car #465: Exported 2/9 | total pts-182, gt pts - 70
# car #466: Exported 3/9 | total pts-360, gt pts - 210
# car #467: Exported 4/9 | total pts-211, gt pts - 126
# car #468: Exported 5/9 | total pts-212, gt pts - 165
# car #469: Exported 6/9 | total pts-199, gt pts - 34
# car #470: Exported 7/9 | total pts-36, gt pts - 15
# car #471: Exported 9/9 | total pts-6, gt pts - 1
# car #472: Exported 1/11 | total pts-1927, gt pts - 855
# car #473: Exported 2/11 | total pts-1088, gt pts - 742
# car #474: Exported 3/11 | total pts-210, gt pts - 150
# car #475: Exported 4/11 | total pts-380, gt pts - 91
# car #476: Exported 5/11 | total pts-647, gt pts - 282
# car #477: Exported 6/11 | total pts-400, gt pts - 189
# car #478: Exported 7/11 | total pts-179, gt pts - 60
# car #479: Exported 8/11 | total pts-328, gt pts - 134
# car #480: Exported 9/11 | total pts-179, gt pts - 88
# car #481: Exported 10/11 | total pts-87, gt pts - 46
# car #482: Exported 11/11 | total pts-57, gt pts - 11
# car #483: Exported 1/8 | total pts-3045, gt pts - 1815
# car #484: Exported 2/8 | total pts-472, gt pts - 286
# car #485: Exported 3/8 | total pts-367, gt pts - 155
# car #486: Exported 4/8 | total pts-219, gt pts - 131
# car #487: Exported 5/8 | total pts-153, gt pts - 76
# car #488: Exported 6/8 | total pts-176, gt pts - 62
# car #489: Exported 7/8 | total pts-116, gt pts - 68
# car #490: Exported 8/8 | total pts-68, gt pts - 29
# car #491: Exported 1/11 | total pts-518, gt pts - 367
# car #492: Exported 2/11 | total pts-190, gt pts - 0
# car #493: Exported 3/11 | total pts-439, gt pts - 150
# car #494: Exported 4/11 | total pts-188, gt pts - 114
# car #495: Exported 5/11 | total pts-286, gt pts - 0
# car #496: Exported 6/11 | total pts-61, gt pts - 1
# car #497: Exported 7/11 | total pts-138, gt pts - 74
# car #498: Exported 8/11 | total pts-59, gt pts - 38
# car #499: Exported 9/11 | total pts-58, gt pts - 27
# car #500: Exported 10/11 | total pts-38, gt pts - 19
# car #501: Exported 11/11 | total pts-50, gt pts - 18
# car #502: Exported 1/4 | total pts-86, gt pts - 33
# car #503: Exported 2/4 | total pts-71, gt pts - 33
# car #504: Exported 3/4 | total pts-25, gt pts - 0
# car #505: Exported 4/4 | total pts-7, gt pts - 0
# car #506: Exported 1/5 | total pts-3097, gt pts - 1398
# car #507: Exported 2/5 | total pts-358, gt pts - 149
# car #508: Exported 3/5 | total pts-179, gt pts - 78
# car #509: Exported 4/5 | total pts-60, gt pts - 13
# car #510: Exported 5/5 | total pts-49, gt pts - 17
# car #511: Exported 1/12 | total pts-2468, gt pts - 1427
# car #512: Exported 2/12 | total pts-1595, gt pts - 1066
# car #513: Exported 3/12 | total pts-742, gt pts - 307
# car #514: Exported 4/12 | total pts-549, gt pts - 219
# car #515: Exported 5/12 | total pts-673, gt pts - 476
# car #516: Exported 6/12 | total pts-268, gt pts - 151
# car #517: Exported 7/12 | total pts-89, gt pts - 0
# car #518: Exported 8/12 | total pts-63, gt pts - 0
# car #519: Exported 9/12 | total pts-115, gt pts - 54
# car #520: Exported 10/12 | total pts-62, gt pts - 30
# car #521: Exported 11/12 | total pts-48, gt pts - 0
# car #522: Exported 1/4 | total pts-268, gt pts - 0
# car #523: Exported 2/4 | total pts-572, gt pts - 349
# car #524: Exported 3/4 | total pts-481, gt pts - 253
# car #525: Exported 1/12 | total pts-2863, gt pts - 1515
# car #526: Exported 2/12 | total pts-1208, gt pts - 520
# car #527: Exported 3/12 | total pts-724, gt pts - 356
# car #528: Exported 4/12 | total pts-235, gt pts - 117
# car #529: Exported 5/12 | total pts-186, gt pts - 99
# car #530: Exported 6/12 | total pts-227, gt pts - 139
# car #531: Exported 7/12 | total pts-205, gt pts - 43
# car #532: Exported 8/12 | total pts-145, gt pts - 79
# car #533: Exported 9/12 | total pts-117, gt pts - 57
# car #534: Exported 10/12 | total pts-84, gt pts - 42
# car #535: Exported 11/12 | total pts-41, gt pts - 13
# car #536: Exported 12/12 | total pts-25, gt pts - 0
# car #537: Exported 1/16 | total pts-117, gt pts - 40
# car #538: Exported 2/16 | total pts-73, gt pts - 29
# car #539: Exported 3/16 | total pts-49, gt pts - 21
# car #540: Exported 4/16 | total pts-46, gt pts - 35
# car #541: Exported 5/16 | total pts-21, gt pts - 0
# car #542: Exported 6/16 | total pts-7, gt pts - 0
# car #543: Exported 7/16 | total pts-6, gt pts - 0
# car #544: Exported 8/16 | total pts-12, gt pts - 0
# car #545: Exported 10/16 | total pts-6, gt pts - 0
# car #546: Exported 11/16 | total pts-7, gt pts - 0
# car #547: Exported 14/16 | total pts-5, gt pts - 0
# car #548: Exported 1/1 | total pts-350, gt pts - 78
# car #549: Exported 1/1 | total pts-25, gt pts - 14
# car #550: Exported 1/3 | total pts-45, gt pts - 14
# car #551: Exported 2/3 | total pts-23, gt pts - 20
# car #552: Exported 3/3 | total pts-5, gt pts - 0
# car #553: Exported 1/6 | total pts-2950, gt pts - 1980
# car #554: Exported 2/6 | total pts-96, gt pts - 9
# car #555: Exported 3/6 | total pts-140, gt pts - 29
# car #556: Exported 4/6 | total pts-136, gt pts - 97
# car #557: Exported 5/6 | total pts-19, gt pts - 12
# car #558: Exported 6/6 | total pts-32, gt pts - 12
# car #559: Exported 1/3 | total pts-427, gt pts - 0
# car #560: Exported 2/3 | total pts-656, gt pts - 317
# car #561: Exported 3/3 | total pts-66, gt pts - 7
# car #562: Exported 1/10 | total pts-1061, gt pts - 616
# car #563: Exported 2/10 | total pts-110, gt pts - 30
# car #564: Exported 3/10 | total pts-65, gt pts - 0
# car #565: Exported 4/10 | total pts-35, gt pts - 13
# car #566: Exported 5/10 | total pts-43, gt pts - 9
# car #567: Exported 6/10 | total pts-47, gt pts - 8
# car #568: Exported 7/10 | total pts-90, gt pts - 39
# car #569: Exported 8/10 | total pts-39, gt pts - 0
# car #570: Exported 9/10 | total pts-9, gt pts - 5
# car #571: Exported 10/10 | total pts-20, gt pts - 0
# car #572: Exported 1/2 | total pts-535, gt pts - 153
# car #573: Exported 2/2 | total pts-9, gt pts - 0
# car #574: Exported 1/7 | total pts-1020, gt pts - 416
# car #575: Exported 2/7 | total pts-389, gt pts - 203
# car #576: Exported 3/7 | total pts-123, gt pts - 43
# car #577: Exported 4/7 | total pts-27, gt pts - 6
# car #578: Exported 5/7 | total pts-38, gt pts - 16
# car #579: Exported 6/7 | total pts-22, gt pts - 11
# car #580: Exported 1/16 | total pts-449, gt pts - 211
# car #581: Exported 2/16 | total pts-122, gt pts - 0
# car #582: Exported 3/16 | total pts-294, gt pts - 88
# car #583: Exported 4/16 | total pts-86, gt pts - 38
# car #584: Exported 5/16 | total pts-21, gt pts - 0
# car #585: Exported 6/16 | total pts-40, gt pts - 11
# car #586: Exported 7/16 | total pts-8, gt pts - 7
# car #587: Exported 8/16 | total pts-6, gt pts - 0
# car #588: Exported 11/16 | total pts-15, gt pts - 0
# car #589: Exported 12/16 | total pts-5, gt pts - 0
# car #590: Exported 14/16 | total pts-15, gt pts - 0
# car #591: Exported 1/2 | total pts-126, gt pts - 94
# car #592: Exported 1/5 | total pts-86, gt pts - 57
# car #593: Exported 2/5 | total pts-47, gt pts - 38
# car #594: Exported 3/5 | total pts-5, gt pts - 0
# car #595: Exported 4/5 | total pts-15, gt pts - 12
# car #596: Exported 5/5 | total pts-9, gt pts - 7
# car #597: Exported 1/4 | total pts-1287, gt pts - 393
# car #598: Exported 2/4 | total pts-124, gt pts - 10
# car #599: Exported 3/4 | total pts-129, gt pts - 3
# car #600: Exported 4/4 | total pts-20, gt pts - 0
# car #601: Exported 1/12 | total pts-205, gt pts - 0
# car #602: Exported 2/12 | total pts-391, gt pts - 217
# car #603: Exported 3/12 | total pts-133, gt pts - 86
# car #604: Exported 4/12 | total pts-259, gt pts - 126
# car #605: Exported 5/12 | total pts-167, gt pts - 91
# car #606: Exported 6/12 | total pts-63, gt pts - 29
# car #607: Exported 7/12 | total pts-69, gt pts - 33
# car #608: Exported 8/12 | total pts-66, gt pts - 0
# car #609: Exported 9/12 | total pts-18, gt pts - 0
# car #610: Exported 10/12 | total pts-24, gt pts - 1
# car #611: Exported 11/12 | total pts-11, gt pts - 6
# car #612: Exported 12/12 | total pts-6, gt pts - 0
# car #613: Exported 1/7 | total pts-2276, gt pts - 1314
# car #614: Exported 2/7 | total pts-195, gt pts - 99
# car #615: Exported 3/7 | total pts-333, gt pts - 160
# car #616: Exported 4/7 | total pts-102, gt pts - 32
# car #617: Exported 5/7 | total pts-124, gt pts - 55
# car #618: Exported 6/7 | total pts-38, gt pts - 16
# car #619: Exported 1/4 | total pts-76, gt pts - 25
# car #620: Exported 2/4 | total pts-42, gt pts - 3
# car #621: Exported 3/4 | total pts-17, gt pts - 1
# car #622: Exported 4/4 | total pts-9, gt pts - 5
# car #623: Exported 1/7 | total pts-645, gt pts - 399
# car #624: Exported 2/7 | total pts-222, gt pts - 139
# car #625: Exported 3/7 | total pts-34, gt pts - 20
# car #626: Exported 4/7 | total pts-81, gt pts - 47
# car #627: Exported 5/7 | total pts-69, gt pts - 37
# car #628: Exported 6/7 | total pts-19, gt pts - 7
# car #629: Exported 7/7 | total pts-13, gt pts - 5
# car #630: Exported 1/2 | total pts-27, gt pts - 13
# car #631: Exported 2/2 | total pts-15, gt pts - 0
# car #632: Exported 1/4 | total pts-869, gt pts - 340
# car #633: Exported 2/4 | total pts-429, gt pts - 206
# car #634: Exported 3/4 | total pts-160, gt pts - 63
# car #635: Exported 4/4 | total pts-105, gt pts - 25
# car #636: Exported 1/1 | total pts-888, gt pts - 504
# car #637: Exported 1/10 | total pts-2860, gt pts - 1878
# car #638: Exported 2/10 | total pts-1431, gt pts - 489
# car #639: Exported 3/10 | total pts-1277, gt pts - 685
# car #640: Exported 4/10 | total pts-774, gt pts - 346
# car #641: Exported 5/10 | total pts-580, gt pts - 146
# car #642: Exported 6/10 | total pts-503, gt pts - 299
# car #643: Exported 7/10 | total pts-491, gt pts - 247
# car #644: Exported 8/10 | total pts-212, gt pts - 126
# car #645: Exported 9/10 | total pts-51, gt pts - 28
# car #646: Exported 10/10 | total pts-83, gt pts - 40
# car #647: Exported 1/6 | total pts-130, gt pts - 11
# car #648: Exported 2/6 | total pts-41, gt pts - 13
# car #649: Exported 3/6 | total pts-40, gt pts - 28
# car #650: Exported 1/3 | total pts-1348, gt pts - 262
# car #651: Exported 2/3 | total pts-2139, gt pts - 1339
# car #652: Exported 3/3 | total pts-191, gt pts - 131
# car #653: Exported 1/4 | total pts-195, gt pts - 102
# car #654: Exported 2/4 | total pts-167, gt pts - 73
# car #655: Exported 3/4 | total pts-130, gt pts - 50
# car #656: Exported 4/4 | total pts-66, gt pts - 18
# car #657: Exported 1/15 | total pts-2529, gt pts - 1442
# car #658: Exported 2/15 | total pts-923, gt pts - 317
# car #659: Exported 3/15 | total pts-2126, gt pts - 1139
# car #660: Exported 4/15 | total pts-713, gt pts - 553
# car #661: Exported 5/15 | total pts-390, gt pts - 183
# car #662: Exported 6/15 | total pts-306, gt pts - 188
# car #663: Exported 7/15 | total pts-228, gt pts - 139
# car #664: Exported 8/15 | total pts-357, gt pts - 170
# car #665: Exported 9/15 | total pts-249, gt pts - 86
# car #666: Exported 10/15 | total pts-153, gt pts - 87
# car #667: Exported 11/15 | total pts-231, gt pts - 69
# car #668: Exported 12/15 | total pts-143, gt pts - 58
# car #669: Exported 13/15 | total pts-56, gt pts - 12
# car #670: Exported 14/15 | total pts-143, gt pts - 58
# car #671: Exported 15/15 | total pts-12, gt pts - 0
# car #672: Exported 1/1 | total pts-1099, gt pts - 0
# car #673: Exported 1/1 | total pts-69, gt pts - 15
# car #674: Exported 1/9 | total pts-1638, gt pts - 1026
# car #675: Exported 2/9 | total pts-795, gt pts - 401
# car #676: Exported 3/9 | total pts-148, gt pts - 108
# car #677: Exported 4/9 | total pts-274, gt pts - 103
# car #678: Exported 5/9 | total pts-127, gt pts - 56
# car #679: Exported 6/9 | total pts-96, gt pts - 25
# car #680: Exported 7/9 | total pts-123, gt pts - 41
# car #681: Exported 8/9 | total pts-21, gt pts - 14
# car #682: Exported 9/9 | total pts-30, gt pts - 13
# car #683: Exported 1/4 | total pts-198, gt pts - 150
# car #684: Exported 2/4 | total pts-44, gt pts - 15
# car #685: Exported 3/4 | total pts-19, gt pts - 13
# car #686: Exported 4/4 | total pts-23, gt pts - 0
# car #687: Exported 1/3 | total pts-1812, gt pts - 728
# car #688: Exported 2/3 | total pts-649, gt pts - 300
# car #689: Exported 3/3 | total pts-6, gt pts - 0
# car #690: Exported 1/9 | total pts-3565, gt pts - 2276
# car #691: Exported 2/9 | total pts-2767, gt pts - 1359
# car #692: Exported 3/9 | total pts-548, gt pts - 188
# car #693: Exported 4/9 | total pts-423, gt pts - 202
# car #694: Exported 5/9 | total pts-420, gt pts - 184
# car #695: Exported 6/9 | total pts-41, gt pts - 19
# car #696: Exported 7/9 | total pts-21, gt pts - 13
# car #697: Exported 8/9 | total pts-15, gt pts - 5
# car #698: Exported 1/1 | total pts-111, gt pts - 72
# car #699: Exported 1/5 | total pts-1251, gt pts - 762
# car #700: Exported 2/5 | total pts-317, gt pts - 233
# car #701: Exported 3/5 | total pts-91, gt pts - 36
# car #702: Exported 4/5 | total pts-11, gt pts - 8
# car #703: Exported 5/5 | total pts-10, gt pts - 2
# car #704: Exported 1/9 | total pts-304, gt pts - 181
# car #705: Exported 2/9 | total pts-35, gt pts - 0
# car #706: Exported 3/9 | total pts-37, gt pts - 14
# car #707: Exported 4/9 | total pts-78, gt pts - 42
# car #708: Exported 5/9 | total pts-10, gt pts - 0
# car #709: Exported 7/9 | total pts-29, gt pts - 0
# car #710: Exported 8/9 | total pts-16, gt pts - 0
# car #711: Exported 9/9 | total pts-28, gt pts - 0
# car #712: Exported 1/1 | total pts-881, gt pts - 0
# car #713: Exported 1/7 | total pts-1706, gt pts - 865
# car #714: Exported 2/7 | total pts-661, gt pts - 291
# car #715: Exported 3/7 | total pts-181, gt pts - 85
# car #716: Exported 4/7 | total pts-436, gt pts - 62
# car #717: Exported 5/7 | total pts-311, gt pts - 149
# car #718: Exported 6/7 | total pts-183, gt pts - 77
# car #719: Exported 7/7 | total pts-8, gt pts - 0
# car #720: Exported 1/1 | total pts-178, gt pts - 25
# car #721: Exported 1/12 | total pts-1588, gt pts - 1001
# car #722: Exported 2/12 | total pts-1629, gt pts - 910
# car #723: Exported 3/12 | total pts-148, gt pts - 65
# car #724: Exported 4/12 | total pts-57, gt pts - 25
# car #725: Exported 5/12 | total pts-146, gt pts - 50
# car #726: Exported 6/12 | total pts-54, gt pts - 24
# car #727: Exported 7/12 | total pts-20, gt pts - 7
# car #728: Exported 8/12 | total pts-7, gt pts - 2
# car #729: Exported 9/12 | total pts-43, gt pts - 17
# car #730: Exported 10/12 | total pts-9, gt pts - 2
# car #731: Exported 1/5 | total pts-85, gt pts - 65
# car #732: Exported 2/5 | total pts-80, gt pts - 67
# car #733: Exported 3/5 | total pts-51, gt pts - 34
# car #734: Exported 4/5 | total pts-18, gt pts - 15
# car #735: Exported 5/5 | total pts-7, gt pts - 0
# car #736: Exported 1/14 | total pts-824, gt pts - 303
# car #737: Exported 2/14 | total pts-289, gt pts - 89
# car #738: Exported 3/14 | total pts-421, gt pts - 247
# car #739: Exported 4/14 | total pts-233, gt pts - 41
# car #740: Exported 5/14 | total pts-55, gt pts - 21
# car #741: Exported 6/14 | total pts-236, gt pts - 115
# car #742: Exported 7/14 | total pts-103, gt pts - 29
# car #743: Exported 8/14 | total pts-121, gt pts - 57
# car #744: Exported 9/14 | total pts-119, gt pts - 31
# car #745: Exported 10/14 | total pts-128, gt pts - 18
# car #746: Exported 11/14 | total pts-63, gt pts - 28
# car #747: Exported 12/14 | total pts-65, gt pts - 27
# car #748: Exported 13/14 | total pts-18, gt pts - 0
# car #749: Exported 14/14 | total pts-7, gt pts - 0
# car #750: Exported 1/6 | total pts-223, gt pts - 113
# car #751: Exported 2/6 | total pts-191, gt pts - 138
# car #752: Exported 3/6 | total pts-90, gt pts - 31
# car #753: Exported 4/6 | total pts-15, gt pts - 4
# car #754: Exported 1/10 | total pts-842, gt pts - 577
# car #755: Exported 2/10 | total pts-251, gt pts - 96
# car #756: Exported 3/10 | total pts-201, gt pts - 125
# car #757: Exported 4/10 | total pts-39, gt pts - 22
# car #758: Exported 5/10 | total pts-129, gt pts - 60
# car #759: Exported 6/10 | total pts-142, gt pts - 52
# car #760: Exported 7/10 | total pts-14, gt pts - 0
# car #761: Exported 8/10 | total pts-37, gt pts - 3
# car #762: Exported 9/10 | total pts-18, gt pts - 0
# car #763: Exported 10/10 | total pts-29, gt pts - 0
# car #764: Exported 1/6 | total pts-235, gt pts - 174
# car #765: Exported 2/6 | total pts-38, gt pts - 6
# car #766: Exported 3/6 | total pts-85, gt pts - 23
# car #767: Exported 4/6 | total pts-66, gt pts - 14
# car #768: Exported 5/6 | total pts-24, gt pts - 7
# car #769: Exported 1/10 | total pts-3461, gt pts - 148
# car #770: Exported 2/10 | total pts-347, gt pts - 217
# car #771: Exported 3/10 | total pts-898, gt pts - 489
# car #772: Exported 4/10 | total pts-193, gt pts - 144
# car #773: Exported 5/10 | total pts-215, gt pts - 115
# car #774: Exported 6/10 | total pts-287, gt pts - 137
# car #775: Exported 7/10 | total pts-113, gt pts - 37
# car #776: Exported 8/10 | total pts-14, gt pts - 1
# car #777: Exported 9/10 | total pts-10, gt pts - 0
# car #778: Exported 10/10 | total pts-18, gt pts - 0
# car #779: Exported 1/4 | total pts-105, gt pts - 80
# car #780: Exported 2/4 | total pts-89, gt pts - 50
# car #781: Exported 3/4 | total pts-23, gt pts - 7
# car #782: Exported 4/4 | total pts-5, gt pts - 1
# car #783: Exported 1/6 | total pts-92, gt pts - 0
# car #784: Exported 2/6 | total pts-169, gt pts - 0
# car #785: Exported 3/6 | total pts-35, gt pts - 0
# car #786: Exported 4/6 | total pts-22, gt pts - 0
# car #787: Exported 1/4 | total pts-188, gt pts - 70
# car #788: Exported 2/4 | total pts-156, gt pts - 26
# car #789: Exported 3/4 | total pts-175, gt pts - 107
# car #790: Exported 4/4 | total pts-58, gt pts - 49
# car #791: Exported 1/12 | total pts-3720, gt pts - 2013
# car #792: Exported 2/12 | total pts-1294, gt pts - 396
# car #793: Exported 3/12 | total pts-367, gt pts - 114
# car #794: Exported 4/12 | total pts-671, gt pts - 341
# car #795: Exported 5/12 | total pts-397, gt pts - 222
# car #796: Exported 6/12 | total pts-357, gt pts - 199
# car #797: Exported 7/12 | total pts-326, gt pts - 203
# car #798: Exported 8/12 | total pts-604, gt pts - 237
# car #799: Exported 9/12 | total pts-289, gt pts - 78
# car #800: Exported 10/12 | total pts-72, gt pts - 10
# car #801: Exported 11/12 | total pts-98, gt pts - 43
# car #802: Exported 12/12 | total pts-17, gt pts - 15
# car #803: Exported 1/2 | total pts-184, gt pts - 112
# car #804: Exported 2/2 | total pts-17, gt pts - 10
# car #805: Exported 1/7 | total pts-519, gt pts - 230
# car #806: Exported 2/7 | total pts-540, gt pts - 335
# car #807: Exported 3/7 | total pts-90, gt pts - 17
# car #808: Exported 4/7 | total pts-74, gt pts - 27
# car #809: Exported 5/7 | total pts-15, gt pts - 12
# car #810: Exported 6/7 | total pts-10, gt pts - 0
# car #811: Exported 7/7 | total pts-5, gt pts - 1
# car #812: Exported 1/9 | total pts-2676, gt pts - 1596
# car #813: Exported 2/9 | total pts-1455, gt pts - 715
# car #814: Exported 3/9 | total pts-1186, gt pts - 600
# car #815: Exported 4/9 | total pts-514, gt pts - 317
# car #816: Exported 5/9 | total pts-207, gt pts - 116
# car #817: Exported 6/9 | total pts-270, gt pts - 124
# car #818: Exported 7/9 | total pts-69, gt pts - 56
# car #819: Exported 8/9 | total pts-31, gt pts - 15
# car #820: Exported 9/9 | total pts-17, gt pts - 5
# car #821: Exported 1/11 | total pts-1690, gt pts - 833
# car #822: Exported 2/11 | total pts-3479, gt pts - 1699
# car #823: Exported 3/11 | total pts-1599, gt pts - 622
# car #824: Exported 4/11 | total pts-1167, gt pts - 650
# car #825: Exported 5/11 | total pts-296, gt pts - 201
# car #826: Exported 6/11 | total pts-94, gt pts - 36
# car #827: Exported 7/11 | total pts-127, gt pts - 60
# car #828: Exported 8/11 | total pts-7, gt pts - 0
# car #829: Exported 9/11 | total pts-61, gt pts - 14
# car #830: Exported 10/11 | total pts-20, gt pts - 0
# car #831: Exported 1/4 | total pts-600, gt pts - 162
# car #832: Exported 2/4 | total pts-75, gt pts - 21
# car #833: Exported 3/4 | total pts-43, gt pts - 8
# car #834: Exported 4/4 | total pts-23, gt pts - 3
# car #835: Exported 1/5 | total pts-557, gt pts - 194
# car #836: Exported 2/5 | total pts-118, gt pts - 87
# car #837: Exported 3/5 | total pts-38, gt pts - 21
# car #838: Exported 4/5 | total pts-16, gt pts - 10
# car #839: Exported 5/5 | total pts-8, gt pts - 3
# car #840: Exported 1/8 | total pts-2084, gt pts - 954
# car #841: Exported 2/8 | total pts-986, gt pts - 612
# car #842: Exported 3/8 | total pts-514, gt pts - 279
# car #843: Exported 4/8 | total pts-141, gt pts - 51
# car #844: Exported 5/8 | total pts-95, gt pts - 70
# car #845: Exported 6/8 | total pts-48, gt pts - 0
# car #846: Exported 7/8 | total pts-24, gt pts - 5
# car #847: Exported 8/8 | total pts-32, gt pts - 27
# car #848: Exported 1/2 | total pts-79, gt pts - 0
# car #849: Exported 2/2 | total pts-124, gt pts - 67
# car #850: Exported 1/11 | total pts-1428, gt pts - 454
# car #851: Exported 2/11 | total pts-2303, gt pts - 1319
# car #852: Exported 3/11 | total pts-533, gt pts - 280
# car #853: Exported 4/11 | total pts-574, gt pts - 345
# car #854: Exported 5/11 | total pts-251, gt pts - 129
# car #855: Exported 6/11 | total pts-169, gt pts - 86
# car #856: Exported 7/11 | total pts-61, gt pts - 40
# car #857: Exported 8/11 | total pts-53, gt pts - 0
# car #858: Exported 9/11 | total pts-27, gt pts - 14
# car #859: Exported 10/11 | total pts-21, gt pts - 0
# car #860: Exported 11/11 | total pts-20, gt pts - 0
# car #861: Exported 1/1 | total pts-362, gt pts - 250
# car #862: Exported 1/4 | total pts-71, gt pts - 0
# car #863: Exported 2/4 | total pts-38, gt pts - 10
# car #864: Exported 3/4 | total pts-42, gt pts - 0
# car #865: Exported 4/4 | total pts-9, gt pts - 8
# car #866: Exported 1/10 | total pts-2472, gt pts - 733
# car #867: Exported 2/10 | total pts-2127, gt pts - 1122
# car #868: Exported 3/10 | total pts-1259, gt pts - 697
# car #869: Exported 4/10 | total pts-769, gt pts - 329
# car #870: Exported 5/10 | total pts-451, gt pts - 156
# car #871: Exported 6/10 | total pts-254, gt pts - 121
# car #872: Exported 7/10 | total pts-262, gt pts - 80
# car #873: Exported 8/10 | total pts-142, gt pts - 35
# car #874: Exported 9/10 | total pts-91, gt pts - 10
# car #875: Exported 10/10 | total pts-65, gt pts - 17
# car #876: Exported 1/3 | total pts-1839, gt pts - 413
# car #877: Exported 2/3 | total pts-730, gt pts - 25
# car #878: Exported 3/3 | total pts-63, gt pts - 32
# car #879: Exported 1/6 | total pts-1774, gt pts - 366
# car #880: Exported 2/6 | total pts-2563, gt pts - 1541
# car #881: Exported 3/6 | total pts-74, gt pts - 37
# car #882: Exported 4/6 | total pts-45, gt pts - 15
# car #883: Exported 5/6 | total pts-17, gt pts - 1
# car #884: Exported 6/6 | total pts-53, gt pts - 32
# car #885: Exported 1/7 | total pts-75, gt pts - 18
# car #886: Exported 2/7 | total pts-95, gt pts - 30
# car #887: Exported 3/7 | total pts-48, gt pts - 27
# car #888: Exported 4/7 | total pts-75, gt pts - 46
# car #889: Exported 5/7 | total pts-14, gt pts - 7
# car #890: Exported 6/7 | total pts-7, gt pts - 0
# car #891: Exported 7/7 | total pts-16, gt pts - 0
# car #892: Exported 1/7 | total pts-3137, gt pts - 1831
# car #893: Exported 2/7 | total pts-1109, gt pts - 764
# car #894: Exported 3/7 | total pts-650, gt pts - 390
# car #895: Exported 4/7 | total pts-189, gt pts - 142
# car #896: Exported 5/7 | total pts-90, gt pts - 39
# car #897: Exported 6/7 | total pts-47, gt pts - 27
# car #898: Exported 7/7 | total pts-83, gt pts - 11
# car #899: Exported 1/10 | total pts-2557, gt pts - 1149
# car #900: Exported 2/10 | total pts-1296, gt pts - 809
# car #901: Exported 3/10 | total pts-173, gt pts - 110
# car #902: Exported 4/10 | total pts-65, gt pts - 20
# car #903: Exported 5/10 | total pts-131, gt pts - 72
# car #904: Exported 6/10 | total pts-57, gt pts - 17
# car #905: Exported 7/10 | total pts-112, gt pts - 29
# car #906: Exported 8/10 | total pts-43, gt pts - 4
# car #907: Exported 9/10 | total pts-41, gt pts - 11
# car #908: Exported 10/10 | total pts-55, gt pts - 4
# car #909: Exported 1/7 | total pts-1611, gt pts - 716
# car #910: Exported 2/7 | total pts-453, gt pts - 241
# car #911: Exported 3/7 | total pts-121, gt pts - 90
# car #912: Exported 4/7 | total pts-81, gt pts - 47
# car #913: Exported 5/7 | total pts-6, gt pts - 0
# car #914: Exported 6/7 | total pts-8, gt pts - 5
# car #915: Exported 1/1 | total pts-914, gt pts - 464
# car #916: Exported 1/9 | total pts-555, gt pts - 318
# car #917: Exported 2/9 | total pts-786, gt pts - 486
# car #918: Exported 3/9 | total pts-445, gt pts - 231
# car #919: Exported 4/9 | total pts-584, gt pts - 385
# car #920: Exported 5/9 | total pts-178, gt pts - 78
# car #921: Exported 6/9 | total pts-159, gt pts - 79
# ...
# car #9864: Exported 5/5 | total pts-25, gt pts - 13
# car #9865: Exported 1/6 | total pts-1570, gt pts - 0
# car #9866: Exported 2/6 | total pts-1132, gt pts - 323
# car #9867: Exported 3/6 | total pts-168, gt pts - 72
# car #9868: Exported 4/6 | total pts-69, gt pts - 43
# car #9869: Exported 5/6 | total pts-44, gt pts - 25
# car #9870: Exported 6/6 | total pts-13, gt pts - 5
# car #9871: Exported 1/2 | total pts-13, gt pts - 13
# car #9872: Exported 2/2 | total pts-5, gt pts - 3
# car #9873: Exported 1/3 | total pts-113, gt pts - 91
# car #9874: Exported 2/3 | total pts-17, gt pts - 6
# car #9875: Exported 3/3 | total pts-8, gt pts - 0
# car #9876: Exported 1/5 | total pts-2709, gt pts - 1348
# car #9877: Exported 2/5 | total pts-260, gt pts - 184
# car #9878: Exported 3/5 | total pts-95, gt pts - 42
# car #9879: Exported 4/5 | total pts-50, gt pts - 16
# car #9880: Exported 5/5 | total pts-13, gt pts - 6
# car #9881: Exported 1/14 | total pts-1088, gt pts - 677
# car #9882: Exported 2/14 | total pts-1423, gt pts - 598
# car #9883: Exported 3/14 | total pts-1710, gt pts - 588
# car #9884: Exported 4/14 | total pts-1254, gt pts - 738
# car #9885: Exported 5/14 | total pts-299, gt pts - 166
# car #9886: Exported 6/14 | total pts-233, gt pts - 130
# car #9887: Exported 7/14 | total pts-291, gt pts - 114
# car #9888: Exported 8/14 | total pts-234, gt pts - 7
# car #9889: Exported 9/14 | total pts-71, gt pts - 42
# car #9890: Exported 10/14 | total pts-103, gt pts - 14
# car #9891: Exported 11/14 | total pts-100, gt pts - 14
# car #9892: Exported 12/14 | total pts-11, gt pts - 0
# car #9893: Exported 1/7 | total pts-1999, gt pts - 760
# car #9894: Exported 2/7 | total pts-1331, gt pts - 640
# car #9895: Exported 3/7 | total pts-1050, gt pts - 449
# car #9896: Exported 4/7 | total pts-44, gt pts - 20
# car #9897: Exported 5/7 | total pts-53, gt pts - 15
# car #9898: Exported 6/7 | total pts-20, gt pts - 1
# car #9899: Exported 7/7 | total pts-20, gt pts - 3
# car #9900: Exported 1/8 | total pts-92, gt pts - 18
# car #9901: Exported 2/8 | total pts-126, gt pts - 73
# car #9902: Exported 3/8 | total pts-49, gt pts - 0
# car #9903: Exported 4/8 | total pts-61, gt pts - 0
# car #9904: Exported 5/8 | total pts-28, gt pts - 0
# car #9905: Exported 6/8 | total pts-15, gt pts - 0
# car #9906: Exported 7/8 | total pts-9, gt pts - 0
# car #9907: Exported 8/8 | total pts-13, gt pts - 0
# car #9908: Exported 1/8 | total pts-2050, gt pts - 991
# car #9909: Exported 2/8 | total pts-333, gt pts - 177
# car #9910: Exported 3/8 | total pts-234, gt pts - 114
# car #9911: Exported 4/8 | total pts-250, gt pts - 54
# car #9912: Exported 5/8 | total pts-205, gt pts - 110
# car #9913: Exported 6/8 | total pts-139, gt pts - 81
# car #9914: Exported 7/8 | total pts-46, gt pts - 4
# car #9915: Exported 8/8 | total pts-60, gt pts - 10
# car #9916: Exported 1/16 | total pts-2151, gt pts - 870
# car #9917: Exported 2/16 | total pts-1366, gt pts - 898
# car #9918: Exported 3/16 | total pts-719, gt pts - 390
# car #9919: Exported 4/16 | total pts-657, gt pts - 389
# car #9920: Exported 5/16 | total pts-769, gt pts - 222
# car #9921: Exported 6/16 | total pts-382, gt pts - 223
# car #9922: Exported 7/16 | total pts-459, gt pts - 192
# car #9923: Exported 8/16 | total pts-146, gt pts - 45
# car #9924: Exported 9/16 | total pts-143, gt pts - 55
# car #9925: Exported 10/16 | total pts-80, gt pts - 53
# car #9926: Exported 11/16 | total pts-54, gt pts - 22
# car #9927: Exported 12/16 | total pts-59, gt pts - 21
# car #9928: Exported 14/16 | total pts-5, gt pts - 0
# car #9929: Exported 1/8 | total pts-3400, gt pts - 2064
# car #9930: Exported 2/8 | total pts-1682, gt pts - 1135
# car #9931: Exported 3/8 | total pts-1424, gt pts - 906
# car #9932: Exported 4/8 | total pts-844, gt pts - 583
# car #9933: Exported 5/8 | total pts-433, gt pts - 221
# car #9934: Exported 6/8 | total pts-297, gt pts - 145
# car #9935: Exported 7/8 | total pts-16, gt pts - 8
# car #9936: Exported 8/8 | total pts-17, gt pts - 7
# car #9937: Exported 1/4 | total pts-3432, gt pts - 1724
# car #9938: Exported 2/4 | total pts-197, gt pts - 86
# car #9939: Exported 3/4 | total pts-39, gt pts - 0
# car #9940: Exported 4/4 | total pts-11, gt pts - 9
# car #9941: Exported 1/11 | total pts-367, gt pts - 201
# car #9942: Exported 2/11 | total pts-396, gt pts - 171
# car #9943: Exported 3/11 | total pts-253, gt pts - 168
# car #9944: Exported 4/11 | total pts-119, gt pts - 77
# car #9945: Exported 5/11 | total pts-82, gt pts - 61
# car #9946: Exported 6/11 | total pts-14, gt pts - 12
# car #9947: Exported 8/11 | total pts-61, gt pts - 28
# car #9948: Exported 10/11 | total pts-16, gt pts - 1
# car #9949: Exported 1/4 | total pts-2637, gt pts - 1652
# car #9950: Exported 2/4 | total pts-22, gt pts - 19
# car #9951: Exported 3/4 | total pts-25, gt pts - 0
# car #9952: Exported 4/4 | total pts-6, gt pts - 0
# car #9953: Exported 1/7 | total pts-887, gt pts - 440
# car #9954: Exported 2/7 | total pts-826, gt pts - 505
# car #9955: Exported 3/7 | total pts-580, gt pts - 352
# car #9956: Exported 4/7 | total pts-77, gt pts - 25
# car #9957: Exported 5/7 | total pts-33, gt pts - 17
# car #9958: Exported 6/7 | total pts-13, gt pts - 4
# car #9959: Exported 7/7 | total pts-17, gt pts - 3
# car #9960: Exported 1/3 | total pts-243, gt pts - 80
# car #9961: Exported 2/3 | total pts-26, gt pts - 16
# car #9962: Exported 3/3 | total pts-30, gt pts - 23
# car #9963: Exported 1/2 | total pts-2369, gt pts - 725
# car #9964: Exported 2/2 | total pts-310, gt pts - 238
# car #9965: Exported 1/5 | total pts-90, gt pts - 39
# car #9966: Exported 2/5 | total pts-47, gt pts - 30
# car #9967: Exported 4/5 | total pts-7, gt pts - 0
# car #9968: Exported 1/1 | total pts-23, gt pts - 11
# car #9969: Exported 1/3 | total pts-176, gt pts - 123
# car #9970: Exported 2/3 | total pts-6, gt pts - 0
# car #9971: Exported 3/3 | total pts-74, gt pts - 41
# car #9972: Exported 1/16 | total pts-1108, gt pts - 565
# car #9973: Exported 2/16 | total pts-322, gt pts - 134
# car #9974: Exported 3/16 | total pts-229, gt pts - 0
# car #9975: Exported 4/16 | total pts-174, gt pts - 67
# car #9976: Exported 5/16 | total pts-145, gt pts - 94
# car #9977: Exported 6/16 | total pts-106, gt pts - 64
# car #9978: Exported 7/16 | total pts-48, gt pts - 0
# car #9979: Exported 8/16 | total pts-37, gt pts - 0
# car #9980: Exported 9/16 | total pts-33, gt pts - 0
# car #9981: Exported 10/16 | total pts-39, gt pts - 0
# car #9982: Exported 11/16 | total pts-108, gt pts - 43
# car #9983: Exported 12/16 | total pts-35, gt pts - 0
# car #9984: Exported 13/16 | total pts-46, gt pts - 17
# car #9985: Exported 14/16 | total pts-12, gt pts - 0
# car #9986: Exported 15/16 | total pts-17, gt pts - 0
# car #9987: Exported 16/16 | total pts-22, gt pts - 3
# car #9988: Exported 1/1 | total pts-1787, gt pts - 1044
# car #9989: Exported 1/1 | total pts-71, gt pts - 36
# car #9990: Exported 1/5 | total pts-1333, gt pts - 722
# car #9991: Exported 2/5 | total pts-1199, gt pts - 442
# car #9992: Exported 3/5 | total pts-146, gt pts - 9
# car #9993: Exported 4/5 | total pts-32, gt pts - 0
# car #9994: Exported 5/5 | total pts-6, gt pts - 0
# car #9995: Exported 1/7 | total pts-1607, gt pts - 920
# car #9996: Exported 2/7 | total pts-358, gt pts - 174
# car #9997: Exported 3/7 | total pts-26, gt pts - 11
# car #9998: Exported 4/7 | total pts-16, gt pts - 0
# car #9999: Exported 5/7 | total pts-100, gt pts - 59
# car #10000: Exported 6/7 | total pts-6, gt pts - 0
# car #10001: Exported 7/7 | total pts-7, gt pts - 0
# car #10002: Exported 1/2 | total pts-1819, gt pts - 735
# car #10003: Exported 2/2 | total pts-209, gt pts - 104
# car #10004: Exported 1/3 | total pts-197, gt pts - 155
# car #10005: Exported 2/3 | total pts-51, gt pts - 0
# car #10006: Exported 1/11 | total pts-677, gt pts - 339
# car #10007: Exported 2/11 | total pts-498, gt pts - 389
# car #10008: Exported 3/11 | total pts-120, gt pts - 40
# car #10009: Exported 4/11 | total pts-306, gt pts - 79
# car #10010: Exported 5/11 | total pts-284, gt pts - 156
# car #10011: Exported 6/11 | total pts-189, gt pts - 64
# car #10012: Exported 7/11 | total pts-228, gt pts - 144
# car #10013: Exported 8/11 | total pts-50, gt pts - 15
# car #10014: Exported 9/11 | total pts-36, gt pts - 9
# car #10015: Exported 10/11 | total pts-68, gt pts - 40
# car #10016: Exported 11/11 | total pts-7, gt pts - 4
# car #10017: Exported 1/2 | total pts-2867, gt pts - 1179
# car #10018: Exported 2/2 | total pts-33, gt pts - 21
# car #10019: Exported 1/6 | total pts-4330, gt pts - 2868
# car #10020: Exported 2/6 | total pts-2572, gt pts - 1409
# car #10021: Exported 3/6 | total pts-635, gt pts - 331
# car #10022: Exported 4/6 | total pts-235, gt pts - 79
# car #10023: Exported 5/6 | total pts-70, gt pts - 36
# car #10024: Exported 6/6 | total pts-42, gt pts - 26
# car #10025: Exported 1/13 | total pts-1013, gt pts - 467
# car #10026: Exported 2/13 | total pts-158, gt pts - 95
# car #10027: Exported 3/13 | total pts-220, gt pts - 138
# car #10028: Exported 4/13 | total pts-98, gt pts - 39
# car #10029: Exported 5/13 | total pts-61, gt pts - 35
# car #10030: Exported 6/13 | total pts-76, gt pts - 20
# car #10031: Exported 7/13 | total pts-75, gt pts - 44
# car #10032: Exported 8/13 | total pts-29, gt pts - 19
# car #10033: Exported 9/13 | total pts-75, gt pts - 44
# car #10034: Exported 10/13 | total pts-45, gt pts - 16
# car #10035: Exported 11/13 | total pts-28, gt pts - 23
# car #10036: Exported 12/13 | total pts-19, gt pts - 4
# car #10037: Exported 13/13 | total pts-6, gt pts - 2
# car #10038: Exported 1/9 | total pts-2752, gt pts - 1587
# car #10039: Exported 2/9 | total pts-1024, gt pts - 374
# car #10040: Exported 3/9 | total pts-258, gt pts - 99
# car #10041: Exported 4/9 | total pts-335, gt pts - 128
# car #10042: Exported 5/9 | total pts-68, gt pts - 33
# car #10043: Exported 6/9 | total pts-24, gt pts - 0
# car #10044: Exported 7/9 | total pts-18, gt pts - 0
# car #10045: Exported 8/9 | total pts-27, gt pts - 2
# car #10046: Exported 9/9 | total pts-27, gt pts - 14
# car #10047: Exported 1/6 | total pts-933, gt pts - 352
# car #10048: Exported 2/6 | total pts-809, gt pts - 527
# car #10049: Exported 3/6 | total pts-280, gt pts - 167
# car #10050: Exported 4/6 | total pts-44, gt pts - 13
# car #10051: Exported 5/6 | total pts-7, gt pts - 0
# car #10052: Exported 1/11 | total pts-364, gt pts - 247
# car #10053: Exported 2/11 | total pts-123, gt pts - 69
# car #10054: Exported 3/11 | total pts-6, gt pts - 0
# car #10055: Exported 4/11 | total pts-48, gt pts - 11
# car #10056: Exported 5/11 | total pts-77, gt pts - 25
# car #10057: Exported 6/11 | total pts-86, gt pts - 51
# car #10058: Exported 7/11 | total pts-8, gt pts - 0
# car #10059: Exported 9/11 | total pts-6, gt pts - 0
# car #10060: Exported 10/11 | total pts-13, gt pts - 0
# car #10061: Exported 11/11 | total pts-5, gt pts - 0
# car #10062: Exported 1/15 | total pts-1788, gt pts - 731
# car #10063: Exported 2/15 | total pts-1835, gt pts - 1117
# car #10064: Exported 3/15 | total pts-965, gt pts - 610
# car #10065: Exported 4/15 | total pts-927, gt pts - 235
# car #10066: Exported 5/15 | total pts-271, gt pts - 176
# car #10067: Exported 6/15 | total pts-453, gt pts - 195
# car #10068: Exported 7/15 | total pts-398, gt pts - 184
# car #10069: Exported 8/15 | total pts-159, gt pts - 82
# car #10070: Exported 9/15 | total pts-251, gt pts - 94
# car #10071: Exported 10/15 | total pts-107, gt pts - 47
# car #10072: Exported 11/15 | total pts-87, gt pts - 39
# car #10073: Exported 12/15 | total pts-14, gt pts - 0
# car #10074: Exported 13/15 | total pts-7, gt pts - 0
# car #10075: Exported 14/15 | total pts-5, gt pts - 0
# car #10076: Exported 1/13 | total pts-1751, gt pts - 923
# car #10077: Exported 2/13 | total pts-861, gt pts - 394
# car #10078: Exported 3/13 | total pts-1482, gt pts - 534
# car #10079: Exported 4/13 | total pts-717, gt pts - 404
# car #10080: Exported 5/13 | total pts-848, gt pts - 416
# car #10081: Exported 6/13 | total pts-1058, gt pts - 306
# car #10082: Exported 7/13 | total pts-487, gt pts - 126
# car #10083: Exported 8/13 | total pts-258, gt pts - 82
# car #10084: Exported 9/13 | total pts-129, gt pts - 31
# car #10085: Exported 10/13 | total pts-200, gt pts - 130
# car #10086: Exported 11/13 | total pts-132, gt pts - 18
# car #10087: Exported 12/13 | total pts-192, gt pts - 90
# car #10088: Exported 13/13 | total pts-39, gt pts - 22
# car #10089: Exported 1/5 | total pts-739, gt pts - 0
# car #10090: Exported 2/5 | total pts-318, gt pts - 204
# car #10091: Exported 3/5 | total pts-224, gt pts - 151
# car #10092: Exported 4/5 | total pts-27, gt pts - 8
# car #10093: Exported 5/5 | total pts-32, gt pts - 0
# car #10094: Exported 1/9 | total pts-2491, gt pts - 1236
# car #10095: Exported 2/9 | total pts-1909, gt pts - 820
# car #10096: Exported 3/9 | total pts-319, gt pts - 186
# car #10097: Exported 4/9 | total pts-260, gt pts - 128
# car #10098: Exported 5/9 | total pts-38, gt pts - 7
# car #10099: Exported 6/9 | total pts-44, gt pts - 23
# car #10100: Exported 7/9 | total pts-7, gt pts - 0
# car #10101: Exported 8/9 | total pts-7, gt pts - 0
# car #10102: Exported 9/9 | total pts-12, gt pts - 0
# car #10103: Exported 1/3 | total pts-1927, gt pts - 740
# car #10104: Exported 2/3 | total pts-1260, gt pts - 814
# car #10105: Exported 3/3 | total pts-143, gt pts - 63
# car #10106: Exported 1/9 | total pts-1370, gt pts - 875
# car #10107: Exported 2/9 | total pts-885, gt pts - 476
# car #10108: Exported 3/9 | total pts-450, gt pts - 256
# car #10109: Exported 4/9 | total pts-413, gt pts - 288
# car #10110: Exported 5/9 | total pts-261, gt pts - 161
# car #10111: Exported 6/9 | total pts-95, gt pts - 22
# car #10112: Exported 7/9 | total pts-56, gt pts - 16
# car #10113: Exported 8/9 | total pts-28, gt pts - 11
# car #10114: Exported 1/3 | total pts-265, gt pts - 105
# car #10115: Exported 2/3 | total pts-128, gt pts - 105
# car #10116: Exported 1/2 | total pts-1779, gt pts - 1037
# car #10117: Exported 2/2 | total pts-259, gt pts - 75
# car #10118: Exported 1/14 | total pts-1472, gt pts - 1019
# car #10119: Exported 2/14 | total pts-947, gt pts - 602
# car #10120: Exported 3/14 | total pts-1090, gt pts - 660
# car #10121: Exported 4/14 | total pts-358, gt pts - 226
# car #10122: Exported 5/14 | total pts-245, gt pts - 164
# car #10123: Exported 6/14 | total pts-137, gt pts - 46
# car #10124: Exported 7/14 | total pts-75, gt pts - 33
# car #10125: Exported 8/14 | total pts-38, gt pts - 34
# car #10126: Exported 9/14 | total pts-25, gt pts - 18
# car #10127: Exported 10/14 | total pts-73, gt pts - 15
# car #10128: Exported 11/14 | total pts-11, gt pts - 4
# car #10129: Exported 12/14 | total pts-18, gt pts - 7
# car #10130: Exported 13/14 | total pts-17, gt pts - 15
# car #10131: Exported 14/14 | total pts-16, gt pts - 13
# car #10132: Exported 1/2 | total pts-904, gt pts - 549
# car #10133: Exported 2/2 | total pts-18, gt pts - 6
# car #10134: Exported 1/7 | total pts-1514, gt pts - 392
# car #10135: Exported 2/7 | total pts-327, gt pts - 225
# car #10136: Exported 3/7 | total pts-861, gt pts - 531
# car #10137: Exported 4/7 | total pts-487, gt pts - 320
# car #10138: Exported 5/7 | total pts-209, gt pts - 81
# car #10139: Exported 6/7 | total pts-153, gt pts - 92
# car #10140: Exported 7/7 | total pts-75, gt pts - 30
# car #10141: Exported 1/1 | total pts-190, gt pts - 98
# car #10142: Exported 1/11 | total pts-2337, gt pts - 1261
# car #10143: Exported 2/11 | total pts-1837, gt pts - 1027
# car #10144: Exported 3/11 | total pts-601, gt pts - 344
# car #10145: Exported 4/11 | total pts-1045, gt pts - 598
# car #10146: Exported 5/11 | total pts-718, gt pts - 492
# car #10147: Exported 6/11 | total pts-390, gt pts - 203
# car #10148: Exported 7/11 | total pts-291, gt pts - 205
# car #10149: Exported 8/11 | total pts-221, gt pts - 154
# car #10150: Exported 9/11 | total pts-171, gt pts - 43
# car #10151: Exported 10/11 | total pts-169, gt pts - 124
# car #10152: Exported 11/11 | total pts-106, gt pts - 34
# car #10153: Exported 1/1 | total pts-201, gt pts - 136
# car #10154: Exported 1/13 | total pts-1926, gt pts - 1390
# car #10155: Exported 2/13 | total pts-1330, gt pts - 893
# car #10156: Exported 3/13 | total pts-577, gt pts - 337
# car #10157: Exported 4/13 | total pts-469, gt pts - 170
# car #10158: Exported 5/13 | total pts-135, gt pts - 85
# car #10159: Exported 6/13 | total pts-35, gt pts - 2
