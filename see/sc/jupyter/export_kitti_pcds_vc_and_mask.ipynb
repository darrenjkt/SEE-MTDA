# %%
import sys
sys.path.append('/SEE-MTDA/see')
from sc.mesher.mesher import Mesher
import numpy as np
import os
import glob
import pickle
from pathlib import Path
from sc.datasets.shared_utils import *
import open3d as o3d
from easydict import EasyDict
import yaml
from PIL import Image
from tqdm import tqdm

def cfg_from_yaml_file(cfg_file):
    cfg = EasyDict()
    print("\n----- Cfgs -----")
    with open(cfg_file, 'r') as f:
        yaml_config = yaml.safe_load(f)
        print(yaml.dump(yaml_config))

    cfg.update(EasyDict(yaml_config))

    return cfg

cfg_file = '/SEE-MTDA/see/sc/cfgs/KIT-LSEG-EXT_R6D-E3_SURFACEKNN_min10pts.yaml'
cfg = cfg_from_yaml_file(cfg_file)
mesher = Mesher(cfg=cfg, cfg_path=cfg_file)
# Out:
# ----- Cfgs -----
# DATASET:
#   CAMERA_CHANNELS:
#   - image_2
#   CLASSES:
#   - Car
#   DET2D_MASK: true
#   DET2D_MODEL: yolox
#   NAME: kitti
#   POINT_CLOUD_RANGE:
#   - -70
#   - -70
#   - -2
#   - 70
#   - 70
#   - 4
# DATA_PATH: /SEE-MTDA/data/kitti
# MESHER:
#   EXPORT_NAME: R6D_E3_surfaceknn_k30
#   MIN_LIDAR_PTS_TO_MESH: 10
#   NAME: ext_mesh
#   REPLACE_OBJECT_WITH_MESH:
#     POINT_DISTANCE_THRESH: 0.1
#
# Loading masks...
# loading annotations into memory...
# Done (t=0.28s)
# creating index...
# index created!
# KittiObjects initialised!
#
# Mesher Initialised!

# %% [markdown]
# # Export points in GT box
#
# This is to assess shape completion with perfect data

# %%
mesher.min_lidar_pts_to_mesh = 5
save_dir = Path(f'/SEE-MTDA/data/shapenet/VC/kitti_vc/test')
# mesher.data_obj.nsweeps = 1

car_count = 0
max_num_cars = 5000

for sample_idx in tqdm(range(mesher.data_obj.__len__()), total=mesher.data_obj.__len__()):
    pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx)

    for object_id in range(len(pcd_gtboxes['gt_boxes'])):    

        object_pcd = pcd_gtboxes['pcd'].crop(pcd_gtboxes['gt_boxes'][object_id])

        if len(object_pcd.points) < mesher.min_lidar_pts_to_mesh:
            continue

        box_pts = np.asarray(pcd_gtboxes['gt_boxes'][object_id].get_box_points())
        label = pcd_gtboxes['xyzlwhry_gt_boxes'][object_id][:7]

        # Save object
        # Save partial, complete, labels
        partial_dir = save_dir / 'partial'
        partial_dir.mkdir(exist_ok=True, parents=True)

        label_dir = save_dir / 'label' 
        label_dir.mkdir(exist_ok=True, parents=True)

        fname =  f'frame-{sample_idx}_car-{object_id:03d}'    
        o3d.io.write_point_cloud(str(partial_dir / f'{fname}.pcd'), object_pcd)
        with open(str(label_dir / f'{fname}.pkl'), 'wb') as f:
            label = {'bbox_pts': box_pts, 
                     'gtbox': label,
                     'pc_id': fname}
            pickle.dump(label, f)
        car_count += 1
        if car_count >= max_num_cars:
            break
            
    if car_count >= max_num_cars:
        break
        
file_glob = glob.glob(f'{str(label_dir)}/*')
file_list = [fname.split('/')[-1].split('.')[0] for fname in file_glob]
with open(f'{save_dir}/file_list.txt','w') as f:
    f.writelines('\n'.join(file_list))
        
#         if mesher.data_obj.dataset_name == 'nuscenes':
#             fname = f'nsweeps-{mesher.data_obj.nsweeps}_frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'
#         else:
#             fname = f'frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'

#         car_dir = Path(f'{mesher.data_obj.root_dir}/exported/cars')
#         car_dir.mkdir(parents=True, exist_ok=True)
#         o3d.io.write_point_cloud(str(car_dir / f'{fname}.pcd'), object_pcd)

#         box_dir = Path(f'{mesher.data_obj.root_dir}/exported/bboxes')    
#         box_dir.mkdir(parents=True, exist_ok=True)
#         np.savetxt(str(box_dir / f'{fname}.txt'), box_pts, delimiter=' ')

#         print(f"frame-{sample_idx}: Exported {object_id}/{len(pcd_gtboxes['gt_boxes'])} | car_pts-{len(object_pcd.points)}")
# Out:
#  19%|█▉        | 1413/7481 [02:45<11:48,  8.56it/s]

# %%
root_dir = Path('/SEE-MTDA/data/nuscenes/custom_t4025-v3980')
ftrain = open(str(root_dir / 'custom_train_split.txt'), 'r').read()            
scene_names = ftrain.split('\n')
print('Scene names len = ', len(scene_names))

fval = open(str(root_dir / 'custom_val_split.txt'), 'r').read()
# scene_names = fval.split('\n')
scene_names.extend(fval.split('\n'))
print('Scene names len = ', len(scene_names))
# Out:
# Scene names len =  100
# Scene names len =  199

# %%
import glob

train_paths = glob.glob('/SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/*')
train = [ids.split('/')[-1] for ids in train_paths]
val = glob.glob('/SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/test/complete/*')
val = [ids.split('/')[-1] for ids in val]
intersect = list(set(train).intersection(set(val)))
len(intersect)
# Out:
# 273

# %%
import shutil

for i in intersect:
    intersect_idx = train.index(i)
    path = train_paths[intersect_idx]
    shutil.rmtree(path)
    print(f'Removed {path}')
# Out:
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/eb1bd7389854311c14f284ebe538e531
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/aec393b8c73d3a8ae4bee94a37836d67
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a5b7cc1a5ab2828b28b0b7b876595fb8
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2254e63f695a1cccbbae182929bb7dd
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/63316c4cff51de417fb21fb4ec0d8d1b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/43be650d6fd7468fd9952f9e00a53f0e
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/19042f5a90290859441c11ab4641b257
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f3205edd456cf36feabc798aaf5f039f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/bbc2f2ffeec425a38eac574d099cd5d2
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/91be65c386bafdd21aee99ace10c2d7c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9752827fb7788c2d5c893a899536502e
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/15d6cd7877c6601d9ed410a010efa019
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/355e7ad1d5664421898b91227342b00c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/634b6b50c7e8912f2ce3f1cb66884331
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f4822aa5b83b28cb35840786ceee5cd2
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ebd820a0694086e81f0d59cde6139796
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c3cfbe068adab0579583ff717105f70d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/7b0ed2e4d59ad5261d5011bbe723eeee
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/acdb7b476fc5a1ca96f65931c8819eb
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/335b3ad6f7a96bf251a95aaa6caba1d3
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/691bf14434c590f212a6200f1680863
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/47716b1acaae5b8083653a771e25099b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/dbd67f5f505a795161c6c61410fc904b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a015b428cf628af3522dcdfaad316d22
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/7e63db420468e1b1bda733a39f84326d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c6ab70b8319d7f2451751fb7affef409
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ddc63b22552ef13b734650590bacf709
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/841a80eb66a079e8e0f3abdce6812423
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/3e37a76f38d057cd3f823401cb5b3c88
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/d471c4f43f008df5c1bcae9def1986da
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/163786646ae2578749a5fc144a874235
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/18d9ac72442260e0e97c6bb243ef67d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/30c2364393514c5b1c685cd768514e67
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c683e8e57b20ceeab927782fc69a1fbb
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9e5faa247753ad479289f0a3d35e8de4
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f21188e5f1a6468050bb0437668bebb7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/40953c3fd24e9d65ecf689885b7c1e59
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/3f18c23d7628966848368c1a2f71c5f3
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1f191e0327ce54474cdd04162f008888
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/279adb2c37867b3a18d9ca1acf6633f6
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c53256341ac5693c66d89345e534c861
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/5e5d7901f587c39726d36807b4d406ea
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/bc75e8adfee9ad70bda733a39f84326d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9648aaf755e6556e2a9eb0f146e94477
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/cdef1867e841d4bfafdee870abc9eca
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/aebaeaf0dfeb9fbe13ded1857c15b5b6
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e3b306ad8f7297817a81f08639c57244
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2be8bd6b150a9fee97df6383472cc5b6
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/57e16ac1b026db4e350d065ac10959e0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/fc5d8e25052fb713f559279c88cd9a37
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/420d1b7af7ceaad59ad3ae277a5ccc98
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/26e2b2920a2330b2cdb8ce1e61248143
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1dbb24dedcb23beab1bb46d2556ba67d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/385d82108ff7ee1be2720e351c87b6fe
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e6846796e15020e02bc9f17412005422
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/5b925881cf8678cabda733a39f84326d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/5caad0d7bc6524531e51722eeef6dfef
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/86d9b82220d7ba342e56818be5fde856
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/fad616172dbd52649f06afd991af5139
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/dedd7ee03210ff8a1ccbd9e5bb82dd04
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/60458c0d233ccf9daa69dfdc5532bb13
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2cbe6850de4fa5a34a6a7ab072f22d7d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e15f9acabfa0adc5470d3ca356fc4190
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/bf7efe509caf42cb7481cee66aa2b2f4
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6749e5a1458ead5abda733a39f84326d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/5d8476a9aecbbe1e9ec9fbf723f60ac0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e40b027b68ff767d76ad064d1c5fdd7c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f2b28cd6e6eaa9679393793f9cf3dbea
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/84f258f2969c02de6f94a44ce504367
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/7f2acaeb45b72793ce6183244062e7c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f94003409831db21f2cdad303f49c9f9
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f238821689b42db5d95840a0da458be0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/16d6ecc22218e21b36dfef0450f0ee37
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/88ad6f5df57cf8ea16abce8cb03e7794
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6291f064e64c6eb9d18a5bd35f0d115b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/36ba5d46f034ec58236804c5ee26a2ab
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/50af70a51a2db34d777b3c68b2536729
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/3344ba7f18d9623d549733b112275285
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/24c46b3a467bb4954b1bdab82d834140
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/eea7f5d02088d49dfdb3c05088c091ae
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/8fadf13734ff86b5f9e6f9c7735c6b41
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/98fa551211d228ef6a089bd459bbc1be
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/7478183ebde9c6c2afe717997470b28d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/fa37419c844e77076489e70b7c61a054
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/7e4667d837e39d0945e930a0b8a8cbc8
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9aec898631a69b6b5da1f915cad9a74
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2076be423fa5bb9f9e908ecb03b3d6fb
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/fab45f900797908bbda733a39f84326d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/83c31a4085063873dc2afbe43bc71afa
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ef15b938dcfa9893c4d922e8a1141322
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c24892528799ccf486b4d991d5310067
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/61bcc13c67a92542b6aab5f7ece0e6cd
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/900c32b154c0dced994a3466f8481f8a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1e2f9cb6b33c92ea82381b04bbe0ce6d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e8a8d47957d15bbf8079d5a13e411210
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/24c0c6d558d4d01d8772618b7452025
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c46a940147e6da66ca92a4cdad802b45
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2ccaaa66525d7f095473e57e894e0ef5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ce63abf6d78ea5bf4f39b2731f699e34
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2999f005f1eba724bda733a39f84326d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a88d69e53a01aab9ff1370452e3a0154
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c07bbf672b56b02aafe1d4530f4c6e24
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e866dd4d4bf1f1f5bbadf8db57668863
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/831a3689b2f48664473f10e6caaeca56
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e92786612a9d60455dca6305fb9f97ca
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ffb4d9920493f1e5c29076ad43b687b5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/62b14fc115d98999f0776ca5816850f0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/38f403b915d950d3ce8f4a5eeb103d2
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/75c4085b3315688aca92a4cdad802b45
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/137f67657cdc9da5f985cd98f7d73e9a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/54dfce0866b65c4778254b98f5b75eb
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a74c1aa71334c6af20363e2561dd589a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/d22a2d20acbdca70c972ff3f74d38438
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/3c103561d9a29ae7ddacb20b6a591772
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/43e48813760ad55875c67b3b1e763fcf
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e9ae93e6ddd5bc1e6047f64eee8fcb68
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/31389308f2b032ddf09fb258eb4b1e60
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9aec89a595e4682fbc5845a373118df7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/28d7a23b2311b1029dce0c74b747947
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/3f6e9baa4657276f97df6383472cc5b6
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6942e70e574edda3c8831f15c6e487ac
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/73e977c312f8628b1d65faadf0df8f28
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/4c427f14f21f128ffa38d2670ab5169c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1c351358afff1cc582e5e3e7771ea25
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/b70d970f8020c25dd141480e2c154d3
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/bad0a52f07afc2319ed410a010efa019
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6a737d71a4c4d81958943aeb17f0d326
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c1b4d407168867c45dca6305fb9f97ca
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c916164d0e5c667a75ef328fc121b1c5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/91f59dc0d204dc64260a770f90456bf7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/90902c72c195d3ce8256c497dfca7529
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1c6591c3fc686bf24132f89b3e69f40f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/29793366c4b45bf6f43c51e53897fea
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/5c4bb9e23c6cd8511371f3c322b54f2c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9a2854600f24017949b12cf3977a48b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6d296f7fae3f7f34981c1fca8c617850
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/faeda504709a7af489d347432ecb438c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ec5c003421112630f53148c8cdf6fc9b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/d5d47fe322179a83473f10e6caaeca56
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e9c2c31da871e0d6c203986ffbbb5e4a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e6ec389325de7ae5becf71e2e014ff6f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a03c7c73c067afa9e5bf84cdd88910df
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/513e2ad82336f56bc0e3666c7d0ec7d0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/7a13aaf4344630329ed7f3a4aa9b6d86
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2f7cf2c2d170e3c936f37029483b3e41
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/58f2baf01b8a3baf24da76692f3228e0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e8745e2d659061ee4a15d27f5dbfc7ba
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f60779c934ee51eddd1e15301c83686f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/107a17c6f2dd9c488924120dfad0e290
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/fcd90d547fdeb629f200a72c9245aee7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f3dc4ff3cecb4eaf8ee29572addd5275
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e93f88a9beb9ddbeaff90a85d875467
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9a806af16e5a102786d01a5629641c74
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/62fa029fb8053560a37f3fc191551700
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ac3f9387cd4319592a9eb0f146e94477
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/31546074e22ec0b69ce1b0be9ab0ab75
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ccc6b5ace9f5164d26068f53fe0ecf07
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1c3c8952b92d567e61c6c61410fc904b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f9eaaf5abb238c22851f021b9ed69c58
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e66cb97aabb79193da5cb3be8feeaadc
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f6e5c35314beee84618e9d35559b7aa
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f49155170c175dff176be984cf2a7f4e
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a3e8a28918af7b07e3857ce739e6606f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/62393db2dee065956e28ffc6e1f368fe
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/3ff887eaebf0bc7e9d2b99af43da16b3
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/92a718b74a2e5e84fd2d6c7ed5a8dbd
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/12b5e4f52c22b348d8499d8846cb4c3b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/69492fdcd530eb3da6ce6972f601a2e9
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e2bc765fc68afde6afe717997470b28d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/332ac5346c7d3c0f8e35db9103756ad5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c8d8089dade71547d2350421a9405ba
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f24129eb2169197c203f35d9b3b48203
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f91d1032b7cfae618e4e882feb9b406a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f6e0b8a0746d36d74eb766e5a46fceab
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/100715345ee54d7ae38b52b4ee9d36a3
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/8ceb581fe28a6496510c6353f9f7a5e3
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/52a1d23a09e38c4d50577cf04f3bf74a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/808e19aed606f10cf919864ecec729ac
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/66baad4c6e4bfa08cfd826dd468a5497
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/932363431a35b189898b91227342b00c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1e6e7bfb08b6b44d615949fb78ffe44f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c0b9eb823b9fff9a2764cfba57a5de73
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/94c75ba9c6747f1bb491214a0cc2380
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2359486974efded33121f82ae456ac81
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ea76015145946dffc0896a3cd08800fe
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/948827c3833b8ce26d709900f94f0df3
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1d0a46cfc2799eefdeea60824a43a0b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/52f2a2472411fe2e6b418c7d9fedcaa9
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6d79f2cde0340b5fbecf71e2e014ff6f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a358931939481311bda733a39f84326d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e7c5fb8f7a553da7d7755e7baabe8a6f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/24b9180ac3f89ba4715e04edb8af9c53
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/53125271f866288dc8b3f3d7aa7cc0c7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9dd5fb440759181035fea498c4ba7c5a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1d4eaafea3ae8303ce94fde2d6224f79
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/713b7eaeea5580af1f71b98bc1f8bb06
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6b642c1c62ae5b49247a5be450795511
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e7b500cc55c8f13b4512af8eced68fa8
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/75221b7668e145b549415f1fb7067088
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2490227846d06e5a2387c64d55d0b4e5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1cd4a2c1b3b4a9661487189ebf835715
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/65c067fcae3292d0e7540f431cab4686
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1710ff46ca275e171df27141dea8c9a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/b990ae1858bb82c133f84f942f9a2bf5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/cd85df142f1999e5f38ed4497f2c53c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ef77d2e622786026d32bfc7a837f790
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/92cc3ad1d3da26955fcb05674109534a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/28c83c5adf799340f2cc18e077b7ba53
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/f6ed076d16960558e6748b6322a06ee3
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/5686e48a700bf4c989439bf55b857b9
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6bb14c1083ed44f5ac34b841f2070767
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6615a61a799c144e84306f3bf0a1f2d7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/b56bfe0649294ebecb02238be5da228
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/21a1f2a7b7e671826405999d829064fa
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/3dab4ef100f906c2bda733a39f84326d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/ae1c1141ce4bfde9d66a73de5847ea37
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/206e39a5f67f4a4a81d0c86cc18e6647
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/c8fd6ee4bdbfa5cfbda3e4f05af7d436
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6b0238b41337365a3330c5ee7577e4de
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/100c3076c74ee1874eb766e5a46fceab
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/468be6b80d1c7dd655ac255cda83e91
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/40c05e511efd3fa96945ae93118ea9d6
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/397d2e2b3e0988a2d3901a534bc610d8
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/1a30678509a1fdfa7fb5267a071ae23a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/7a756a1c54cd3a5a1b3611fc576bceff
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/8cbc8e27e885eb763ffe0e5069bf1eb5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/8f8bd59f17f122a163739f01ec1d22b0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a3e1cb03e1af7c6161c6c61410fc904b
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/54514b3e6ea7ad944361eef216dfeaa6
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/158a95b4da25aa1fa37f3fc191551700
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/fd765ab34e7907db186bed5098d348af
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a1d85821a0666a4d8dc995728b1ad443
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/18927999d0c5a9687ba2618ede0d52ff
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/b61f6554d83c50684fa22c482c32995d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/84ffded0ab4b499588ed7b6315c3b4a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/5c29bf38845b4ecbea0f3fb9c87b9c6a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/692a66739b9ed5e14c88b7369bd6883d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/485df8eb9c410c132a9eb0f146e94477
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2f369806f69ba9cb55048eb8b7ed14b6
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/3026dc837dc5dd7a157e36ecb370d387
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e7f40f595169f1b44a383db4764d5432
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/71304f56bb1165e7f42b5c72b4901f94
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/18aad9d102afbca57ba2273581c30cb
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/598f0aea814b1d0f8db98a39370e7faf
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/8fac42d0e74f5b454ca84d60642ec7e8
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/6208166202d795a2272523adb0c9ecd0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/63dceacb54c3c170fc7fcf88dfdc47f1
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a5d32daf96820ca5f63ee8a34069b7c5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/a2d1b78e03f3cc39d1e95557cb698cdf
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/903b043072a209ba8290d32865eb3245
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/275df71b6258e818597505fd7d99b613
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/7bd15f738bf2a402d4fdf31cc2d78fd0
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/dbd0651a6d5bdad69bc489396a21b465
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/b8de49dd963c0669afe1d4530f4c6e24
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/b17d638e7def9adbc8a6c4a50ada6f9f
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/cd2ac3225eb36c0e1a04a94f2d5fba0a
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/b88a4c0cb2092fa52fa4ad29a1236d7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/71b00ea32b1810ac373af83f3f2fe606
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/817bb8c69e4ac23ec81ddeca50aa3117
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/4db6c644912bfbb3e0445fc6d980dd5c
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/2cd119ce9ec61f1af63ee8a34069b7c5
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/e0bf76446d320aa9aa69dfdc5532bb13
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/198d8e274c59511b36a1a31af8f59
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/933b88ebf7eff4c095551e0d9e50cb0d
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/93357732c6306cb51673e1c313348a01
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/94b3689f899c8cfbd575863af568c85
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/61b40cc1d7e054cfaeea7738551d104
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/edb2ab8a1d7e20f36436916a86a90ed7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/4c3b9ecbafc80b9cd485372bb746f3c7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/5662d48de15dcacee1c2519ec6f06d41
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/9803af6123238620247a5be450795511
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/72ad8ebcd7dfbc87368990af61c704f7
# Removed /SEE-MTDA/data/shapenet/VC/WAYMO_nviews-30/train/partial/b12e8616bb73f5daccaf7041f92bc85b

# %%
pcd_gtboxes = mesher.get_pcd_gtboxes(8)
box_pts = np.asarray(pcd_gtboxes['gt_boxes'][0].get_box_points())
box_pts
# Out:
# array([[ 2.19680528,  2.3956037 , -1.53011145],
#        [ 5.30030254,  1.50050327, -1.53011145],
#        [ 2.64019868,  3.9329398 , -1.53011145],
#        [ 2.19680528,  2.3956037 ,  0.03988855],
#        [ 5.74369594,  3.03783937,  0.03988855],
#        [ 2.64019868,  3.9329398 ,  0.03988855],
#        [ 5.30030254,  1.50050327,  0.03988855],
#        [ 5.74369594,  3.03783937, -1.53011145]])

# %% [markdown]
# # Export points in mask/bbox
#
# This is to test out lidar segmentation on the points within a box

# %%
mesher.data_obj.mask_dir
# Out:
# PosixPath('/SEE-MTDA/data/kitti/training/masks/yolox')

# %%
htc_mask.dataset['annotations']
# Out:
# [{'id': '1000000',
#   'image_id': 0,
#   'category_id': 0,
#   'iscrowd': 0,
#   'area': 5103,
#   'bbox': [713.2767333984375,
#    150.7246856689453,
#    95.412109375,
#    158.2196502685547],
#   'segmentation': [[765,
#     151,
#     764,
#     152,
#     761,
#     152,
#     755,
#     158,
#     755,
#     159,
#     754,
#     160,
#     754,
#     164,
#     753,
#     165,
#     753,
#     169,
#     752,
#     170,
#     752,
#     171,
#     751,
#     172,
#     751,
#     174,
#     750,
#     175,
#     750,
#     176,
#     749,
#     177,
#     749,
#     178,
#     747,
#     180,
#     747,
#     182,
#     746,
#     183,
#     746,
#     184,
#     745,
#     185,
#     745,
#     186,
#     744,
#     187,
#     744,
#     191,
#     743,
#     192,
#     743,
#     195,
#     742,
#     196,
#     742,
#     197,
#     741,
#     198,
#     741,
#     204,
#     740,
#     205,
#     740,
#     215,
#     739,
#     216,
#     739,
#     224,
#     740,
#     225,
#     740,
#     230,
#     741,
#     231,
#     741,
#     235,
#     742,
#     236,
#     742,
#     239,
#     741,
#     240,
#     741,
#     244,
#     740,
#     245,
#     740,
#     247,
#     739,
#     248,
#     739,
#     249,
#     738,
#     250,
#     738,
#     251,
#     737,
#     252,
#     737,
#     255,
#     734,
#     258,
#     734,
#     259,
#     733,
#     260,
#     733,
#     261,
#     731,
#     263,
#     731,
#     264,
#     730,
#     265,
#     730,
#     266,
#     729,
#     267,
#     729,
#     268,
#     727,
#     270,
#     727,
#     271,
#     726,
#     272,
#     726,
#     273,
#     724,
#     275,
#     724,
#     276,
#     723,
#     277,
#     723,
#     278,
#     721,
#     280,
#     721,
#     281,
#     720,
#     282,
#     720,
#     283,
#     719,
#     284,
#     719,
#     285,
#     717,
#     287,
#     717,
#     289,
#     716,
#     290,
#     716,
#     301,
#     717,
#     302,
#     717,
#     303,
#     718,
#     304,
#     718,
#     305,
#     719,
#     305,
#     721,
#     307,
#     729,
#     307,
#     730,
#     306,
#     731,
#     306,
#     732,
#     305,
#     732,
#     303,
#     733,
#     302,
#     733,
#     298,
#     732,
#     297,
#     732,
#     292,
#     733,
#     291,
#     733,
#     288,
#     734,
#     287,
#     734,
#     285,
#     735,
#     284,
#     735,
#     283,
#     736,
#     282,
#     736,
#     281,
#     739,
#     278,
#     739,
#     277,
#     740,
#     276,
#     740,
#     275,
#     742,
#     273,
#     742,
#     272,
#     743,
#     271,
#     743,
#     270,
#     746,
#     267,
#     746,
#     266,
#     747,
#     265,
#     747,
#     264,
#     750,
#     261,
#     750,
#     260,
#     757,
#     253,
#     760,
#     253,
#     764,
#     257,
#     764,
#     258,
#     765,
#     259,
#     765,
#     260,
#     766,
#     261,
#     766,
#     262,
#     767,
#     263,
#     767,
#     264,
#     768,
#     265,
#     768,
#     266,
#     769,
#     267,
#     769,
#     268,
#     771,
#     270,
#     771,
#     272,
#     772,
#     273,
#     772,
#     274,
#     773,
#     275,
#     773,
#     276,
#     774,
#     277,
#     774,
#     278,
#     775,
#     279,
#     775,
#     281,
#     777,
#     283,
#     777,
#     286,
#     778,
#     287,
#     778,
#     289,
#     779,
#     290,
#     779,
#     291,
#     780,
#     292,
#     780,
#     294,
#     781,
#     295,
#     781,
#     296,
#     782,
#     297,
#     782,
#     298,
#     783,
#     299,
#     783,
#     300,
#     785,
#     302,
#     786,
#     302,
#     787,
#     303,
#     793,
#     303,
#     794,
#     302,
#     799,
#     302,
#     800,
#     301,
#     801,
#     301,
#     803,
#     299,
#     803,
#     297,
#     804,
#     296,
#     804,
#     294,
#     803,
#     293,
#     802,
#     293,
#     801,
#     292,
#     800,
#     292,
#     792,
#     284,
#     792,
#     283,
#     791,
#     282,
#     791,
#     280,
#     790,
#     279,
#     790,
#     277,
#     789,
#     276,
#     789,
#     275,
#     788,
#     274,
#     788,
#     272,
#     787,
#     271,
#     787,
#     270,
#     786,
#     269,
#     786,
#     268,
#     785,
#     267,
#     785,
#     266,
#     784,
#     265,
#     784,
#     263,
#     783,
#     262,
#     783,
#     260,
#     782,
#     259,
#     782,
#     258,
#     781,
#     257,
#     781,
#     256,
#     780,
#     255,
#     780,
#     253,
#     779,
#     252,
#     779,
#     251,
#     778,
#     250,
#     778,
#     248,
#     777,
#     247,
#     777,
#     245,
#     776,
#     244,
#     776,
#     242,
#     775,
#     241,
#     775,
#     240,
#     774,
#     239,
#     774,
#     238,
#     773,
#     237,
#     773,
#     235,
#     772,
#     234,
#     772,
#     233,
#     771,
#     232,
#     771,
#     228,
#     770,
#     227,
#     770,
#     226,
#     771,
#     225,
#     771,
#     224,
#     772,
#     223,
#     772,
#     222,
#     773,
#     221,
#     774,
#     221,
#     775,
#     220,
#     779,
#     220,
#     780,
#     221,
#     781,
#     221,
#     782,
#     222,
#     786,
#     222,
#     787,
#     223,
#     791,
#     223,
#     792,
#     224,
#     797,
#     224,
#     800,
#     221,
#     800,
#     220,
#     798,
#     218,
#     797,
#     218,
#     795,
#     216,
#     794,
#     216,
#     793,
#     215,
#     791,
#     215,
#     790,
#     214,
#     788,
#     214,
#     787,
#     213,
#     785,
#     213,
#     784,
#     212,
#     783,
#     212,
#     778,
#     207,
#     777,
#     207,
#     774,
#     204,
#     774,
#     203,
#     773,
#     202,
#     773,
#     201,
#     772,
#     200,
#     772,
#     198,
#     771,
#     197,
#     771,
#     194,
#     770,
#     193,
#     770,
#     188,
#     769,
#     187,
#     769,
#     180,
#     770,
#     179,
#     770,
#     175,
#     771,
#     174,
#     771,
#     173,
#     772,
#     172,
#     772,
#     171,
#     773,
#     170,
#     773,
#     168,
#     774,
#     167,
#     774,
#     166,
#     775,
#     165,
#     775,
#     158,
#     773,
#     156,
#     773,
#     155,
#     770,
#     152,
#     767,
#     152,
#     766,
#     151]]},
#  {'id': '1000001',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 3015,
#   'bbox': [852.802734375,
#    201.02886962890625,
#    68.154052734375,
#    80.56277465820312],
#   'segmentation': [[885,
#     207,
#     884,
#     208,
#     882,
#     208,
#     881,
#     209,
#     875,
#     209,
#     874,
#     210,
#     872,
#     210,
#     872,
#     211,
#     871,
#     212,
#     871,
#     213,
#     870,
#     214,
#     870,
#     216,
#     868,
#     218,
#     868,
#     219,
#     860,
#     227,
#     860,
#     228,
#     858,
#     230,
#     858,
#     231,
#     856,
#     233,
#     856,
#     234,
#     855,
#     235,
#     855,
#     237,
#     854,
#     238,
#     854,
#     246,
#     855,
#     247,
#     855,
#     251,
#     856,
#     252,
#     856,
#     255,
#     857,
#     256,
#     857,
#     258,
#     858,
#     259,
#     858,
#     260,
#     863,
#     265,
#     864,
#     265,
#     865,
#     266,
#     867,
#     266,
#     868,
#     267,
#     869,
#     267,
#     870,
#     268,
#     873,
#     268,
#     874,
#     269,
#     876,
#     269,
#     877,
#     270,
#     878,
#     270,
#     879,
#     271,
#     884,
#     271,
#     885,
#     272,
#     888,
#     272,
#     892,
#     276,
#     892,
#     277,
#     893,
#     278,
#     896,
#     278,
#     898,
#     276,
#     898,
#     274,
#     899,
#     273,
#     899,
#     267,
#     900,
#     266,
#     900,
#     263,
#     902,
#     261,
#     903,
#     262,
#     904,
#     262,
#     906,
#     264,
#     906,
#     265,
#     907,
#     266,
#     907,
#     267,
#     908,
#     268,
#     908,
#     269,
#     909,
#     270,
#     909,
#     272,
#     911,
#     274,
#     911,
#     275,
#     912,
#     276,
#     912,
#     277,
#     913,
#     278,
#     917,
#     278,
#     917,
#     277,
#     918,
#     276,
#     918,
#     275,
#     919,
#     274,
#     919,
#     265,
#     918,
#     264,
#     918,
#     259,
#     917,
#     258,
#     917,
#     252,
#     916,
#     251,
#     916,
#     248,
#     915,
#     247,
#     915,
#     246,
#     914,
#     245,
#     914,
#     244,
#     913,
#     243,
#     913,
#     241,
#     912,
#     240,
#     912,
#     239,
#     911,
#     238,
#     911,
#     237,
#     909,
#     235,
#     909,
#     234,
#     908,
#     233,
#     908,
#     232,
#     907,
#     231,
#     907,
#     230,
#     906,
#     229,
#     904,
#     229,
#     903,
#     228,
#     900,
#     228,
#     899,
#     227,
#     896,
#     227,
#     895,
#     226,
#     893,
#     226,
#     892,
#     225,
#     891,
#     225,
#     887,
#     221,
#     887,
#     219,
#     891,
#     215,
#     891,
#     211,
#     890,
#     210,
#     890,
#     209,
#     889,
#     208,
#     888,
#     208,
#     887,
#     207]]},
#  {'id': '1000002',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 1989,
#   'bbox': [951.4155883789062,
#    199.11827087402344,
#    49.4010009765625,
#    80.33265686035156],
#   'segmentation': [[963,
#     203,
#     963,
#     205,
#     964,
#     206,
#     964,
#     209,
#     963,
#     210,
#     961,
#     210,
#     958,
#     213,
#     958,
#     216,
#     959,
#     217,
#     959,
#     220,
#     958,
#     221,
#     958,
#     230,
#     959,
#     231,
#     959,
#     247,
#     960,
#     248,
#     960,
#     252,
#     961,
#     253,
#     961,
#     256,
#     962,
#     257,
#     962,
#     259,
#     963,
#     260,
#     963,
#     262,
#     964,
#     263,
#     964,
#     264,
#     968,
#     264,
#     969,
#     265,
#     971,
#     265,
#     973,
#     267,
#     974,
#     267,
#     976,
#     269,
#     977,
#     269,
#     984,
#     276,
#     985,
#     276,
#     987,
#     278,
#     990,
#     278,
#     991,
#     277,
#     992,
#     277,
#     995,
#     274,
#     995,
#     273,
#     996,
#     272,
#     996,
#     271,
#     997,
#     270,
#     997,
#     267,
#     998,
#     266,
#     998,
#     248,
#     997,
#     247,
#     997,
#     243,
#     996,
#     242,
#     996,
#     241,
#     995,
#     240,
#     995,
#     239,
#     994,
#     238,
#     994,
#     237,
#     992,
#     235,
#     992,
#     234,
#     991,
#     233,
#     991,
#     231,
#     990,
#     230,
#     990,
#     229,
#     987,
#     226,
#     987,
#     225,
#     986,
#     225,
#     985,
#     224,
#     983,
#     224,
#     982,
#     225,
#     981,
#     225,
#     980,
#     224,
#     979,
#     224,
#     978,
#     223,
#     978,
#     222,
#     976,
#     220,
#     976,
#     219,
#     975,
#     218,
#     975,
#     217,
#     974,
#     216,
#     974,
#     215,
#     973,
#     214,
#     973,
#     213,
#     970,
#     210,
#     970,
#     209,
#     969,
#     208,
#     969,
#     206,
#     967,
#     204,
#     967,
#     203]]},
#  {'id': '1000003',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 1242,
#   'bbox': [380.1058044433594,
#    208.26617431640625,
#    41.568603515625,
#    60.875457763671875],
#   'segmentation': [[403,
#     209,
#     402,
#     210,
#     392,
#     210,
#     391,
#     211,
#     390,
#     211,
#     392,
#     213,
#     392,
#     214,
#     393,
#     215,
#     393,
#     223,
#     390,
#     226,
#     390,
#     234,
#     391,
#     235,
#     391,
#     242,
#     392,
#     243,
#     392,
#     252,
#     393,
#     253,
#     393,
#     258,
#     394,
#     259,
#     394,
#     260,
#     395,
#     261,
#     395,
#     262,
#     399,
#     266,
#     400,
#     266,
#     401,
#     267,
#     408,
#     267,
#     409,
#     266,
#     410,
#     266,
#     411,
#     265,
#     412,
#     265,
#     416,
#     261,
#     416,
#     260,
#     418,
#     258,
#     418,
#     257,
#     419,
#     256,
#     419,
#     254,
#     420,
#     253,
#     420,
#     239,
#     419,
#     238,
#     419,
#     236,
#     418,
#     235,
#     418,
#     234,
#     417,
#     233,
#     417,
#     232,
#     414,
#     229,
#     413,
#     229,
#     412,
#     228,
#     410,
#     228,
#     409,
#     227,
#     407,
#     227,
#     406,
#     226,
#     404,
#     226,
#     400,
#     222,
#     400,
#     221,
#     399,
#     220,
#     399,
#     219,
#     398,
#     218,
#     398,
#     217,
#     401,
#     214,
#     403,
#     214,
#     404,
#     213,
#     406,
#     213,
#     408,
#     211,
#     407,
#     210,
#     406,
#     210,
#     405,
#     209]]},
#  {'id': '1000004',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 1754,
#   'bbox': [914.1317138671875,
#    195.69993591308594,
#    46.62164306640625,
#    83.49754333496094],
#   'segmentation': [[936,
#     212,
#     935,
#     213,
#     935,
#     214,
#     934,
#     215,
#     934,
#     217,
#     933,
#     218,
#     932,
#     218,
#     931,
#     219,
#     928,
#     219,
#     927,
#     218,
#     926,
#     218,
#     924,
#     220,
#     924,
#     222,
#     923,
#     223,
#     923,
#     228,
#     924,
#     229,
#     924,
#     251,
#     925,
#     252,
#     925,
#     258,
#     926,
#     259,
#     926,
#     260,
#     927,
#     261,
#     927,
#     262,
#     929,
#     264,
#     929,
#     265,
#     931,
#     267,
#     931,
#     268,
#     932,
#     268,
#     933,
#     269,
#     935,
#     269,
#     936,
#     270,
#     937,
#     270,
#     938,
#     271,
#     943,
#     271,
#     947,
#     275,
#     948,
#     275,
#     949,
#     276,
#     950,
#     276,
#     951,
#     277,
#     955,
#     277,
#     956,
#     276,
#     956,
#     275,
#     957,
#     274,
#     957,
#     272,
#     958,
#     271,
#     958,
#     254,
#     957,
#     253,
#     957,
#     246,
#     956,
#     245,
#     956,
#     241,
#     955,
#     240,
#     955,
#     238,
#     954,
#     237,
#     954,
#     236,
#     953,
#     235,
#     953,
#     234,
#     952,
#     233,
#     952,
#     230,
#     951,
#     229,
#     951,
#     227,
#     950,
#     226,
#     950,
#     225,
#     943,
#     218,
#     943,
#     217,
#     942,
#     216,
#     942,
#     214,
#     941,
#     213,
#     941,
#     212],
#    [926, 208, 925, 209, 925, 212, 926, 213],
#    [920,
#     201,
#     919,
#     202,
#     919,
#     203,
#     920,
#     204,
#     923,
#     204,
#     924,
#     203,
#     924,
#     202,
#     923,
#     201]]},
#  {'id': '1000005',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 1391,
#   'bbox': [306.7940979003906,
#    207.85877990722656,
#    34.0028076171875,
#    74.93943786621094],
#   'segmentation': [[323,
#     210,
#     322,
#     211,
#     315,
#     211,
#     314,
#     212,
#     313,
#     212,
#     312,
#     213,
#     312,
#     215,
#     313,
#     216,
#     313,
#     218,
#     314,
#     219,
#     314,
#     220,
#     315,
#     221,
#     315,
#     225,
#     314,
#     226,
#     314,
#     230,
#     313,
#     231,
#     313,
#     233,
#     312,
#     234,
#     312,
#     236,
#     311,
#     237,
#     311,
#     239,
#     310,
#     240,
#     310,
#     242,
#     309,
#     243,
#     309,
#     255,
#     310,
#     256,
#     310,
#     261,
#     311,
#     262,
#     311,
#     266,
#     312,
#     267,
#     312,
#     269,
#     313,
#     270,
#     313,
#     272,
#     314,
#     273,
#     314,
#     274,
#     315,
#     275,
#     315,
#     276,
#     319,
#     280,
#     320,
#     280,
#     321,
#     281,
#     324,
#     281,
#     325,
#     280,
#     326,
#     280,
#     327,
#     279,
#     328,
#     279,
#     329,
#     278,
#     329,
#     277,
#     331,
#     275,
#     331,
#     274,
#     332,
#     273,
#     332,
#     272,
#     333,
#     271,
#     333,
#     269,
#     334,
#     268,
#     334,
#     266,
#     335,
#     265,
#     335,
#     262,
#     336,
#     261,
#     336,
#     248,
#     335,
#     247,
#     335,
#     246,
#     332,
#     243,
#     332,
#     242,
#     331,
#     241,
#     331,
#     240,
#     330,
#     239,
#     330,
#     236,
#     329,
#     235,
#     329,
#     229,
#     328,
#     228,
#     328,
#     227,
#     326,
#     225,
#     326,
#     224,
#     325,
#     223,
#     325,
#     215,
#     326,
#     214,
#     326,
#     211,
#     325,
#     210]]},
#  {'id': '1000006',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 2527,
#   'bbox': [347.8551940917969,
#    207.6772918701172,
#    72.29541015625,
#    70.44908142089844],
#   'segmentation': [[403,
#     209,
#     402,
#     210,
#     392,
#     210,
#     391,
#     211,
#     391,
#     212,
#     392,
#     213,
#     392,
#     215,
#     393,
#     216,
#     393,
#     220,
#     392,
#     221,
#     392,
#     223,
#     388,
#     227,
#     384,
#     227,
#     383,
#     226,
#     382,
#     226,
#     380,
#     224,
#     380,
#     223,
#     379,
#     222,
#     379,
#     216,
#     380,
#     215,
#     380,
#     212,
#     381,
#     211,
#     377,
#     211,
#     376,
#     210,
#     372,
#     210,
#     371,
#     211,
#     371,
#     212,
#     372,
#     213,
#     372,
#     218,
#     373,
#     219,
#     373,
#     222,
#     372,
#     223,
#     372,
#     226,
#     371,
#     227,
#     371,
#     228,
#     370,
#     229,
#     370,
#     230,
#     369,
#     231,
#     369,
#     233,
#     368,
#     234,
#     368,
#     236,
#     367,
#     237,
#     367,
#     238,
#     366,
#     239,
#     366,
#     240,
#     365,
#     241,
#     365,
#     242,
#     364,
#     243,
#     364,
#     248,
#     365,
#     249,
#     365,
#     252,
#     366,
#     253,
#     366,
#     256,
#     368,
#     258,
#     368,
#     259,
#     369,
#     260,
#     369,
#     263,
#     370,
#     264,
#     370,
#     265,
#     371,
#     266,
#     371,
#     268,
#     372,
#     269,
#     372,
#     270,
#     376,
#     274,
#     378,
#     274,
#     379,
#     275,
#     382,
#     275,
#     383,
#     274,
#     386,
#     274,
#     389,
#     271,
#     391,
#     271,
#     392,
#     270,
#     394,
#     270,
#     395,
#     269,
#     401,
#     269,
#     402,
#     268,
#     404,
#     268,
#     405,
#     267,
#     407,
#     267,
#     408,
#     266,
#     409,
#     266,
#     410,
#     265,
#     411,
#     265,
#     412,
#     264,
#     413,
#     264,
#     416,
#     261,
#     416,
#     260,
#     417,
#     259,
#     417,
#     258,
#     418,
#     257,
#     418,
#     253,
#     419,
#     252,
#     419,
#     240,
#     418,
#     239,
#     418,
#     236,
#     417,
#     235,
#     417,
#     234,
#     416,
#     233,
#     416,
#     232,
#     414,
#     230,
#     413,
#     230,
#     412,
#     229,
#     411,
#     229,
#     410,
#     228,
#     407,
#     228,
#     406,
#     227,
#     404,
#     227,
#     403,
#     226,
#     402,
#     226,
#     399,
#     223,
#     399,
#     222,
#     398,
#     221,
#     398,
#     218,
#     399,
#     217,
#     399,
#     216,
#     400,
#     215,
#     401,
#     215,
#     402,
#     214,
#     403,
#     214,
#     404,
#     213,
#     405,
#     213,
#     406,
#     212,
#     407,
#     212,
#     408,
#     211,
#     406,
#     209]]},
#  {'id': '1000007',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 2151,
#   'bbox': [251.85984802246094,
#    209.0645294189453,
#    53.94602966308594,
#    75.21473693847656],
#   'segmentation': [[287,
#     225,
#     286,
#     226,
#     284,
#     226,
#     279,
#     231,
#     279,
#     234,
#     278,
#     235,
#     278,
#     236,
#     275,
#     239,
#     274,
#     238,
#     273,
#     238,
#     271,
#     236,
#     271,
#     235,
#     270,
#     234,
#     270,
#     233,
#     269,
#     232,
#     269,
#     231,
#     268,
#     230,
#     265,
#     230,
#     264,
#     231,
#     263,
#     231,
#     257,
#     237,
#     257,
#     238,
#     255,
#     240,
#     255,
#     241,
#     254,
#     242,
#     254,
#     245,
#     253,
#     246,
#     253,
#     262,
#     254,
#     263,
#     254,
#     266,
#     255,
#     267,
#     255,
#     269,
#     256,
#     270,
#     256,
#     271,
#     257,
#     272,
#     257,
#     273,
#     261,
#     277,
#     261,
#     278,
#     262,
#     278,
#     263,
#     279,
#     263,
#     280,
#     264,
#     280,
#     266,
#     282,
#     270,
#     282,
#     271,
#     281,
#     272,
#     281,
#     273,
#     280,
#     274,
#     280,
#     276,
#     278,
#     277,
#     278,
#     278,
#     277,
#     279,
#     277,
#     284,
#     272,
#     288,
#     272,
#     289,
#     273,
#     290,
#     273,
#     293,
#     276,
#     293,
#     277,
#     294,
#     277,
#     295,
#     278,
#     296,
#     277,
#     297,
#     277,
#     297,
#     276,
#     302,
#     271,
#     302,
#     262,
#     301,
#     261,
#     301,
#     255,
#     300,
#     254,
#     300,
#     248,
#     299,
#     247,
#     299,
#     242,
#     298,
#     241,
#     298,
#     238,
#     297,
#     237,
#     297,
#     236,
#     296,
#     235,
#     296,
#     232,
#     295,
#     231,
#     295,
#     230,
#     294,
#     229,
#     294,
#     228,
#     293,
#     227,
#     293,
#     226,
#     292,
#     225]]},
#  {'id': '1000008',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 5293,
#   'bbox': [1147.7103271484375,
#    233.08990478515625,
#    75.612548828125,
#    120.5037841796875],
#   'segmentation': [[1162,
#     250,
#     1161,
#     251,
#     1159,
#     251,
#     1158,
#     252,
#     1158,
#     255,
#     1157,
#     256,
#     1158,
#     257,
#     1158,
#     260,
#     1159,
#     261,
#     1159,
#     305,
#     1158,
#     306,
#     1158,
#     331,
#     1159,
#     332,
#     1159,
#     335,
#     1160,
#     336,
#     1160,
#     337,
#     1163,
#     340,
#     1164,
#     340,
#     1166,
#     342,
#     1167,
#     342,
#     1168,
#     343,
#     1169,
#     343,
#     1170,
#     344,
#     1172,
#     344,
#     1173,
#     345,
#     1175,
#     345,
#     1176,
#     346,
#     1177,
#     346,
#     1178,
#     347,
#     1181,
#     347,
#     1182,
#     348,
#     1188,
#     348,
#     1189,
#     349,
#     1194,
#     349,
#     1195,
#     348,
#     1200,
#     348,
#     1201,
#     347,
#     1203,
#     347,
#     1205,
#     345,
#     1206,
#     345,
#     1219,
#     332,
#     1219,
#     331,
#     1220,
#     330,
#     1220,
#     329,
#     1221,
#     328,
#     1221,
#     324,
#     1222,
#     323,
#     1222,
#     301,
#     1221,
#     300,
#     1221,
#     258,
#     1220,
#     257,
#     1220,
#     256,
#     1219,
#     255,
#     1214,
#     255,
#     1213,
#     256,
#     1210,
#     256,
#     1209,
#     257,
#     1207,
#     257,
#     1206,
#     258,
#     1204,
#     258,
#     1203,
#     259,
#     1202,
#     259,
#     1200,
#     261,
#     1199,
#     261,
#     1198,
#     262,
#     1198,
#     263,
#     1197,
#     264,
#     1197,
#     265,
#     1196,
#     266,
#     1196,
#     267,
#     1195,
#     268,
#     1195,
#     272,
#     1196,
#     273,
#     1196,
#     274,
#     1195,
#     275,
#     1195,
#     277,
#     1193,
#     279,
#     1190,
#     279,
#     1189,
#     280,
#     1188,
#     279,
#     1185,
#     279,
#     1184,
#     278,
#     1182,
#     278,
#     1180,
#     276,
#     1180,
#     275,
#     1179,
#     274,
#     1179,
#     272,
#     1180,
#     271,
#     1180,
#     268,
#     1179,
#     268,
#     1178,
#     267,
#     1175,
#     267,
#     1174,
#     266,
#     1174,
#     261,
#     1176,
#     259,
#     1180,
#     259,
#     1181,
#     258,
#     1183,
#     258,
#     1184,
#     257,
#     1184,
#     256,
#     1180,
#     256,
#     1179,
#     255,
#     1175,
#     255,
#     1173,
#     253,
#     1172,
#     253,
#     1171,
#     252,
#     1168,
#     252,
#     1167,
#     251,
#     1163,
#     251]]},
#  {'id': '1000009',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 1238,
#   'bbox': [341.66375732421875,
#    209.84893798828125,
#    38.996429443359375,
#    71.54959106445312],
#   'segmentation': [[358,
#     226,
#     357,
#     227,
#     357,
#     228,
#     355,
#     230,
#     354,
#     230,
#     353,
#     231,
#     352,
#     231,
#     351,
#     232,
#     350,
#     232,
#     349,
#     233,
#     348,
#     233,
#     347,
#     234,
#     347,
#     235,
#     346,
#     236,
#     346,
#     238,
#     345,
#     239,
#     345,
#     246,
#     344,
#     247,
#     344,
#     266,
#     345,
#     267,
#     345,
#     271,
#     346,
#     272,
#     346,
#     273,
#     348,
#     275,
#     348,
#     276,
#     351,
#     279,
#     357,
#     279,
#     358,
#     278,
#     359,
#     278,
#     362,
#     275,
#     363,
#     275,
#     364,
#     274,
#     365,
#     274,
#     367,
#     272,
#     370,
#     272,
#     371,
#     273,
#     373,
#     273,
#     373,
#     264,
#     372,
#     263,
#     372,
#     259,
#     371,
#     258,
#     371,
#     256,
#     370,
#     255,
#     370,
#     254,
#     369,
#     253,
#     369,
#     250,
#     368,
#     249,
#     368,
#     231,
#     367,
#     231,
#     367,
#     232,
#     364,
#     235,
#     362,
#     233,
#     362,
#     231,
#     360,
#     229,
#     360,
#     228],
#    [351,
#     213,
#     351,
#     215,
#     352,
#     216,
#     353,
#     216,
#     357,
#     220,
#     357,
#     218,
#     358,
#     217,
#     358,
#     215,
#     357,
#     214,
#     357,
#     213]]},
#  {'id': '1000010',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 2607,
#   'bbox': [292.2491760253906,
#    207.8737335205078,
#    94.129150390625,
#    73.42509460449219],
#   'segmentation': [[316,
#     211,
#     315,
#     212,
#     314,
#     212,
#     314,
#     215,
#     315,
#     216,
#     315,
#     217,
#     316,
#     218,
#     316,
#     223,
#     315,
#     224,
#     315,
#     225,
#     314,
#     226,
#     314,
#     230,
#     313,
#     231,
#     313,
#     234,
#     312,
#     235,
#     312,
#     237,
#     310,
#     239,
#     310,
#     240,
#     309,
#     241,
#     309,
#     244,
#     308,
#     245,
#     308,
#     247,
#     307,
#     248,
#     307,
#     252,
#     308,
#     253,
#     308,
#     256,
#     309,
#     257,
#     309,
#     259,
#     310,
#     260,
#     310,
#     263,
#     311,
#     264,
#     311,
#     266,
#     312,
#     267,
#     312,
#     268,
#     313,
#     269,
#     313,
#     270,
#     314,
#     271,
#     314,
#     272,
#     315,
#     273,
#     315,
#     274,
#     317,
#     276,
#     317,
#     277,
#     318,
#     277,
#     320,
#     279,
#     324,
#     279,
#     325,
#     278,
#     326,
#     278,
#     327,
#     277,
#     328,
#     277,
#     334,
#     271,
#     334,
#     270,
#     337,
#     267,
#     338,
#     267,
#     339,
#     266,
#     341,
#     266,
#     342,
#     267,
#     342,
#     268,
#     348,
#     274,
#     349,
#     274,
#     352,
#     277,
#     356,
#     277,
#     357,
#     276,
#     358,
#     276,
#     359,
#     275,
#     361,
#     275,
#     362,
#     274,
#     363,
#     274,
#     364,
#     273,
#     365,
#     273,
#     366,
#     272,
#     367,
#     272,
#     368,
#     271,
#     369,
#     271,
#     371,
#     269,
#     371,
#     266,
#     370,
#     265,
#     370,
#     264,
#     369,
#     263,
#     369,
#     262,
#     368,
#     261,
#     368,
#     260,
#     367,
#     259,
#     367,
#     258,
#     366,
#     257,
#     366,
#     256,
#     363,
#     253,
#     363,
#     251,
#     361,
#     249,
#     361,
#     247,
#     360,
#     246,
#     360,
#     244,
#     359,
#     243,
#     359,
#     241,
#     358,
#     240,
#     358,
#     235,
#     357,
#     234,
#     357,
#     232,
#     353,
#     232,
#     352,
#     233,
#     351,
#     233,
#     350,
#     234,
#     349,
#     233,
#     343,
#     233,
#     342,
#     232,
#     340,
#     232,
#     338,
#     230,
#     337,
#     230,
#     336,
#     229,
#     334,
#     229,
#     331,
#     226,
#     330,
#     226,
#     329,
#     225,
#     328,
#     225,
#     327,
#     224,
#     326,
#     224,
#     321,
#     219,
#     321,
#     218,
#     320,
#     217,
#     322,
#     215,
#     323,
#     215,
#     327,
#     211]]},
#  {'id': '1000011',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 1122,
#   'bbox': [884.6060791015625,
#    204.51817321777344,
#    38.8284912109375,
#    76.77668762207031],
#   'segmentation': [[898,
#     216,
#     897,
#     217,
#     894,
#     217,
#     893,
#     218,
#     893,
#     220,
#     892,
#     221,
#     892,
#     224,
#     889,
#     227,
#     889,
#     235,
#     890,
#     236,
#     890,
#     237,
#     891,
#     238,
#     891,
#     239,
#     892,
#     240,
#     892,
#     241,
#     894,
#     243,
#     894,
#     244,
#     895,
#     245,
#     895,
#     248,
#     896,
#     249,
#     896,
#     252,
#     897,
#     253,
#     897,
#     255,
#     898,
#     256,
#     899,
#     256,
#     901,
#     258,
#     902,
#     258,
#     905,
#     261,
#     905,
#     262,
#     906,
#     263,
#     906,
#     264,
#     907,
#     265,
#     907,
#     266,
#     908,
#     267,
#     908,
#     269,
#     909,
#     270,
#     909,
#     271,
#     910,
#     272,
#     910,
#     273,
#     911,
#     274,
#     911,
#     275,
#     913,
#     277,
#     913,
#     278,
#     914,
#     278,
#     915,
#     279,
#     916,
#     279,
#     918,
#     277,
#     918,
#     275,
#     919,
#     274,
#     919,
#     258,
#     918,
#     257,
#     918,
#     247,
#     917,
#     246,
#     917,
#     244,
#     916,
#     243,
#     916,
#     241,
#     915,
#     240,
#     915,
#     237,
#     914,
#     236,
#     914,
#     235,
#     913,
#     234,
#     913,
#     232,
#     912,
#     231,
#     912,
#     229,
#     911,
#     228,
#     911,
#     227,
#     909,
#     225,
#     908,
#     225,
#     907,
#     224,
#     906,
#     224,
#     903,
#     221,
#     903,
#     220,
#     902,
#     219,
#     902,
#     217,
#     901,
#     216]]},
#  {'id': '1000012',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 994,
#   'bbox': [283.9914245605469,
#    215.4269256591797,
#    26.747650146484375,
#    68.51945495605469],
#   'segmentation': [[295,
#     226,
#     294,
#     227,
#     293,
#     227,
#     292,
#     228,
#     292,
#     229,
#     291,
#     230,
#     291,
#     232,
#     290,
#     233,
#     290,
#     235,
#     289,
#     236,
#     289,
#     238,
#     288,
#     239,
#     288,
#     242,
#     287,
#     243,
#     287,
#     246,
#     286,
#     247,
#     286,
#     263,
#     287,
#     264,
#     287,
#     271,
#     288,
#     272,
#     288,
#     274,
#     289,
#     275,
#     289,
#     277,
#     293,
#     281,
#     294,
#     281,
#     295,
#     282,
#     296,
#     282,
#     297,
#     281,
#     298,
#     281,
#     299,
#     280,
#     300,
#     280,
#     302,
#     278,
#     303,
#     278,
#     306,
#     275,
#     306,
#     274,
#     307,
#     273,
#     307,
#     263,
#     306,
#     262,
#     306,
#     251,
#     305,
#     250,
#     305,
#     231,
#     304,
#     231,
#     303,
#     230,
#     302,
#     230,
#     298,
#     226]]},
#  {'id': '1000013',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 1194,
#   'bbox': [314.459716796875,
#    206.86679077148438,
#    43.990386962890625,
#    74.56698608398438],
#   'segmentation': [[342,
#     224,
#     340,
#     226,
#     340,
#     228,
#     338,
#     230,
#     335,
#     230,
#     334,
#     229,
#     331,
#     229,
#     330,
#     228,
#     327,
#     228,
#     327,
#     237,
#     326,
#     238,
#     326,
#     241,
#     325,
#     242,
#     325,
#     243,
#     324,
#     244,
#     323,
#     243,
#     322,
#     243,
#     319,
#     246,
#     319,
#     247,
#     318,
#     248,
#     318,
#     250,
#     317,
#     251,
#     317,
#     263,
#     316,
#     264,
#     316,
#     273,
#     317,
#     274,
#     317,
#     276,
#     318,
#     277,
#     318,
#     278,
#     319,
#     279,
#     320,
#     279,
#     321,
#     280,
#     324,
#     280,
#     325,
#     279,
#     327,
#     279,
#     331,
#     275,
#     331,
#     274,
#     333,
#     272,
#     333,
#     270,
#     334,
#     269,
#     334,
#     268,
#     335,
#     267,
#     335,
#     266,
#     337,
#     264,
#     338,
#     264,
#     339,
#     263,
#     340,
#     263,
#     343,
#     266,
#     343,
#     267,
#     345,
#     269,
#     347,
#     267,
#     347,
#     264,
#     346,
#     263,
#     346,
#     253,
#     345,
#     252,
#     345,
#     228,
#     344,
#     227,
#     344,
#     225,
#     343,
#     224]]},
#  {'id': '1000014',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 3190,
#   'bbox': [915.0739135742188,
#    197.58851623535156,
#    107.45458984375,
#    81.60093688964844],
#   'segmentation': [[966,
#     204,
#     965,
#     205,
#     966,
#     206,
#     966,
#     207,
#     964,
#     209,
#     962,
#     209,
#     961,
#     210,
#     959,
#     210,
#     958,
#     211,
#     957,
#     211,
#     956,
#     212,
#     954,
#     212,
#     953,
#     213,
#     952,
#     213,
#     949,
#     216,
#     950,
#     217,
#     950,
#     220,
#     949,
#     221,
#     949,
#     222,
#     948,
#     223,
#     948,
#     225,
#     945,
#     228,
#     945,
#     230,
#     944,
#     231,
#     944,
#     234,
#     943,
#     235,
#     943,
#     243,
#     942,
#     244,
#     942,
#     252,
#     943,
#     253,
#     943,
#     254,
#     941,
#     256,
#     941,
#     260,
#     940,
#     261,
#     940,
#     263,
#     941,
#     264,
#     941,
#     265,
#     946,
#     270,
#     946,
#     271,
#     947,
#     271,
#     950,
#     274,
#     955,
#     274,
#     955,
#     273,
#     956,
#     272,
#     956,
#     271,
#     957,
#     270,
#     957,
#     269,
#     958,
#     268,
#     958,
#     267,
#     962,
#     263,
#     967,
#     263,
#     968,
#     264,
#     969,
#     264,
#     970,
#     265,
#     971,
#     265,
#     973,
#     267,
#     974,
#     267,
#     977,
#     270,
#     978,
#     270,
#     983,
#     275,
#     984,
#     275,
#     986,
#     277,
#     992,
#     277,
#     993,
#     276,
#     994,
#     276,
#     995,
#     275,
#     995,
#     274,
#     998,
#     271,
#     998,
#     268,
#     999,
#     267,
#     999,
#     263,
#     1000,
#     262,
#     1000,
#     260,
#     1001,
#     259,
#     1001,
#     258,
#     1002,
#     257,
#     1002,
#     256,
#     1003,
#     255,
#     1003,
#     252,
#     1004,
#     251,
#     1003,
#     250,
#     1003,
#     244,
#     1002,
#     243,
#     1002,
#     240,
#     1001,
#     239,
#     1001,
#     237,
#     1000,
#     236,
#     1000,
#     235,
#     999,
#     234,
#     999,
#     233,
#     996,
#     230,
#     996,
#     229,
#     992,
#     225,
#     992,
#     224,
#     989,
#     221,
#     988,
#     221,
#     987,
#     220,
#     986,
#     220,
#     985,
#     219,
#     983,
#     219,
#     982,
#     218,
#     981,
#     218,
#     979,
#     216,
#     978,
#     216,
#     977,
#     215,
#     975,
#     215,
#     973,
#     213,
#     972,
#     213,
#     970,
#     211,
#     970,
#     210,
#     969,
#     209,
#     968,
#     209,
#     967,
#     208,
#     967,
#     206,
#     966,
#     205]]},
#  {'id': '1000015',
#   'image_id': 0,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 796,
#   'bbox': [984.6376342773438,
#    217.3634490966797,
#    40.92999267578125,
#    61.22425842285156],
#   'segmentation': [[1001,
#     222,
#     1000,
#     223,
#     1000,
#     224,
#     999,
#     225,
#     999,
#     228,
#     997,
#     230,
#     995,
#     228,
#     995,
#     227,
#     992,
#     227,
#     992,
#     229,
#     993,
#     230,
#     993,
#     231,
#     994,
#     232,
#     994,
#     233,
#     995,
#     234,
#     995,
#     237,
#     996,
#     238,
#     996,
#     239,
#     997,
#     240,
#     997,
#     254,
#     998,
#     255,
#     998,
#     259,
#     999,
#     260,
#     999,
#     261,
#     1000,
#     261,
#     1001,
#     260,
#     1002,
#     260,
#     1003,
#     259,
#     1004,
#     259,
#     1005,
#     258,
#     1006,
#     258,
#     1007,
#     257,
#     1018,
#     257,
#     1022,
#     253,
#     1022,
#     252,
#     1023,
#     251,
#     1023,
#     249,
#     1022,
#     248,
#     1022,
#     247,
#     1021,
#     246,
#     1021,
#     245,
#     1020,
#     244,
#     1020,
#     243,
#     1019,
#     242,
#     1019,
#     240,
#     1018,
#     239,
#     1018,
#     237,
#     1017,
#     236,
#     1017,
#     231,
#     1014,
#     228,
#     1013,
#     228,
#     1012,
#     227,
#     1011,
#     227,
#     1010,
#     226,
#     1008,
#     226,
#     1007,
#     225,
#     1006,
#     225,
#     1004,
#     223,
#     1003,
#     223,
#     1002,
#     222]]},
#  {'id': '100010',
#   'image_id': 1,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 477,
#   'bbox': [388.8900451660156,
#    181.3492431640625,
#    33.968505859375,
#    19.488235473632812],
#   'segmentation': [[402,
#     182,
#     401,
#     183,
#     399,
#     183,
#     398,
#     184,
#     397,
#     184,
#     395,
#     186,
#     394,
#     186,
#     390,
#     190,
#     390,
#     193,
#     389,
#     194,
#     389,
#     195,
#     390,
#     196,
#     390,
#     197,
#     391,
#     198,
#     392,
#     198,
#     393,
#     199,
#     394,
#     198,
#     419,
#     198,
#     420,
#     197,
#     420,
#     196,
#     421,
#     195,
#     421,
#     189,
#     420,
#     188,
#     420,
#     187,
#     419,
#     186,
#     419,
#     185,
#     418,
#     184,
#     417,
#     184,
#     416,
#     183,
#     415,
#     183,
#     414,
#     182]]},
#  {'id': '100011',
#   'image_id': 1,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 122,
#   'bbox': [512.3601684570312,
#    176.158447265625,
#    16.78118896484375,
#    10.353790283203125],
#   'segmentation': [[517,
#     177,
#     516,
#     178,
#     515,
#     178,
#     514,
#     179,
#     514,
#     180,
#     513,
#     181,
#     513,
#     185,
#     526,
#     185,
#     528,
#     183,
#     528,
#     182,
#     527,
#     181,
#     527,
#     180,
#     524,
#     177]]},
#  {'id': '100012',
#   'image_id': 1,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 98,
#   'bbox': [558.1759033203125,
#    175.69100952148438,
#    16.991455078125,
#    8.78460693359375],
#   'segmentation': [[561,
#     177,
#     560,
#     178,
#     560,
#     179,
#     559,
#     180,
#     559,
#     182,
#     560,
#     183,
#     570,
#     183,
#     571,
#     182,
#     573,
#     182,
#     573,
#     181,
#     574,
#     180,
#     574,
#     179,
#     572,
#     177]]},
#  {'id': '100013',
#   'image_id': 1,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 80,
#   'bbox': [532.0996704101562,
#    175.10205078125,
#    11.90802001953125,
#    9.93896484375],
#   'segmentation': [[535,
#     176,
#     534,
#     177,
#     534,
#     180,
#     533,
#     181,
#     533,
#     183,
#     534,
#     184,
#     541,
#     184,
#     543,
#     182,
#     543,
#     181,
#     542,
#     180,
#     542,
#     178,
#     541,
#     177,
#     540,
#     177,
#     539,
#     176]]},
#  {'id': '100020',
#   'image_id': 2,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 1079,
#   'bbox': [658.9513549804688,
#    191.5946502685547,
#    43.35980224609375,
#    32.073577880859375],
#   'segmentation': [[670,
#     192,
#     669,
#     193,
#     667,
#     193,
#     666,
#     194,
#     666,
#     195,
#     665,
#     196,
#     665,
#     197,
#     664,
#     198,
#     664,
#     199,
#     662,
#     201,
#     662,
#     202,
#     661,
#     203,
#     661,
#     204,
#     660,
#     205,
#     660,
#     208,
#     659,
#     209,
#     659,
#     214,
#     660,
#     215,
#     660,
#     218,
#     662,
#     220,
#     663,
#     220,
#     664,
#     221,
#     668,
#     221,
#     669,
#     220,
#     673,
#     220,
#     674,
#     219,
#     687,
#     219,
#     688,
#     220,
#     689,
#     220,
#     690,
#     221,
#     695,
#     221,
#     696,
#     220,
#     698,
#     220,
#     700,
#     218,
#     700,
#     212,
#     701,
#     211,
#     701,
#     210,
#     700,
#     209,
#     700,
#     203,
#     699,
#     202,
#     699,
#     201,
#     698,
#     200,
#     698,
#     199,
#     697,
#     198,
#     697,
#     197,
#     694,
#     194,
#     692,
#     194,
#     691,
#     193,
#     684,
#     193,
#     683,
#     192]]},
#  {'id': '100030',
#   'image_id': 3,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 8121,
#   'bbox': [614.6173706054688,
#    184.55429077148438,
#    109.1907958984375,
#    98.55224609375],
#   'segmentation': [[641,
#     186,
#     640,
#     187,
#     635,
#     187,
#     634,
#     188,
#     632,
#     188,
#     627,
#     193,
#     627,
#     194,
#     626,
#     195,
#     626,
#     198,
#     625,
#     199,
#     625,
#     200,
#     624,
#     201,
#     624,
#     202,
#     623,
#     203,
#     623,
#     207,
#     622,
#     208,
#     622,
#     211,
#     621,
#     212,
#     621,
#     214,
#     620,
#     215,
#     620,
#     218,
#     619,
#     219,
#     619,
#     222,
#     618,
#     223,
#     618,
#     236,
#     617,
#     237,
#     617,
#     243,
#     616,
#     244,
#     616,
#     256,
#     615,
#     257,
#     615,
#     269,
#     616,
#     270,
#     616,
#     276,
#     617,
#     277,
#     617,
#     278,
#     618,
#     279,
#     618,
#     280,
#     619,
#     281,
#     628,
#     281,
#     633,
#     276,
#     633,
#     275,
#     634,
#     274,
#     634,
#     273,
#     637,
#     270,
#     638,
#     270,
#     639,
#     269,
#     641,
#     269,
#     642,
#     268,
#     649,
#     268,
#     650,
#     267,
#     660,
#     267,
#     661,
#     266,
#     682,
#     266,
#     683,
#     267,
#     685,
#     267,
#     686,
#     268,
#     688,
#     268,
#     689,
#     269,
#     692,
#     269,
#     693,
#     270,
#     696,
#     270,
#     697,
#     271,
#     698,
#     271,
#     699,
#     272,
#     700,
#     272,
#     701,
#     273,
#     702,
#     273,
#     704,
#     275,
#     705,
#     275,
#     706,
#     276,
#     708,
#     276,
#     709,
#     277,
#     714,
#     277,
#     715,
#     276,
#     716,
#     276,
#     717,
#     275,
#     718,
#     275,
#     718,
#     274,
#     719,
#     273,
#     719,
#     271,
#     720,
#     270,
#     720,
#     266,
#     721,
#     265,
#     721,
#     254,
#     720,
#     253,
#     720,
#     246,
#     719,
#     245,
#     719,
#     236,
#     718,
#     235,
#     718,
#     232,
#     717,
#     231,
#     717,
#     230,
#     716,
#     229,
#     716,
#     226,
#     715,
#     225,
#     715,
#     224,
#     714,
#     223,
#     714,
#     222,
#     713,
#     221,
#     713,
#     220,
#     712,
#     219,
#     712,
#     215,
#     711,
#     214,
#     711,
#     212,
#     709,
#     210,
#     709,
#     209,
#     708,
#     208,
#     708,
#     207,
#     707,
#     206,
#     707,
#     204,
#     704,
#     201,
#     704,
#     200,
#     703,
#     199,
#     703,
#     198,
#     700,
#     195,
#     700,
#     194,
#     694,
#     188,
#     692,
#     188,
#     691,
#     187,
#     686,
#     187,
#     685,
#     186]]},
#  {'id': '100031',
#   'image_id': 3,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 17690,
#   'bbox': [0.0, 246.056396484375, 203.9627685546875, 126.00115966796875],
#   'segmentation': [[52,
#     249,
#     51,
#     250,
#     8,
#     250,
#     7,
#     251,
#     4,
#     251,
#     1,
#     254,
#     1,
#     256,
#     0,
#     257,
#     0,
#     336,
#     1,
#     337,
#     1,
#     365,
#     2,
#     366,
#     2,
#     369,
#     3,
#     369,
#     4,
#     370,
#     195,
#     370,
#     196,
#     369,
#     199,
#     369,
#     199,
#     368,
#     200,
#     367,
#     200,
#     364,
#     198,
#     362,
#     198,
#     361,
#     192,
#     355,
#     191,
#     355,
#     190,
#     354,
#     189,
#     354,
#     186,
#     351,
#     184,
#     351,
#     183,
#     350,
#     182,
#     350,
#     181,
#     349,
#     180,
#     349,
#     179,
#     348,
#     178,
#     348,
#     177,
#     347,
#     176,
#     347,
#     175,
#     346,
#     174,
#     346,
#     173,
#     345,
#     171,
#     345,
#     170,
#     344,
#     169,
#     344,
#     168,
#     343,
#     167,
#     343,
#     165,
#     341,
#     164,
#     341,
#     159,
#     336,
#     159,
#     335,
#     158,
#     334,
#     158,
#     333,
#     157,
#     333,
#     154,
#     330,
#     154,
#     329,
#     152,
#     327,
#     152,
#     326,
#     151,
#     325,
#     151,
#     324,
#     146,
#     319,
#     146,
#     317,
#     145,
#     316,
#     145,
#     315,
#     144,
#     314,
#     144,
#     313,
#     143,
#     312,
#     143,
#     311,
#     138,
#     306,
#     138,
#     305,
#     137,
#     304,
#     137,
#     303,
#     136,
#     302,
#     136,
#     301,
#     135,
#     300,
#     134,
#     300,
#     132,
#     298,
#     132,
#     297,
#     131,
#     296,
#     131,
#     295,
#     130,
#     294,
#     130,
#     293,
#     129,
#     292,
#     129,
#     291,
#     124,
#     286,
#     124,
#     285,
#     123,
#     284,
#     123,
#     281,
#     122,
#     280,
#     122,
#     278,
#     120,
#     276,
#     120,
#     275,
#     117,
#     272,
#     117,
#     270,
#     116,
#     269,
#     116,
#     267,
#     115,
#     266,
#     115,
#     265,
#     114,
#     264,
#     114,
#     263,
#     107,
#     256,
#     106,
#     256,
#     105,
#     255,
#     103,
#     255,
#     102,
#     254,
#     100,
#     254,
#     99,
#     253,
#     97,
#     253,
#     96,
#     252,
#     94,
#     252,
#     93,
#     251,
#     86,
#     251,
#     85,
#     250,
#     72,
#     250,
#     71,
#     249]]},
#  {'id': '100032',
#   'image_id': 3,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 189,
#   'bbox': [526.3030395507812,
#    206.3096160888672,
#    17.63671875,
#    14.320999145507812],
#   'segmentation': [[532,
#     207,
#     531,
#     208,
#     530,
#     208,
#     528,
#     210,
#     528,
#     211,
#     527,
#     212,
#     527,
#     217,
#     529,
#     219,
#     542,
#     219,
#     542,
#     218,
#     543,
#     217,
#     543,
#     214,
#     542,
#     213,
#     542,
#     211,
#     541,
#     210,
#     541,
#     209,
#     540,
#     208,
#     539,
#     208,
#     538,
#     207]]},
#  {'id': '100033',
#   'image_id': 3,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 89,
#   'bbox': [607.1981811523438,
#    211.8882293701172,
#    13.0582275390625,
#    9.484222412109375],
#   'segmentation': [[610,
#     213,
#     609,
#     214,
#     608,
#     214,
#     608,
#     218,
#     610,
#     220,
#     618,
#     220,
#     619,
#     219,
#     619,
#     214,
#     618,
#     213]]},
#  {'id': '100040',
#   'image_id': 4,
#   'category_id': 1,
#   'iscrowd': 0,
#   'area': 1417,
#   'bbox': [1211.300537109375,
#    263.96844482421875,
#    30.699462890625,
#    62.8907470703125],
#   'segmentation': [[1225,
#     265,
#     1224,
#     266,
#     1224,
#     268,
#     1223,
#     269,
#     1223,
#     272,
#     1222,
#     273,
#     1222,
#     274,
#     1221,
#     275,
#     1221,
#     276,
#     1220,
#     277,
#     1220,
#     278,
#     1215,
#     283,
#     1215,
#     284,
#     1214,
#     285,
#     1214,
#     286,
#     1213,
#     287,
#     1213,
#     289,
#     1212,
#     290,
#     1212,
#     304,
#     1213,
#     305,
#     1213,
#     307,
#     1214,
#     308,
#     1214,
#     310,
#     1216,
#     312,
#     1216,
#     313,
#     1217,
#     314,
#     1217,
#     315,
#     1220,
#     318,
#     1221,
#     318,
#     1224,
#     321,
#     1225,
#     321,
#     1227,
#     323,
#     1228,
#     323,
#     1229,
#     324,
#     1230,
#     324,
#     1231,
#     325,
#     1241,
#     325,
#     1241,
#     276,
#     1240,
#     275,
#     1240,
#     274,
#     1239,
#     274,
#     1238,
#     273,
#     1236,
#     273,
#     1235,
#     272,
#     1234,
#     272,
#     1232,
#     270,
#     1232,
#     269,
#     1231,
#     268,
#     1231,
#     267,
#     1230,
#     267,
#     1228,
#     265]]},
#  {'id': '100041',
#   'image_id': 4,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 1319,
#   'bbox': [281.0668029785156,
#    184.41847229003906,
#    61.97662353515625,
#    28.82012939453125],
#   'segmentation': [[307,
#     185,
#     306,
#     186,
#     300,
#     186,
#     299,
#     187,
#     298,
#     187,
#     292,
#     193,
#     291,
#     193,
#     287,
#     197,
#     286,
#     197,
#     282,
#     201,
#     282,
#     203,
#     281,
#     204,
#     281,
#     205,
#     282,
#     206,
#     282,
#     208,
#     284,
#     210,
#     310,
#     210,
#     311,
#     211,
#     320,
#     211,
#     321,
#     210,
#     323,
#     210,
#     324,
#     209,
#     326,
#     209,
#     327,
#     208,
#     332,
#     208,
#     333,
#     209,
#     334,
#     209,
#     335,
#     210,
#     339,
#     210,
#     340,
#     209,
#     340,
#     208,
#     341,
#     207,
#     341,
#     204,
#     342,
#     203,
#     342,
#     201,
#     341,
#     200,
#     341,
#     197,
#     340,
#     196,
#     340,
#     195,
#     336,
#     191,
#     336,
#     190,
#     333,
#     187,
#     332,
#     187,
#     331,
#     186,
#     326,
#     186,
#     325,
#     185]]},
#  {'id': '100042',
#   'image_id': 4,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 603,
#   'bbox': [366.32708740234375,
#    182.6038055419922,
#    37.340301513671875,
#    21.761367797851562],
#   'segmentation': [[382,
#     183,
#     381,
#     184,
#     377,
#     184,
#     376,
#     185,
#     375,
#     185,
#     368,
#     192,
#     368,
#     193,
#     367,
#     194,
#     367,
#     201,
#     368,
#     202,
#     368,
#     203,
#     371,
#     203,
#     372,
#     202,
#     373,
#     202,
#     374,
#     201,
#     382,
#     201,
#     383,
#     202,
#     393,
#     202,
#     394,
#     201,
#     397,
#     201,
#     398,
#     202,
#     401,
#     202,
#     402,
#     201,
#     402,
#     192,
#     401,
#     191,
#     401,
#     190,
#     397,
#     186,
#     396,
#     186,
#     394,
#     184,
#     390,
#     184,
#     389,
#     183]]},
#  {'id': '100043',
#   'image_id': 4,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 505,
#   'bbox': [404.2193298339844,
#    173.1184844970703,
#    31.511322021484375,
#    19.90130615234375],
#   'segmentation': [[411,
#     174,
#     408,
#     177,
#     408,
#     178,
#     406,
#     180,
#     406,
#     181,
#     405,
#     182,
#     405,
#     189,
#     406,
#     190,
#     410,
#     190,
#     411,
#     191,
#     415,
#     191,
#     416,
#     192,
#     419,
#     192,
#     420,
#     191,
#     432,
#     191,
#     433,
#     190,
#     434,
#     190,
#     434,
#     177,
#     433,
#     176,
#     433,
#     175,
#     432,
#     175,
#     431,
#     174]]},
#  {'id': '100044',
#   'image_id': 4,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 301,
#   'bbox': [450.1189880371094,
#    177.09857177734375,
#    23.071014404296875,
#    16.281234741210938],
#   'segmentation': [[454,
#     178,
#     453,
#     179,
#     452,
#     179,
#     452,
#     180,
#     451,
#     181,
#     451,
#     190,
#     453,
#     192,
#     470,
#     192,
#     471,
#     191,
#     471,
#     190,
#     472,
#     189,
#     472,
#     184,
#     471,
#     183,
#     471,
#     181,
#     470,
#     180,
#     469,
#     180,
#     468,
#     179,
#     465,
#     179,
#     464,
#     178]]},
#  {'id': '100045',
#   'image_id': 4,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 111,
#   'bbox': [549.8102416992188,
#    178.42332458496094,
#    16.60516357421875,
#    9.896636962890625],
#   'segmentation': [[559,
#     179,
#     558,
#     180,
#     553,
#     180,
#     552,
#     181,
#     551,
#     181,
#     551,
#     186,
#     552,
#     186,
#     553,
#     187,
#     560,
#     187,
#     561,
#     186,
#     564,
#     186,
#     565,
#     185,
#     565,
#     181,
#     564,
#     180,
#     561,
#     180,
#     560,
#     179]]},
#  {'id': '100050',
#   'image_id': 5,
#   'category_id': 0,
#   'iscrowd': 0,
#   'area': 816,
#   'bbox': [329.22265625,
#    181.06808471679688,
#    27.388519287109375,
#    56.34831237792969],
#   'segmentation': [[343,
#     182,
#     342,
#     183,
#     341,
#     183,
#     341,
#     184,
#     340,
#     185,
#     340,
#     186,
#     334,
#     192,
#     334,
#     193,
#     333,
#     194,
#     333,
#     196,
#     332,
#     197,
#     332,
#     199,
#     331,
#     200,
#     331,
#     202,
#     330,
#     203,
#     330,
#     210,
#     334,
#     210,
#     336,
#     212,
#     336,
#     213,
#     337,
#     214,
#     337,
#     217,
#     338,
#     218,
#     338,
#     221,
#     339,
#     222,
#     339,
#     223,
#     340,
#     224,
#     340,
#     225,
#     341,
#     226,
#     341,
#     227,
#     342,
#     228,
#     342,
#     229,
#     343,
#     230,
#     343,
#     234,
#     344,
#     235,
#     344,
#     236,
#     348,
#     236,
#     349,
#     235,
#     349,
#     220,
#     350,
#     219,
#     350,
#     218,
#     351,
#     217,
#     351,
#     215,
#     352,
#     214,
#     352,
#     213,
#     353,
#     212,
#     353,
#     206,
#     354,
#     205,
#     354,
#     196,
#     353,
#     195,
#     353,
#     194,
#     352,
#     193,
#     352,
#     192,
#     351,
#     191,
#     350,
#     191,
#     347,
#     188,
#     347,
#     187,
#     346,
#     186,
#     346,
#     183,
#     345,
#     182]]},
#  {'id': '100051',
#   'image_id': 5,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 151,
#   'bbox': [607.0225830078125,
#    171.5962371826172,
#    13.61981201171875,
#    13.525726318359375],
#   'segmentation': [[610,
#     172,
#     608,
#     174,
#     608,
#     176,
#     607,
#     177,
#     607,
#     181,
#     608,
#     182,
#     608,
#     183,
#     609,
#     184,
#     617,
#     184,
#     619,
#     182,
#     619,
#     174,
#     617,
#     172]]},
#  {'id': '100060',
#   'image_id': 6,
#   'category_id': 0,
#   'iscrowd': 0,
#   'area': 139,
#   'bbox': [648.7214965820312,
#    172.6647186279297,
#    9.1282958984375,
#    26.399765014648438],
#   'segmentation': [[652,
#     174,
#     652,
#     175,
#     651,
#     176,
#     651,
#     179,
#     650,
#     180,
#     650,
#     189,
#     651,
#     190,
#     651,
#     197,
#     653,
#     197,
#     654,
#     198,
#     655,
#     197,
#     655,
#     189,
#     656,
#     188,
#     656,
#     178,
#     655,
#     177,
#     655,
#     175,
#     654,
#     174]]},
#  {'id': '100061',
#   'image_id': 6,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 7143,
#   'bbox': [43.945068359375,
#    185.84548950195312,
#    178.9008331298828,
#    58.33113098144531],
#   'segmentation': [[109,
#     187,
#     108,
#     188,
#     85,
#     188,
#     84,
#     189,
#     76,
#     189,
#     75,
#     190,
#     69,
#     190,
#     68,
#     191,
#     66,
#     191,
#     65,
#     192,
#     63,
#     192,
#     62,
#     193,
#     60,
#     193,
#     59,
#     194,
#     58,
#     194,
#     51,
#     201,
#     51,
#     202,
#     50,
#     203,
#     50,
#     204,
#     49,
#     205,
#     49,
#     207,
#     48,
#     208,
#     48,
#     209,
#     47,
#     210,
#     47,
#     212,
#     46,
#     213,
#     46,
#     216,
#     45,
#     217,
#     45,
#     227,
#     48,
#     230,
#     49,
#     230,
#     50,
#     231,
#     51,
#     231,
#     52,
#     232,
#     54,
#     232,
#     55,
#     233,
#     57,
#     233,
#     58,
#     234,
#     59,
#     234,
#     60,
#     235,
#     61,
#     235,
#     63,
#     237,
#     63,
#     238,
#     65,
#     240,
#     66,
#     240,
#     67,
#     241,
#     69,
#     241,
#     70,
#     242,
#     83,
#     242,
#     84,
# ...
#     1003,
#     259,
#     1004,
#     258,
#     1005,
#     258,
#     1006,
#     257,
#     1017,
#     257,
#     1018,
#     256,
#     1019,
#     256,
#     1022,
#     253,
#     1022,
#     251,
#     1023,
#     250,
#     1023,
#     249,
#     1022,
#     248,
#     1022,
#     247,
#     1021,
#     246,
#     1021,
#     245,
#     1020,
#     244,
#     1020,
#     243,
#     1019,
#     242,
#     1019,
#     241,
#     1018,
#     240,
#     1018,
#     238,
#     1017,
#     237,
#     1017,
#     232,
#     1013,
#     228,
#     1012,
#     228,
#     1011,
#     227,
#     1009,
#     227,
#     1008,
#     226,
#     1007,
#     226,
#     1005,
#     224,
#     1004,
#     224,
#     1003,
#     223]]},
#  {'id': '1013100',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 5061,
#   'bbox': [208.0738067626953,
#    183.34283447265625,
#    115.26179504394531,
#    56.996673583984375],
#   'segmentation': [[267,
#     184,
#     266,
#     185,
#     254,
#     185,
#     253,
#     186,
#     250,
#     186,
#     249,
#     187,
#     247,
#     187,
#     246,
#     188,
#     244,
#     188,
#     243,
#     189,
#     240,
#     189,
#     239,
#     190,
#     236,
#     190,
#     235,
#     191,
#     232,
#     191,
#     231,
#     192,
#     229,
#     192,
#     228,
#     193,
#     227,
#     193,
#     226,
#     194,
#     225,
#     194,
#     224,
#     195,
#     223,
#     195,
#     222,
#     196,
#     221,
#     196,
#     212,
#     205,
#     212,
#     206,
#     211,
#     207,
#     211,
#     208,
#     210,
#     209,
#     210,
#     210,
#     209,
#     211,
#     209,
#     225,
#     210,
#     226,
#     210,
#     227,
#     211,
#     227,
#     213,
#     229,
#     214,
#     229,
#     215,
#     230,
#     216,
#     230,
#     217,
#     231,
#     218,
#     231,
#     222,
#     235,
#     223,
#     235,
#     226,
#     238,
#     229,
#     238,
#     230,
#     239,
#     231,
#     238,
#     235,
#     238,
#     239,
#     234,
#     240,
#     234,
#     241,
#     233,
#     253,
#     233,
#     254,
#     234,
#     255,
#     234,
#     256,
#     235,
#     257,
#     235,
#     258,
#     236,
#     259,
#     236,
#     260,
#     237,
#     269,
#     237,
#     270,
#     236,
#     272,
#     236,
#     273,
#     235,
#     275,
#     235,
#     276,
#     234,
#     278,
#     234,
#     279,
#     233,
#     281,
#     233,
#     282,
#     232,
#     285,
#     232,
#     286,
#     231,
#     299,
#     231,
#     300,
#     232,
#     305,
#     232,
#     306,
#     231,
#     312,
#     231,
#     313,
#     230,
#     317,
#     230,
#     321,
#     226,
#     321,
#     216,
#     320,
#     215,
#     320,
#     204,
#     319,
#     203,
#     319,
#     200,
#     318,
#     199,
#     318,
#     196,
#     315,
#     193,
#     315,
#     192,
#     312,
#     189,
#     311,
#     189,
#     309,
#     187,
#     308,
#     187,
#     307,
#     186,
#     306,
#     186,
#     305,
#     185,
#     302,
#     185,
#     301,
#     184]]},
#  {'id': '1013101',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 2546,
#   'bbox': [440.08349609375,
#    176.6537322998047,
#    88.784912109375,
#    41.013458251953125],
#   'segmentation': [[460,
#     178,
#     459,
#     179,
#     457,
#     179,
#     456,
#     180,
#     455,
#     180,
#     454,
#     181,
#     453,
#     181,
#     450,
#     184,
#     450,
#     185,
#     447,
#     188,
#     447,
#     189,
#     446,
#     190,
#     446,
#     191,
#     445,
#     192,
#     445,
#     193,
#     444,
#     194,
#     444,
#     196,
#     443,
#     197,
#     443,
#     209,
#     444,
#     210,
#     444,
#     211,
#     446,
#     213,
#     446,
#     214,
#     448,
#     216,
#     453,
#     216,
#     458,
#     211,
#     460,
#     211,
#     461,
#     210,
#     466,
#     210,
#     467,
#     211,
#     473,
#     211,
#     475,
#     213,
#     476,
#     213,
#     477,
#     214,
#     478,
#     214,
#     479,
#     215,
#     486,
#     215,
#     487,
#     214,
#     489,
#     214,
#     491,
#     212,
#     493,
#     212,
#     494,
#     211,
#     497,
#     211,
#     498,
#     210,
#     513,
#     210,
#     514,
#     211,
#     516,
#     211,
#     517,
#     212,
#     520,
#     212,
#     522,
#     210,
#     523,
#     210,
#     524,
#     209,
#     524,
#     208,
#     525,
#     207,
#     525,
#     203,
#     526,
#     202,
#     526,
#     197,
#     522,
#     193,
#     521,
#     193,
#     518,
#     190,
#     517,
#     190,
#     513,
#     186,
#     512,
#     186,
#     510,
#     184,
#     509,
#     184,
#     508,
#     183,
#     506,
#     183,
#     505,
#     182,
#     504,
#     182,
#     503,
#     181,
#     501,
#     181,
#     500,
#     180,
#     498,
#     180,
#     497,
#     179,
#     490,
#     179,
#     489,
#     178]]},
#  {'id': '1013102',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 1058,
#   'bbox': [575.6029663085938,
#    176.0762481689453,
#    51.91961669921875,
#    26.9453125],
#   'segmentation': [[591,
#     177,
#     590,
#     178,
#     588,
#     178,
#     587,
#     179,
#     586,
#     179,
#     584,
#     181,
#     583,
#     181,
#     577,
#     187,
#     577,
#     188,
#     576,
#     189,
#     576,
#     196,
#     577,
#     197,
#     577,
#     199,
#     578,
#     200,
#     578,
#     201,
#     584,
#     201,
#     585,
#     200,
#     586,
#     200,
#     587,
#     199,
#     589,
#     199,
#     590,
#     200,
#     594,
#     200,
#     595,
#     201,
#     605,
#     201,
#     606,
#     200,
#     611,
#     200,
#     612,
#     199,
#     620,
#     199,
#     621,
#     200,
#     622,
#     200,
#     623,
#     199,
#     624,
#     199,
#     625,
#     198,
#     625,
#     197,
#     626,
#     196,
#     626,
#     188,
#     623,
#     185,
#     622,
#     185,
#     620,
#     183,
#     619,
#     183,
#     616,
#     180,
#     615,
#     180,
#     613,
#     178,
#     612,
#     178,
#     611,
#     177]]},
#  {'id': '1013103',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 340,
#   'bbox': [710.8409423828125,
#    171.16424560546875,
#    24.7127685546875,
#    18.855117797851562],
#   'segmentation': [[717,
#     172,
#     716,
#     173,
#     715,
#     173,
#     713,
#     175,
#     713,
#     176,
#     712,
#     177,
#     712,
#     187,
#     713,
#     188,
#     718,
#     188,
#     719,
#     187,
#     727,
#     187,
#     728,
#     188,
#     733,
#     188,
#     733,
#     187,
#     734,
#     186,
#     734,
#     182,
#     733,
#     181,
#     733,
#     178,
#     732,
#     177,
#     732,
#     176,
#     729,
#     173,
#     728,
#     173,
#     727,
#     172]]},
#  {'id': '1013104',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 247,
#   'bbox': [1119.0328369140625,
#    162.94766235351562,
#    29.5902099609375,
#    12.039505004882812],
#   'segmentation': [[1135,
#     163,
#     1134,
#     164,
#     1127,
#     164,
#     1122,
#     169,
#     1122,
#     170,
#     1120,
#     172,
#     1120,
#     174,
#     1126,
#     174,
#     1127,
#     173,
#     1144,
#     173,
#     1145,
#     172,
#     1145,
#     171,
#     1146,
#     170,
#     1146,
#     168,
#     1147,
#     167,
#     1146,
#     166,
#     1146,
#     165,
#     1145,
#     165,
#     1144,
#     164,
#     1140,
#     164,
#     1139,
#     163]]},
#  {'id': '1013105',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 217,
#   'bbox': [730.494384765625,
#    168.78131103515625,
#    17.91552734375,
#    17.519866943359375],
#   'segmentation': [[733,
#     169,
#     732,
#     170,
#     731,
#     170,
#     731,
#     172,
#     732,
#     173,
#     732,
#     174,
#     733,
#     175,
#     733,
#     177,
#     734,
#     178,
#     734,
#     180,
#     735,
#     181,
#     735,
#     182,
#     736,
#     183,
#     736,
#     184,
#     741,
#     184,
#     742,
#     185,
#     745,
#     185,
#     746,
#     184,
#     746,
#     183,
#     747,
#     182,
#     747,
#     177,
#     746,
#     176,
#     746,
#     174,
#     745,
#     173,
#     745,
#     172,
#     743,
#     170,
#     742,
#     170,
#     741,
#     169]]},
#  {'id': '1013106',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 402,
#   'bbox': [564.2223510742188,
#    170.3672637939453,
#    37.95257568359375,
#    24.654647827148438],
#   'segmentation': [[577,
#     171,
#     576,
#     172,
#     572,
#     172,
#     569,
#     175,
#     569,
#     176,
#     566,
#     179,
#     566,
#     180,
#     565,
#     181,
#     565,
#     187,
#     566,
#     188,
#     566,
#     192,
#     567,
#     193,
#     572,
#     193,
#     576,
#     189,
#     576,
#     188,
#     578,
#     186,
#     578,
#     185,
#     581,
#     182,
#     582,
#     182,
#     586,
#     178,
#     587,
#     178,
#     589,
#     176,
#     596,
#     176,
#     597,
#     175,
#     598,
#     175,
#     598,
#     173,
#     597,
#     172,
#     593,
#     172,
#     592,
#     171]]},
#  {'id': '1013107',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 185,
#   'bbox': [1101.7122802734375,
#    162.13327026367188,
#    22.6497802734375,
#    12.070892333984375],
#   'segmentation': [[1108,
#     163,
#     1107,
#     164,
#     1106,
#     164,
#     1105,
#     165,
#     1105,
#     166,
#     1104,
#     167,
#     1104,
#     168,
#     1103,
#     169,
#     1103,
#     173,
#     1117,
#     173,
#     1119,
#     171,
#     1119,
#     170,
#     1120,
#     169,
#     1120,
#     168,
#     1121,
#     167,
#     1121,
#     166,
#     1122,
#     165,
#     1122,
#     163]]},
#  {'id': '1013108',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 2773,
#   'bbox': [0.6074085235595703,
#    168.47544860839844,
#    72.7006664276123,
#    52.504486083984375],
#   'segmentation': [[4,
#     170,
#     2,
#     172,
#     2,
#     173,
#     1,
#     174,
#     1,
#     208,
#     2,
#     209,
#     2,
#     213,
#     4,
#     215,
#     13,
#     215,
#     14,
#     214,
#     24,
#     214,
#     25,
#     215,
#     26,
#     215,
#     27,
#     216,
#     28,
#     216,
#     30,
#     218,
#     31,
#     217,
#     32,
#     217,
#     36,
#     213,
#     49,
#     213,
#     50,
#     214,
#     51,
#     214,
#     52,
#     215,
#     53,
#     215,
#     54,
#     216,
#     55,
#     216,
#     56,
#     217,
#     57,
#     217,
#     58,
#     218,
#     64,
#     218,
#     65,
#     217,
#     66,
#     217,
#     68,
#     215,
#     69,
#     215,
#     69,
#     213,
#     70,
#     212,
#     70,
#     203,
#     69,
#     202,
#     69,
#     199,
#     68,
#     198,
#     67,
#     198,
#     63,
#     194,
#     61,
#     194,
#     59,
#     196,
#     58,
#     196,
#     57,
#     195,
#     57,
#     193,
#     56,
#     192,
#     56,
#     179,
#     55,
#     178,
#     55,
#     177,
#     54,
#     176,
#     54,
#     175,
#     53,
#     174,
#     51,
#     174,
#     50,
#     173,
#     48,
#     173,
#     47,
#     172,
#     41,
#     172,
#     40,
#     171,
#     36,
#     171,
#     35,
#     170]]},
#  {'id': '1013109',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 196,
#   'bbox': [1059.9364013671875,
#    163.250244140625,
#    21.8980712890625,
#    12.807647705078125],
#   'segmentation': [[1068,
#     164,
#     1067,
#     165,
#     1066,
#     165,
#     1063,
#     168,
#     1063,
#     169,
#     1062,
#     170,
#     1062,
#     171,
#     1061,
#     172,
#     1061,
#     175,
#     1065,
#     175,
#     1066,
#     174,
#     1067,
#     174,
#     1068,
#     175,
#     1075,
#     175,
#     1076,
#     174,
#     1078,
#     174,
#     1079,
#     173,
#     1079,
#     164]]},
#  {'id': '1013110',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 217,
#   'bbox': [1079.43359375,
#    163.11317443847656,
#    24.8232421875,
#    11.948318481445312],
#   'segmentation': [[1087,
#     164,
#     1084,
#     167,
#     1083,
#     167,
#     1083,
#     168,
#     1082,
#     169,
#     1082,
#     170,
#     1081,
#     171,
#     1081,
#     174,
#     1100,
#     174,
#     1101,
#     173,
#     1101,
#     172,
#     1102,
#     171,
#     1102,
#     164]]},
#  {'id': '1013111',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 225,
#   'bbox': [1042.5042724609375,
#    162.00323486328125,
#    22.5968017578125,
#    14.023529052734375],
#   'segmentation': [[1049,
#     163,
#     1048,
#     164,
#     1047,
#     164,
#     1043,
#     168,
#     1043,
#     173,
#     1044,
#     174,
#     1044,
#     175,
#     1057,
#     175,
#     1058,
#     174,
#     1059,
#     174,
#     1059,
#     173,
#     1060,
#     172,
#     1060,
#     170,
#     1061,
#     169,
#     1061,
#     167,
#     1063,
#     165,
#     1063,
#     163]]},
#  {'id': '1013112',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 336,
#   'bbox': [987.351318359375,
#    161.95921325683594,
#    33.31219482421875,
#    13.219558715820312],
#   'segmentation': [[1007,
#     163,
#     1006,
#     164,
#     996,
#     164,
#     995,
#     165,
#     993,
#     165,
#     992,
#     166,
#     991,
#     166,
#     988,
#     169,
#     988,
#     173,
#     989,
#     173,
#     990,
#     174,
#     1016,
#     174,
#     1017,
#     173,
#     1018,
#     173,
#     1018,
#     172,
#     1019,
#     171,
#     1019,
#     165,
#     1017,
#     163]]},
#  {'id': '1013113',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 209,
#   'bbox': [1224.0885009765625,
#    159.62831115722656,
#    17.9114990234375,
#    15.286148071289062],
#   'segmentation': [[1240,
#     160,
#     1239,
#     161,
#     1235,
#     161,
#     1234,
#     162,
#     1233,
#     162,
#     1232,
#     163,
#     1230,
#     163,
#     1229,
#     164,
#     1228,
#     164,
#     1225,
#     167,
#     1225,
#     168,
#     1224,
#     169,
#     1225,
#     170,
#     1225,
#     173,
#     1226,
#     174,
#     1240,
#     174,
#     1241,
#     173,
#     1241,
#     161]]},
#  {'id': '1013114',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 203,
#   'bbox': [615.592041015625,
#    174.99725341796875,
#    26.5020751953125,
#    12.400726318359375],
#   'segmentation': [[618,
#     176,
#     616,
#     178,
#     616,
#     179,
#     617,
#     180,
#     617,
#     181,
#     618,
#     181,
#     620,
#     183,
#     622,
#     183,
#     623,
#     184,
#     625,
#     184,
#     626,
#     185,
#     628,
#     185,
#     629,
#     186,
#     639,
#     186,
#     640,
#     185,
#     640,
#     182,
#     637,
#     179,
#     636,
#     179,
#     635,
#     178,
#     634,
#     178,
#     633,
#     177,
#     630,
#     177,
#     629,
#     176]]},
#  {'id': '1013115',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 204,
#   'bbox': [833.218994140625,
#    162.99647521972656,
#    24.634521484375,
#    11.87799072265625],
#   'segmentation': [[850,
#     163,
#     849,
#     164,
#     843,
#     164,
#     842,
#     165,
#     840,
#     165,
#     838,
#     167,
#     837,
#     167,
#     835,
#     169,
#     835,
#     170,
#     834,
#     171,
#     834,
#     173,
#     835,
#     173,
#     836,
#     174,
#     843,
#     174,
#     844,
#     173,
#     854,
#     173,
#     854,
#     172,
#     855,
#     171,
#     855,
#     166,
#     856,
#     165,
#     855,
#     164,
#     854,
#     164,
#     853,
#     163]]},
#  {'id': '1013116',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 462,
#   'bbox': [1182.959228515625,
#    158.31484985351562,
#    57.43505859375,
#    17.643508911132812],
#   'segmentation': [[1233,
#     161,
#     1232,
#     162,
#     1231,
#     162,
#     1230,
#     163,
#     1228,
#     163,
#     1227,
#     164,
#     1226,
#     164,
#     1226,
#     165,
#     1225,
#     166,
#     1225,
#     167,
#     1224,
#     168,
#     1224,
#     171,
#     1225,
#     172,
#     1225,
#     173,
#     1226,
#     174,
#     1227,
#     174,
#     1228,
#     175,
#     1238,
#     175,
#     1239,
#     174,
#     1239,
#     161],
#    [1196,
#     160,
#     1195,
#     161,
#     1194,
#     161,
#     1193,
#     162,
#     1191,
#     162,
#     1190,
#     163,
#     1189,
#     163,
#     1188,
#     164,
#     1187,
#     164,
#     1185,
#     166,
#     1185,
#     173,
#     1186,
#     174,
#     1199,
#     174,
#     1200,
#     173,
#     1202,
#     173,
#     1204,
#     171,
#     1204,
#     161,
#     1203,
#     160]]},
#  {'id': '1013117',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 155,
#   'bbox': [1169.2398681640625,
#    161.05589294433594,
#    17.060302734375,
#    13.52728271484375],
#   'segmentation': [[1171,
#     162,
#     1170,
#     163,
#     1170,
#     170,
#     1171,
#     171,
#     1171,
#     172,
#     1172,
#     173,
#     1183,
#     173,
#     1184,
#     172,
#     1184,
#     168,
#     1183,
#     167,
#     1183,
#     166,
#     1181,
#     164,
#     1180,
#     164,
#     1179,
#     163,
#     1178,
#     163,
#     1177,
#     162]]},
#  {'id': '1013118',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 142,
#   'bbox': [913.7546997070312,
#    163.24632263183594,
#    19.1241455078125,
#    11.015853881835938],
#   'segmentation': [[921,
#     164,
#     920,
#     165,
#     919,
#     165,
#     918,
#     166,
#     917,
#     166,
#     915,
#     168,
#     915,
#     169,
#     914,
#     170,
#     914,
#     171,
#     915,
#     172,
#     915,
#     173,
#     927,
#     173,
#     928,
#     172,
#     929,
#     172,
#     929,
#     171,
#     930,
#     170,
#     930,
#     168,
#     931,
#     167,
#     931,
#     166,
#     930,
#     165,
#     927,
#     165,
#     926,
#     164]]},
#  {'id': '1013119',
#   'image_id': 131,
#   'category_id': 2,
#   'iscrowd': 0,
#   'area': 298,
#   'bbox': [870.49267578125,
#    163.57644653320312,
#    33.99810791015625,
#    10.677658081054688],
#   'segmentation': [[878,
#     164,
#     877,
#     165,
#     872,
#     165,
#     871,
#     166,
#     871,
#     168,
#     872,
#     169,
#     872,
#     172,
#     873,
#     173,
#     900,
#     173,
#     901,
#     172,
#     901,
#     169,
#     902,
#     168,
#     902,
#     165,
#     901,
#     165,
#     900,
#     164]]},
#  ...]

# %%
from pycocotools.coco import COCO
mask_json = '/SEE-MTDA/data/kitti/training/masks/htc/image_2.json'
htc_mask = COCO(mask_json)
# Out:
# loading annotations into memory...
# Done (t=1.34s)
# creating index...
# index created!

# %%
htcinst[0]['segmentation']
# Out:
# [[437,
#   180,
#   436,
#   181,
#   430,
#   181,
#   429,
#   182,
#   426,
#   182,
#   425,
#   183,
#   424,
#   183,
#   423,
#   184,
#   422,
#   184,
#   418,
#   188,
#   417,
#   188,
#   413,
#   192,
#   412,
#   192,
#   408,
#   196,
#   407,
#   196,
#   401,
#   202,
#   400,
#   202,
#   397,
#   205,
#   396,
#   205,
#   390,
#   211,
#   389,
#   211,
#   386,
#   214,
#   385,
#   214,
#   381,
#   218,
#   380,
#   218,
#   379,
#   219,
#   379,
#   220,
#   374,
#   225,
#   374,
#   226,
#   373,
#   227,
#   373,
#   229,
#   372,
#   230,
#   372,
#   231,
#   371,
#   232,
#   371,
#   233,
#   370,
#   234,
#   370,
#   246,
#   371,
#   247,
#   371,
#   249,
#   372,
#   250,
#   372,
#   252,
#   373,
#   253,
#   373,
#   255,
#   374,
#   256,
#   374,
#   258,
#   376,
#   260,
#   377,
#   260,
#   378,
#   261,
#   379,
#   261,
#   380,
#   262,
#   391,
#   262,
#   392,
#   261,
#   394,
#   261,
#   395,
#   260,
#   398,
#   260,
#   399,
#   259,
#   417,
#   259,
#   418,
#   260,
#   423,
#   260,
#   424,
#   261,
#   427,
#   261,
#   428,
#   262,
#   434,
#   262,
#   435,
#   263,
#   441,
#   263,
#   442,
#   264,
#   448,
#   264,
#   449,
#   265,
#   453,
#   265,
#   454,
#   266,
#   457,
#   266,
#   458,
#   267,
#   465,
#   267,
#   466,
#   266,
#   469,
#   266,
#   471,
#   264,
#   471,
#   263,
#   472,
#   262,
#   472,
#   261,
#   474,
#   259,
#   474,
#   258,
#   476,
#   256,
#   476,
#   255,
#   479,
#   252,
#   481,
#   252,
#   482,
#   251,
#   483,
#   251,
#   484,
#   250,
#   495,
#   250,
#   496,
#   249,
#   500,
#   249,
#   503,
#   246,
#   503,
#   245,
#   504,
#   244,
#   504,
#   242,
#   505,
#   241,
#   505,
#   239,
#   506,
#   238,
#   506,
#   235,
#   507,
#   234,
#   507,
#   231,
#   508,
#   230,
#   508,
#   226,
#   509,
#   225,
#   509,
#   224,
#   510,
#   223,
#   510,
#   212,
#   509,
#   211,
#   509,
#   209,
#   508,
#   208,
#   508,
#   207,
#   507,
#   206,
#   507,
#   204,
#   506,
#   203,
#   506,
#   202,
#   504,
#   200,
#   504,
#   199,
#   503,
#   198,
#   503,
#   197,
#   502,
#   196,
#   502,
#   195,
#   501,
#   194,
#   501,
#   193,
#   497,
#   189,
#   496,
#   189,
#   495,
#   188,
#   494,
#   188,
#   492,
#   186,
#   490,
#   186,
#   489,
#   185,
#   486,
#   185,
#   485,
#   184,
#   483,
#   184,
#   482,
#   183,
#   479,
#   183,
#   478,
#   182,
#   468,
#   182,
#   467,
#   181,
#   454,
#   181,
#   453,
#   180]]

# %%
idx = 876
aid = htc_mask.getAnnIds(imgIds=idx, catIds=[2])
htcinst = htc_mask.loadAnns(aid)
seg_mask = htc_mask.annToMask(htcinst[0])
print(seg_mask.shape)
print(mesher.data_obj.get_image(idx, 'image_2').shape)
# Out:
# (376, 1241)
# (376, 1241, 3)

# %%
idx = 21
camera_channel='image_2'
img = mesher.data_obj.get_image(idx, channel=camera_channel)
pc_velo = mesher.data_obj.get_pointcloud(idx, append_labels=False)
calib = mesher.data_obj.get_calibration(idx)
imgfov = mesher.data_obj.map_pointcloud_to_image(pc_velo[:,:3], calib, img, min_dist=1.0)
imgfov['img_shape'] = img.shape[:2] # H, W
instances = mesher.data_obj.get_camera_instances(idx, channel=camera_channel)

# %%
sample_idx = 28
i_clouds = mesher.data_obj.get_mask_instance_clouds(sample_idx, use_bbox=True)
# pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx, add_ground_lift=True)    
# inst_labels = mesher.data_obj.get_camera_instances(sample_idx, channel=camera_channel)

# %%
from PIL import Image
from tqdm import tqdm

camera_channel = 'image_2'

export_tag = 'bbox'
if export_tag == 'bbox':
    use_bbox = True
else:
    use_bbox = False

instance_dataset_id = 0
for sample_idx in tqdm(range(mesher.data_obj.__len__()), total=mesher.data_obj.__len__()):
    
    i_clouds = mesher.data_obj.get_mask_instance_clouds(sample_idx, use_bbox=use_bbox)
    if len(i_clouds) == 0:
        continue
    
    pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx, add_ground_lift=True)    
    inst_labels = mesher.data_obj.get_camera_instances(sample_idx, channel=camera_channel)
        
    for object_id, i_cloud in enumerate(i_clouds):
        mask_pcd = convert_to_o3dpcd(i_clouds[object_id])
        cropped_pcds, num_pts_in_gt_for_mask = [], []        
        
        if len(i_cloud) < 10:
            continue
            
        for i in range(len(pcd_gtboxes['gt_boxes'])):    
            cropped = mask_pcd.crop(pcd_gtboxes['gt_boxes'][i])
            num_pts_in_gt_for_mask.append(len(cropped.points))
            cropped_pcds.append(cropped)            
            
        if not num_pts_in_gt_for_mask or max(num_pts_in_gt_for_mask) == 0:
            labelled_pts = np.hstack([i_cloud[:,:3], np.zeros((len(i_cloud),1))])
            box_pts = np.zeros((8,3))
            num_points_in_gt = 0
        else:
            gtbox_idx = np.argmax(np.array(num_pts_in_gt_for_mask)) 
            
            cropped_np = np.array(cropped_pcds[gtbox_idx].points)
            obj_pts_labelled = np.hstack([cropped_np, 10*np.ones((len(cropped_np),1))])

            dist = mask_pcd.compute_point_cloud_distance(cropped_pcds[gtbox_idx])
            cropped_inds = np.where(np.asarray(dist) < 0.01)[0]
            mask_without_obj = np.asarray(mask_pcd.select_by_index(cropped_inds, invert=True).points)
            mask_pts_labelled = np.hstack([mask_without_obj, np.zeros((len(mask_without_obj),1))])

            labelled_pts = np.vstack([mask_pts_labelled, obj_pts_labelled])
            box_pts = np.asarray(pcd_gtboxes['gt_boxes'][gtbox_idx].get_box_points())
            num_points_in_gt = len(cropped_np)
               
        # Save pcl
        fname = f"{sample_idx:06}_{object_id:03}"
        car_dir = Path(f'{mesher.data_obj.root_dir}/exported/{mesher.data_obj.dataset_cfg.DET2D_MODEL}/lidar_seg_data_groundlift/points_in_{export_tag}/pointcloud')
        car_dir.mkdir(parents=True, exist_ok=True)
        car_fname = str(car_dir / f'{fname}.bin')
        points = np.float32(labelled_pts)
        points.tofile(car_fname)
        
        # Save points labels
        label_dir = Path(f'{mesher.data_obj.root_dir}/exported/{mesher.data_obj.dataset_cfg.DET2D_MODEL}/lidar_seg_data_groundlift/points_in_{export_tag}/labels')
        label_dir.mkdir(parents=True, exist_ok=True)
        label_fname = str(label_dir / f'{fname}.label')
        labels = np.uint32(labelled_pts[:,3])
        labels.tofile(label_fname)
        
        # Save gt bboxes
        box_dir = Path(f'{mesher.data_obj.root_dir}/exported/{mesher.data_obj.dataset_cfg.DET2D_MODEL}/lidar_seg_data_groundlift/points_in_{export_tag}/gt_bboxes')    
        box_dir.mkdir(parents=True, exist_ok=True)
        np.savetxt(str(box_dir / f'{fname}.txt'), box_pts, delimiter=' ')
        
#         # Save img - this takes a while. Not necessary for cylinder3d
#         img_dir = Path(f'{mesher.data_obj.root_dir}/exported/{mesher.data_obj.dataset_cfg.DET2D_MODEL}/lidar_seg_data_groundlift/points_in_{export_tag}/image')    
#         img_dir.mkdir(parents=True, exist_ok=True)
#         img = mesher.data_obj.get_image(sample_idx, channel=camera_channel)
#         imglabels = inst_labels[object_id]
#         ann_img = draw_lidar_on_image([], img, instances=[imglabels], display=False)
#         Image.fromarray(ann_img).save(str(img_dir / f'{fname}.png'))

        # Save original filepath of input pointcloud
        origpath_dir = Path(f'{mesher.data_obj.root_dir}/exported/{mesher.data_obj.dataset_cfg.DET2D_MODEL}/lidar_seg_data_groundlift/points_in_{export_tag}/fpath')
        origpath_dir.mkdir(parents=True, exist_ok=True)
        with open(str(origpath_dir / f'{fname}.txt'), 'w') as f:
              f.write(f'{sample_idx:06}')
        
#         print(f"car #{instance_dataset_id}: Exported {object_id+1}/{len(i_clouds)} | total pts-{len(labelled_pts)}, gt pts - {num_points_in_gt}")
        instance_dataset_id = instance_dataset_id + 1
# Out:
# 100%|█| 7481/7481 [25:27<00:00,  4.90it

# %% [markdown]
# # Import lidarseg predictions

# %%
sample_idx = 21
icloud_paths = glob.glob(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data_groundlift/points_in_bbox/icloud/*.pcd')
i_cloud = [np.asarray(o3d.io.read_point_cloud(path).points) for path in icloud_paths if  f'{sample_idx:06}_' in path]
list_mesh_instances = mesher.mesh_det_pts(i_cloud, sample_idx)
# frame_labels = [np.fromfile(paths, dtype=np.uint32).reshape((-1,1)) for paths in label_paths if f'{sample_idx:06}_' in paths]
# frame_frustums = [np.fromfile(paths, dtype=np.float32).reshape((-1,4)) for paths in frustum_paths if f'{sample_idx:06}_' in paths]
original_pcd = convert_to_o3dpcd(mesher.data_obj.get_pointcloud(sample_idx))
final_pcd = mesher.replace_pts_with_mesh_pts(original_pcd, list_mesh_instances, label_points=False, point_dist_thresh=mesher.mesher_cfg.REPLACE_OBJECT_WITH_MESH.POINT_DISTANCE_THRESH)

# %%
o3d.io.write_point_cloud('temp.pcd', convert_to_o3dpcd(final_pcd), write_ascii=False)
# Out:
# True
