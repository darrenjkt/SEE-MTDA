# %%
import sys
sys.path.append('/SEE-MTDA/see')
from sc.mesher.mesher import Mesher
import numpy as np
import os
import glob
from pathlib import Path
from sc.datasets.shared_utils import *
import open3d as o3d
from easydict import EasyDict
import yaml

def cfg_from_yaml_file(cfg_file):
    cfg = EasyDict()
    print("\n----- Cfgs -----")
    with open(cfg_file, 'r') as f:
        yaml_config = yaml.safe_load(f)
        print(yaml.dump(yaml_config))

    cfg.update(EasyDict(yaml_config))

    return cfg

cfg_file = '/SEE-MTDA/see/sc/cfgs/KIT-DM-ORH005.yaml'
cfg = cfg_from_yaml_file(cfg_file)
mesher = Mesher(cfg=cfg, cfg_path=cfg_file)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
#
# ----- Cfgs -----
# DATASET:
#   CAMERA_CHANNELS:
#   - image_2
#   CLASSES:
#   - Car
#   DET2D_MASK: true
#   DET2D_MODEL: htc
#   NAME: kitti
#   POINT_CLOUD_RANGE:
#   - -70
#   - -70
#   - -2
#   - 70
#   - 70
#   - 4
#   SHRINK_MASK_PERCENTAGE: 2
# DATA_PATH: /SEE-MTDA/data/kitti
# MESHER:
#   CLUSTERING:
#     EPS_SCALING: 5
#     NAME: db_scan
#   MESH_ALGORITHM:
#     LOWER_RADIUS: 0.01
#     NAME: ball_pivoting
#     UPPER_RADIUS: 1.155
#   MIN_LIDAR_PTS_TO_MESH: 30
#   NAME: det_mesh
#   REPLACE_OBJECT_WITH_MESH:
#     POINT_DISTANCE_THRESH: 0.1
#   SAMPLING:
#     NAME: vres_ring_based_sampling
#     OPTIMAL_RING_HEIGHT: 0.05
#     TYPE: poisson
#   VRES: 0.4
#
# Loading masks...
# loading annotations into memory...
# Done (t=0.96s)
# creating index...
# index created!
# KittiObjects initialised!
#
# Mesher Initialised!

# %% [markdown]
# # Export points in GT box

# %%
mesher.min_lidar_pts_to_mesh = 5

for sample_idx in range(mesher.data_obj.__len__()):
    pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx)

    for object_id in range(len(pcd_gtboxes['gt_boxes'])):    

        object_pcd = pcd_gtboxes['pcd'].crop(pcd_gtboxes['gt_boxes'][object_id])

        if len(object_pcd.points) < mesher.min_lidar_pts_to_mesh:
            continue

        box_pts = np.asarray(pcd_gtboxes['gt_boxes'][object_id].get_box_points())

        if mesher.data_obj.dataset_name == 'nuscenes':
            fname = f'nsweeps-{mesher.data_obj.nsweeps}_frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'
        else:
            fname = f'frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'

        car_dir = Path(f'{mesher.data_obj.root_dir}/exported/cars')
        car_dir.mkdir(parents=True, exist_ok=True)
        o3d.io.write_point_cloud(str(car_dir / f'{fname}.pcd'), object_pcd)

        box_dir = Path(f'{mesher.data_obj.root_dir}/exported/bboxes')    
        box_dir.mkdir(parents=True, exist_ok=True)
        np.savetxt(str(box_dir / f'{fname}.txt'), box_pts, delimiter=' ')

        print(f"frame-{sample_idx}: Exported {object_id}/{len(pcd_gtboxes['gt_boxes'])} | car_pts-{len(object_pcd.points)}")
# Out:
# frame-1: Exported 0/1 | car_pts-9
# frame-2: Exported 0/1 | car_pts-53
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1814/870191404.py in <module>
#       2
#       3 for sample_idx in range(mesher.data_obj.__len__()):
# ----> 4     pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx)
#       5
#       6     for object_id in range(len(pcd_gtboxes['gt_boxes'])):
#
# /SEE-MTDA/see/sc/mesher/mesher.py in get_pcd_gtboxes(self, idx, add_ground_lift)
#      77         """
#      78         sample_infos = self.data_obj.get_infos(idx)
# ---> 79         o3dpcd = convert_to_o3dpcd(self.data_obj.get_pointcloud(idx))
#      80         pcd_gtboxes = populate_gtboxes(sample_infos, self.data_obj.dataset_name, self.classes, add_ground_lift=add_ground_lift)
#      81         pcd_gtboxes['pcd'] = o3dpcd
#
# /SEE-MTDA/see/sc/datasets/shared_utils.py in convert_to_o3dpcd(points)
#     232     else:
#     233         pcd = o3d.geometry.PointCloud()
# --> 234         pcd.points = o3d.utility.Vector3dVector(points[:,:3])
#     235         return pcd
#     236
#
# KeyboardInterrupt:

# %%
sfd = []
if sfd and max(sfd) == 0:
    print('yes')

# %% [markdown]
# # Export points in mask

# %%
export_tag = 'mask'
if export_tag == 'bbox':
    use_bbox = True


for sample_idx in range(mesher.data_obj.__len__()):
    
    i_clouds = mesher.data_obj.get_mask_instance_clouds(sample_idx, append_labels=False, use_bbox=True)
    pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx, add_ground_lift=False)
    
    for object_id, i_cloud in enumerate(i_clouds):
        mask_pcd = convert_to_o3dpcd(i_clouds[object_id])
        cropped_pcds, num_pts_in_gt_for_mask = [], []
        for i in range(len(pcd_gtboxes['gt_boxes'])):    
            cropped = mask_pcd.crop(pcd_gtboxes['gt_boxes'][i])
            num_pts_in_gt_for_mask.append(len(cropped.points))
            cropped_pcds.append(cropped)

        if !num_pts_in_gt_for_mask or max(num_pts_in_gt_for_mask) == 0:
            labelled_pts = np.hstack([i_cloud, np.ones((len(i_cloud),0))])
            box_pts = np.zeros((8,3))
            num_points_in_gt = 0
        else:
            gtbox_idx = np.argmax(np.array(num_pts_in_gt_for_mask)) 
            cropped_np = np.array(cropped_pcds[gtbox_idx].points)
            obj_pts_labelled = np.hstack([cropped_np, np.ones((len(cropped_np),1))])

            dist = mask_pcd.compute_point_cloud_distance(cropped_pcds[gtbox_idx])
            cropped_inds = np.where(np.asarray(dist) < 0.01)[0]
            mask_without_obj = np.asarray(mask_pcd.select_by_index(cropped_inds, invert=True).points)
            mask_pts_labelled = np.hstack([mask_without_obj, np.zeros((len(mask_without_obj),1))])\

            labelled_pts = np.vstack([mask_pts_labelled, obj_pts_labelled])
            box_pts = np.asarray(pcd_gtboxes['gt_boxes'][gtbox_idx].get_box_points())
            num_points_in_gt = len(cropped_np)
            
        if mesher.data_obj.dataset_name == 'nuscenes':
            fname = f'nsweeps-{mesher.data_obj.nsweeps}_frame-{sample_idx}_object-{object_id}_total_pts-{len(labelled_pts)}'
        else:
            fname = f'frame-{sample_idx}_object-{object_id}_total_pts-{len(labelled_pts)}'

        car_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data/points_in_{export_tag}/cars')
        car_dir.mkdir(parents=True, exist_ok=True)
        o3d.io.write_point_cloud(str(car_dir / f'{fname}.pcd'), object_pcd)

        box_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data/points_in_{export_tag}/gt_bboxes')    
        box_dir.mkdir(parents=True, exist_ok=True)
        np.savetxt(str(box_dir / f'{fname}.txt'), box_pts, delimiter=' ')

        print(f"frame-{sample_idx}: Exported {object_id+1}/{len(i_clouds)} | total pts-{len(labelled_pts)}, gt pts - {num_points_in_gt}")
# Out:
# frame-1: Exported 1/1 | total pts-10, gt pts - 9
# frame-2: Exported 1/1 | total pts-110, gt pts - 67
# frame-3: Exported 1/4 | total pts-408, gt pts - 0
# frame-3: Exported 2/4 | total pts-952, gt pts - 674
# frame-3: Exported 3/4 | total pts-2, gt pts - 0
# frame-3: Exported 4/4 | total pts-15, gt pts - 0
# frame-4: Exported 1/3 | total pts-120, gt pts - 68
# frame-4: Exported 2/3 | total pts-33, gt pts - 25
# frame-4: Exported 3/3 | total pts-3, gt pts - 0
# frame-6: Exported 1/5 | total pts-666, gt pts - 321
# frame-6: Exported 2/5 | total pts-138, gt pts - 65
# frame-6: Exported 3/5 | total pts-98, gt pts - 26
# frame-6: Exported 4/5 | total pts-10, gt pts - 0
# frame-6: Exported 5/5 | total pts-16, gt pts - 0
# frame-7: Exported 1/3 | total pts-213, gt pts - 182
# frame-7: Exported 2/3 | total pts-25, gt pts - 20
# frame-7: Exported 3/3 | total pts-7, gt pts - 5
# frame-8: Exported 1/10 | total pts-2959, gt pts - 1371
# frame-8: Exported 2/10 | total pts-1579, gt pts - 860
# frame-8: Exported 3/10 | total pts-3099, gt pts - 1627
# frame-8: Exported 4/10 | total pts-1038, gt pts - 658
# frame-8: Exported 5/10 | total pts-298, gt pts - 162
# frame-8: Exported 6/10 | total pts-85, gt pts - 51
# frame-8: Exported 7/10 | total pts-12, gt pts - 0
# frame-8: Exported 8/10 | total pts-19, gt pts - 2
# frame-8: Exported 9/10 | total pts-2, gt pts - 0
# frame-8: Exported 10/10 | total pts-6, gt pts - 0
# frame-9: Exported 1/3 | total pts-237, gt pts - 213
# frame-9: Exported 2/3 | total pts-29, gt pts - 0
# frame-9: Exported 3/3 | total pts-2, gt pts - 1
# frame-10: Exported 1/14 | total pts-986, gt pts - 285
# frame-10: Exported 2/14 | total pts-1503, gt pts - 1009
# frame-10: Exported 3/14 | total pts-526, gt pts - 340
# frame-10: Exported 4/14 | total pts-282, gt pts - 231
# frame-10: Exported 5/14 | total pts-111, gt pts - 45
# frame-10: Exported 6/14 | total pts-19, gt pts - 17
# frame-10: Exported 7/14 | total pts-61, gt pts - 27
# frame-10: Exported 8/14 | total pts-15, gt pts - 0
# frame-10: Exported 9/14 | total pts-83, gt pts - 49
# frame-10: Exported 10/14 | total pts-58, gt pts - 28
# frame-10: Exported 11/14 | total pts-9, gt pts - 0
# frame-10: Exported 12/14 | total pts-43, gt pts - 5
# frame-10: Exported 13/14 | total pts-6, gt pts - 2
# frame-10: Exported 14/14 | total pts-11, gt pts - 11
# frame-11: Exported 1/2 | total pts-332, gt pts - 216
# frame-11: Exported 2/2 | total pts-231, gt pts - 162
# frame-12: Exported 1/1 | total pts-16, gt pts - 13
# frame-13: Exported 1/1 | total pts-450, gt pts - 293
# frame-14: Exported 1/1 | total pts-20, gt pts - 16
# frame-15: Exported 1/1 | total pts-2383, gt pts - 1601
# frame-16: Exported 1/14 | total pts-3040, gt pts - 1722
# frame-16: Exported 2/14 | total pts-100, gt pts - 50
# frame-16: Exported 3/14 | total pts-26, gt pts - 10
# frame-16: Exported 4/14 | total pts-9, gt pts - 0
# frame-16: Exported 5/14 | total pts-16, gt pts - 0
# frame-16: Exported 6/14 | total pts-39, gt pts - 23
# frame-16: Exported 7/14 | total pts-5, gt pts - 0
# frame-16: Exported 8/14 | total pts-12, gt pts - 0
# frame-16: Exported 9/14 | total pts-5, gt pts - 0
# frame-16: Exported 10/14 | total pts-7, gt pts - 0
# frame-16: Exported 11/14 | total pts-5, gt pts - 0
# frame-16: Exported 12/14 | total pts-1, gt pts - 0
# frame-16: Exported 13/14 | total pts-10, gt pts - 0
# frame-16: Exported 14/14 | total pts-3, gt pts - 0
# frame-17: Exported 1/1 | total pts-50, gt pts - 7
# frame-18: Exported 1/13 | total pts-43, gt pts - 0
# frame-18: Exported 2/13 | total pts-23, gt pts - 0
# frame-18: Exported 3/13 | total pts-27, gt pts - 0
# frame-18: Exported 4/13 | total pts-28, gt pts - 0
# frame-18: Exported 5/13 | total pts-34, gt pts - 0
# frame-18: Exported 6/13 | total pts-41, gt pts - 0
# frame-18: Exported 7/13 | total pts-29, gt pts - 29
# frame-18: Exported 8/13 | total pts-34, gt pts - 0
# frame-18: Exported 9/13 | total pts-27, gt pts - 0
# frame-18: Exported 10/13 | total pts-3, gt pts - 0
# frame-18: Exported 11/13 | total pts-16, gt pts - 0
# frame-18: Exported 12/13 | total pts-4, gt pts - 0
# frame-18: Exported 13/13 | total pts-3, gt pts - 0
# frame-19: Exported 1/6 | total pts-1701, gt pts - 1184
# frame-19: Exported 2/6 | total pts-21, gt pts - 19
# frame-19: Exported 3/6 | total pts-16, gt pts - 0
# frame-19: Exported 4/6 | total pts-1, gt pts - 0
# frame-19: Exported 5/6 | total pts-5, gt pts - 0
# frame-19: Exported 6/6 | total pts-1, gt pts - 1
# frame-20: Exported 1/1 | total pts-937, gt pts - 500
# frame-21: Exported 1/8 | total pts-1227, gt pts - 828
# frame-21: Exported 2/8 | total pts-509, gt pts - 211
# frame-21: Exported 3/8 | total pts-221, gt pts - 173
# frame-21: Exported 4/8 | total pts-158, gt pts - 113
# frame-21: Exported 5/8 | total pts-145, gt pts - 64
# frame-21: Exported 6/8 | total pts-96, gt pts - 57
# frame-21: Exported 7/8 | total pts-9, gt pts - 7
# frame-21: Exported 8/8 | total pts-3, gt pts - 0
# frame-22: Exported 1/2 | total pts-161, gt pts - 48
# frame-22: Exported 2/2 | total pts-101, gt pts - 56
# frame-23: Exported 1/1 | total pts-16, gt pts - 13
# frame-24: Exported 1/4 | total pts-143, gt pts - 94
# frame-24: Exported 2/4 | total pts-64, gt pts - 42
# frame-24: Exported 3/4 | total pts-24, gt pts - 11
# frame-24: Exported 4/4 | total pts-6, gt pts - 0
# frame-25: Exported 1/9 | total pts-2054, gt pts - 0
# frame-25: Exported 2/9 | total pts-1150, gt pts - 130
# frame-25: Exported 3/9 | total pts-1807, gt pts - 1114
# frame-25: Exported 4/9 | total pts-442, gt pts - 316
# frame-25: Exported 5/9 | total pts-104, gt pts - 57
# frame-25: Exported 6/9 | total pts-500, gt pts - 176
# frame-25: Exported 7/9 | total pts-89, gt pts - 25
# frame-25: Exported 8/9 | total pts-16, gt pts - 0
# frame-25: Exported 9/9 | total pts-22, gt pts - 0
# frame-26: Exported 1/1 | total pts-12, gt pts - 12
# frame-29: Exported 1/1 | total pts-86, gt pts - 49
# frame-30: Exported 1/1 | total pts-26, gt pts - 20
# frame-31: Exported 1/5 | total pts-1863, gt pts - 982
# frame-31: Exported 2/5 | total pts-792, gt pts - 0
# frame-31: Exported 3/5 | total pts-1425, gt pts - 1012
# frame-31: Exported 4/5 | total pts-883, gt pts - 516
# frame-31: Exported 5/5 | total pts-204, gt pts - 141
# frame-32: Exported 1/7 | total pts-2083, gt pts - 1318
# frame-32: Exported 2/7 | total pts-2435, gt pts - 1425
# frame-32: Exported 3/7 | total pts-792, gt pts - 408
# frame-32: Exported 4/7 | total pts-413, gt pts - 203
# frame-32: Exported 5/7 | total pts-91, gt pts - 0
# frame-32: Exported 6/7 | total pts-51, gt pts - 39
# frame-32: Exported 7/7 | total pts-75, gt pts - 0
# frame-33: Exported 1/2 | total pts-940, gt pts - 441
# frame-33: Exported 2/2 | total pts-17, gt pts - 16
# frame-34: Exported 1/6 | total pts-1335, gt pts - 696
# frame-34: Exported 2/6 | total pts-49, gt pts - 19
# frame-34: Exported 3/6 | total pts-15, gt pts - 0
# frame-34: Exported 4/6 | total pts-1, gt pts - 0
# frame-34: Exported 5/6 | total pts-19, gt pts - 0
# frame-34: Exported 6/6 | total pts-1, gt pts - 0
# frame-35: Exported 1/3 | total pts-766, gt pts - 504
# frame-35: Exported 2/3 | total pts-244, gt pts - 96
# frame-35: Exported 3/3 | total pts-18, gt pts - 14
# frame-36: Exported 1/9 | total pts-1524, gt pts - 1056
# frame-36: Exported 2/9 | total pts-423, gt pts - 177
# frame-36: Exported 3/9 | total pts-268, gt pts - 82
# frame-36: Exported 4/9 | total pts-198, gt pts - 92
# frame-36: Exported 5/9 | total pts-20, gt pts - 6
# frame-36: Exported 6/9 | total pts-62, gt pts - 34
# frame-36: Exported 7/9 | total pts-14, gt pts - 12
# frame-36: Exported 8/9 | total pts-16, gt pts - 8
# frame-36: Exported 9/9 | total pts-13, gt pts - 10
# frame-37: Exported 1/4 | total pts-449, gt pts - 344
# frame-37: Exported 2/4 | total pts-84, gt pts - 56
# frame-37: Exported 3/4 | total pts-47, gt pts - 20
# frame-37: Exported 4/4 | total pts-27, gt pts - 3
# frame-38: Exported 1/10 | total pts-2846, gt pts - 1566
# frame-38: Exported 2/10 | total pts-774, gt pts - 534
# frame-38: Exported 3/10 | total pts-858, gt pts - 380
# frame-38: Exported 4/10 | total pts-526, gt pts - 349
# frame-38: Exported 5/10 | total pts-273, gt pts - 208
# frame-38: Exported 6/10 | total pts-163, gt pts - 152
# frame-38: Exported 7/10 | total pts-91, gt pts - 56
# frame-38: Exported 8/10 | total pts-62, gt pts - 22
# frame-38: Exported 9/10 | total pts-27, gt pts - 16
# frame-38: Exported 10/10 | total pts-26, gt pts - 7
# frame-39: Exported 1/6 | total pts-3206, gt pts - 1255
# frame-39: Exported 2/6 | total pts-613, gt pts - 240
# frame-39: Exported 3/6 | total pts-115, gt pts - 68
# frame-39: Exported 4/6 | total pts-122, gt pts - 81
# frame-39: Exported 5/6 | total pts-18, gt pts - 16
# frame-39: Exported 6/6 | total pts-33, gt pts - 21
# frame-40: Exported 1/2 | total pts-85, gt pts - 60
# frame-40: Exported 2/2 | total pts-17, gt pts - 8
# frame-41: Exported 1/5 | total pts-93, gt pts - 56
# frame-41: Exported 2/5 | total pts-27, gt pts - 0
# frame-41: Exported 3/5 | total pts-14, gt pts - 0
# frame-41: Exported 4/5 | total pts-1, gt pts - 0
# frame-41: Exported 5/5 | total pts-8, gt pts - 0
# frame-42: Exported 1/1 | total pts-25, gt pts - 22
# frame-44: Exported 1/2 | total pts-2440, gt pts - 1642
# frame-44: Exported 2/2 | total pts-840, gt pts - 559
# frame-45: Exported 1/7 | total pts-1064, gt pts - 615
# frame-45: Exported 2/7 | total pts-345, gt pts - 173
# frame-45: Exported 3/7 | total pts-113, gt pts - 62
# frame-45: Exported 4/7 | total pts-102, gt pts - 30
# frame-45: Exported 5/7 | total pts-44, gt pts - 20
# frame-45: Exported 6/7 | total pts-25, gt pts - 20
# frame-45: Exported 7/7 | total pts-10, gt pts - 0
# frame-46: Exported 1/6 | total pts-3209, gt pts - 1938
# frame-46: Exported 2/6 | total pts-640, gt pts - 429
# frame-46: Exported 3/6 | total pts-128, gt pts - 113
# frame-46: Exported 4/6 | total pts-136, gt pts - 106
# frame-46: Exported 5/6 | total pts-55, gt pts - 21
# frame-46: Exported 6/6 | total pts-49, gt pts - 26
# frame-47: Exported 1/9 | total pts-1543, gt pts - 996
# frame-47: Exported 2/9 | total pts-527, gt pts - 291
# frame-47: Exported 3/9 | total pts-190, gt pts - 156
# frame-47: Exported 4/9 | total pts-138, gt pts - 30
# frame-47: Exported 5/9 | total pts-169, gt pts - 153
# frame-47: Exported 6/9 | total pts-153, gt pts - 100
# frame-47: Exported 7/9 | total pts-25, gt pts - 12
# frame-47: Exported 8/9 | total pts-74, gt pts - 43
# frame-47: Exported 9/9 | total pts-14, gt pts - 11
# frame-49: Exported 1/12 | total pts-1388, gt pts - 569
# frame-49: Exported 2/12 | total pts-904, gt pts - 0
# frame-49: Exported 3/12 | total pts-1352, gt pts - 920
# frame-49: Exported 4/12 | total pts-1181, gt pts - 425
# frame-49: Exported 5/12 | total pts-185, gt pts - 20
# frame-49: Exported 6/12 | total pts-726, gt pts - 436
# frame-49: Exported 7/12 | total pts-523, gt pts - 309
# frame-49: Exported 8/12 | total pts-466, gt pts - 184
# frame-49: Exported 9/12 | total pts-273, gt pts - 207
# frame-49: Exported 10/12 | total pts-137, gt pts - 48
# frame-49: Exported 11/12 | total pts-283, gt pts - 134
# frame-49: Exported 12/12 | total pts-104, gt pts - 63
# frame-50: Exported 1/4 | total pts-1426, gt pts - 155
# frame-50: Exported 2/4 | total pts-1906, gt pts - 1074
# frame-50: Exported 3/4 | total pts-992, gt pts - 656
# frame-50: Exported 4/4 | total pts-104, gt pts - 64
# frame-51: Exported 1/10 | total pts-312, gt pts - 0
# frame-51: Exported 2/10 | total pts-73, gt pts - 58
# frame-51: Exported 3/10 | total pts-155, gt pts - 0
# frame-51: Exported 4/10 | total pts-100, gt pts - 0
# frame-51: Exported 5/10 | total pts-96, gt pts - 0
# frame-51: Exported 6/10 | total pts-67, gt pts - 0
# frame-51: Exported 7/10 | total pts-60, gt pts - 0
# frame-51: Exported 8/10 | total pts-64, gt pts - 0
# frame-51: Exported 9/10 | total pts-42, gt pts - 0
# frame-51: Exported 10/10 | total pts-24, gt pts - 0
# frame-52: Exported 1/11 | total pts-2624, gt pts - 14
# frame-52: Exported 2/11 | total pts-651, gt pts - 380
# frame-52: Exported 3/11 | total pts-319, gt pts - 228
# frame-52: Exported 4/11 | total pts-131, gt pts - 10
# frame-52: Exported 5/11 | total pts-270, gt pts - 174
# frame-52: Exported 6/11 | total pts-150, gt pts - 0
# frame-52: Exported 7/11 | total pts-222, gt pts - 117
# frame-52: Exported 8/11 | total pts-50, gt pts - 0
# frame-52: Exported 9/11 | total pts-103, gt pts - 3
# frame-52: Exported 10/11 | total pts-13, gt pts - 8
# frame-52: Exported 11/11 | total pts-3, gt pts - 0
# frame-53: Exported 1/8 | total pts-1698, gt pts - 772
# frame-53: Exported 2/8 | total pts-980, gt pts - 526
# frame-53: Exported 3/8 | total pts-334, gt pts - 135
# frame-53: Exported 4/8 | total pts-102, gt pts - 51
# frame-53: Exported 5/8 | total pts-141, gt pts - 71
# frame-53: Exported 6/8 | total pts-37, gt pts - 17
# frame-53: Exported 7/8 | total pts-18, gt pts - 0
# frame-53: Exported 8/8 | total pts-14, gt pts - 0
# frame-55: Exported 1/5 | total pts-103, gt pts - 22
# frame-55: Exported 2/5 | total pts-72, gt pts - 18
# frame-55: Exported 3/5 | total pts-55, gt pts - 15
# frame-55: Exported 4/5 | total pts-14, gt pts - 4
# frame-55: Exported 5/5 | total pts-7, gt pts - 0
# frame-56: Exported 1/1 | total pts-20, gt pts - 19
# frame-57: Exported 1/2 | total pts-434, gt pts - 184
# frame-57: Exported 2/2 | total pts-157, gt pts - 97
# frame-59: Exported 1/4 | total pts-265, gt pts - 108
# frame-59: Exported 2/4 | total pts-255, gt pts - 140
# frame-59: Exported 3/4 | total pts-148, gt pts - 79
# frame-59: Exported 4/4 | total pts-52, gt pts - 52
# frame-60: Exported 1/3 | total pts-286, gt pts - 215
# frame-60: Exported 2/3 | total pts-9, gt pts - 1
# frame-60: Exported 3/3 | total pts-12, gt pts - 0
# frame-61: Exported 1/5 | total pts-196, gt pts - 137
# frame-61: Exported 2/5 | total pts-164, gt pts - 108
# frame-61: Exported 3/5 | total pts-23, gt pts - 13
# frame-61: Exported 4/5 | total pts-31, gt pts - 0
# frame-61: Exported 5/5 | total pts-27, gt pts - 0
# frame-62: Exported 1/7 | total pts-615, gt pts - 451
# frame-62: Exported 2/7 | total pts-160, gt pts - 95
# frame-62: Exported 3/7 | total pts-60, gt pts - 22
# frame-62: Exported 4/7 | total pts-33, gt pts - 6
# frame-62: Exported 5/7 | total pts-11, gt pts - 6
# frame-62: Exported 6/7 | total pts-1, gt pts - 0
# frame-62: Exported 7/7 | total pts-5, gt pts - 0
# frame-63: Exported 1/3 | total pts-1454, gt pts - 248
# frame-63: Exported 2/3 | total pts-473, gt pts - 305
# frame-63: Exported 3/3 | total pts-140, gt pts - 3
# frame-64: Exported 1/4 | total pts-1151, gt pts - 820
# frame-64: Exported 2/4 | total pts-163, gt pts - 132
# frame-64: Exported 3/4 | total pts-71, gt pts - 32
# frame-64: Exported 4/4 | total pts-19, gt pts - 0
# frame-66: Exported 1/4 | total pts-111, gt pts - 96
# frame-66: Exported 2/4 | total pts-56, gt pts - 30
# frame-66: Exported 3/4 | total pts-7, gt pts - 1
# frame-66: Exported 4/4 | total pts-6, gt pts - 0
# frame-67: Exported 1/12 | total pts-1654, gt pts - 723
# frame-67: Exported 2/12 | total pts-1531, gt pts - 810
# frame-67: Exported 3/12 | total pts-52, gt pts - 19
# frame-67: Exported 4/12 | total pts-33, gt pts - 21
# frame-67: Exported 5/12 | total pts-7, gt pts - 0
# frame-67: Exported 6/12 | total pts-20, gt pts - 0
# frame-67: Exported 7/12 | total pts-6, gt pts - 0
# frame-67: Exported 8/12 | total pts-12, gt pts - 0
# frame-67: Exported 9/12 | total pts-5, gt pts - 0
# frame-67: Exported 10/12 | total pts-3, gt pts - 0
# frame-67: Exported 11/12 | total pts-4, gt pts - 0
# frame-67: Exported 12/12 | total pts-4, gt pts - 0
# frame-68: Exported 1/10 | total pts-2856, gt pts - 1704
# frame-68: Exported 2/10 | total pts-584, gt pts - 206
# frame-68: Exported 3/10 | total pts-1384, gt pts - 114
# frame-68: Exported 4/10 | total pts-395, gt pts - 211
# frame-68: Exported 5/10 | total pts-154, gt pts - 117
# frame-68: Exported 6/10 | total pts-103, gt pts - 66
# frame-68: Exported 7/10 | total pts-70, gt pts - 38
# frame-68: Exported 8/10 | total pts-57, gt pts - 9
# frame-68: Exported 9/10 | total pts-13, gt pts - 8
# frame-68: Exported 10/10 | total pts-11, gt pts - 0
# frame-69: Exported 1/3 | total pts-1069, gt pts - 633
# frame-69: Exported 2/3 | total pts-45, gt pts - 27
# frame-69: Exported 3/3 | total pts-9, gt pts - 7
# frame-71: Exported 1/1 | total pts-360, gt pts - 263
# frame-72: Exported 1/3 | total pts-1469, gt pts - 846
# frame-72: Exported 2/3 | total pts-125, gt pts - 78
# frame-72: Exported 3/3 | total pts-74, gt pts - 58
# frame-75: Exported 1/5 | total pts-325, gt pts - 39
# frame-75: Exported 2/5 | total pts-729, gt pts - 486
# frame-75: Exported 3/5 | total pts-294, gt pts - 187
# frame-75: Exported 4/5 | total pts-206, gt pts - 105
# frame-75: Exported 5/5 | total pts-20, gt pts - 2
# frame-77: Exported 1/2 | total pts-54, gt pts - 37
# frame-77: Exported 2/2 | total pts-11, gt pts - 0
# frame-78: Exported 1/7 | total pts-2182, gt pts - 35
# frame-78: Exported 2/7 | total pts-1433, gt pts - 921
# frame-78: Exported 3/7 | total pts-186, gt pts - 0
# frame-78: Exported 4/7 | total pts-93, gt pts - 49
# frame-78: Exported 5/7 | total pts-27, gt pts - 13
# frame-78: Exported 6/7 | total pts-4, gt pts - 2
# frame-78: Exported 7/7 | total pts-2, gt pts - 0
# frame-79: Exported 1/14 | total pts-1574, gt pts - 650
# frame-79: Exported 2/14 | total pts-1958, gt pts - 938
# frame-79: Exported 3/14 | total pts-45, gt pts - 21
# frame-79: Exported 4/14 | total pts-7, gt pts - 0
# frame-79: Exported 5/14 | total pts-36, gt pts - 21
# frame-79: Exported 6/14 | total pts-21, gt pts - 0
# frame-79: Exported 7/14 | total pts-6, gt pts - 0
# frame-79: Exported 8/14 | total pts-17, gt pts - 2
# frame-79: Exported 9/14 | total pts-12, gt pts - 0
# frame-79: Exported 10/14 | total pts-3, gt pts - 0
# frame-79: Exported 11/14 | total pts-6, gt pts - 0
# frame-79: Exported 12/14 | total pts-4, gt pts - 0
# frame-79: Exported 13/14 | total pts-10, gt pts - 0
# frame-79: Exported 14/14 | total pts-4, gt pts - 0
# frame-80: Exported 1/6 | total pts-268, gt pts - 221
# frame-80: Exported 2/6 | total pts-101, gt pts - 93
# frame-80: Exported 3/6 | total pts-13, gt pts - 11
# frame-80: Exported 4/6 | total pts-33, gt pts - 0
# frame-80: Exported 5/6 | total pts-3, gt pts - 0
# frame-80: Exported 6/6 | total pts-5, gt pts - 4
# frame-81: Exported 1/1 | total pts-19, gt pts - 0
# frame-82: Exported 1/1 | total pts-11, gt pts - 10
# frame-83: Exported 1/8 | total pts-1433, gt pts - 223
# frame-83: Exported 2/8 | total pts-1854, gt pts - 60
# frame-83: Exported 3/8 | total pts-1318, gt pts - 448
# frame-83: Exported 4/8 | total pts-201, gt pts - 60
# frame-83: Exported 5/8 | total pts-216, gt pts - 59
# frame-83: Exported 6/8 | total pts-77, gt pts - 38
# frame-83: Exported 7/8 | total pts-48, gt pts - 8
# frame-83: Exported 8/8 | total pts-31, gt pts - 0
# frame-84: Exported 1/2 | total pts-156, gt pts - 123
# frame-84: Exported 2/2 | total pts-14, gt pts - 2
# frame-86: Exported 1/7 | total pts-1646, gt pts - 727
# frame-86: Exported 2/7 | total pts-156, gt pts - 48
# frame-86: Exported 3/7 | total pts-476, gt pts - 347
# frame-86: Exported 4/7 | total pts-451, gt pts - 189
# frame-86: Exported 5/7 | total pts-357, gt pts - 182
# frame-86: Exported 6/7 | total pts-184, gt pts - 76
# frame-86: Exported 7/7 | total pts-97, gt pts - 25
# frame-87: Exported 1/6 | total pts-844, gt pts - 485
# frame-87: Exported 2/6 | total pts-77, gt pts - 58
# frame-87: Exported 3/6 | total pts-89, gt pts - 0
# frame-87: Exported 4/6 | total pts-65, gt pts - 0
# frame-87: Exported 5/6 | total pts-39, gt pts - 18
# frame-87: Exported 6/6 | total pts-19, gt pts - 0
# frame-88: Exported 1/3 | total pts-883, gt pts - 553
# frame-88: Exported 2/3 | total pts-153, gt pts - 18
# frame-88: Exported 3/3 | total pts-28, gt pts - 0
# frame-89: Exported 1/5 | total pts-1316, gt pts - 836
# frame-89: Exported 2/5 | total pts-402, gt pts - 234
# frame-89: Exported 3/5 | total pts-399, gt pts - 242
# frame-89: Exported 4/5 | total pts-232, gt pts - 136
# frame-89: Exported 5/5 | total pts-37, gt pts - 19
# frame-90: Exported 1/2 | total pts-385, gt pts - 214
# frame-90: Exported 2/2 | total pts-77, gt pts - 9
# frame-91: Exported 1/8 | total pts-119, gt pts - 0
# frame-91: Exported 2/8 | total pts-133, gt pts - 0
# frame-91: Exported 3/8 | total pts-73, gt pts - 49
# frame-91: Exported 4/8 | total pts-67, gt pts - 0
# frame-91: Exported 5/8 | total pts-59, gt pts - 0
# frame-91: Exported 6/8 | total pts-44, gt pts - 0
# frame-91: Exported 7/8 | total pts-45, gt pts - 0
# frame-91: Exported 8/8 | total pts-2, gt pts - 0
# frame-92: Exported 1/5 | total pts-255, gt pts - 121
# frame-92: Exported 2/5 | total pts-215, gt pts - 139
# frame-92: Exported 3/5 | total pts-137, gt pts - 108
# frame-92: Exported 4/5 | total pts-21, gt pts - 13
# frame-92: Exported 5/5 | total pts-12, gt pts - 0
# frame-93: Exported 1/13 | total pts-2705, gt pts - 1781
# frame-93: Exported 2/13 | total pts-962, gt pts - 576
# frame-93: Exported 3/13 | total pts-516, gt pts - 366
# frame-93: Exported 4/13 | total pts-549, gt pts - 296
# frame-93: Exported 5/13 | total pts-75, gt pts - 0
# frame-93: Exported 6/13 | total pts-40, gt pts - 7
# frame-93: Exported 7/13 | total pts-51, gt pts - 11
# frame-93: Exported 8/13 | total pts-65, gt pts - 27
# frame-93: Exported 9/13 | total pts-14, gt pts - 0
# frame-93: Exported 10/13 | total pts-10, gt pts - 10
# frame-93: Exported 11/13 | total pts-3, gt pts - 0
# frame-93: Exported 12/13 | total pts-3, gt pts - 0
# frame-93: Exported 13/13 | total pts-2, gt pts - 1
# frame-94: Exported 1/1 | total pts-455, gt pts - 300
# frame-95: Exported 1/13 | total pts-1101, gt pts - 567
# frame-95: Exported 2/13 | total pts-1139, gt pts - 630
# frame-95: Exported 3/13 | total pts-441, gt pts - 103
# frame-95: Exported 4/13 | total pts-437, gt pts - 344
# frame-95: Exported 5/13 | total pts-343, gt pts - 244
# frame-95: Exported 6/13 | total pts-148, gt pts - 104
# frame-95: Exported 7/13 | total pts-102, gt pts - 54
# frame-95: Exported 8/13 | total pts-97, gt pts - 60
# frame-95: Exported 9/13 | total pts-65, gt pts - 22
# frame-95: Exported 10/13 | total pts-184, gt pts - 102
# frame-95: Exported 11/13 | total pts-22, gt pts - 11
# frame-95: Exported 12/13 | total pts-7, gt pts - 6
# frame-95: Exported 13/13 | total pts-16, gt pts - 5
# frame-96: Exported 1/7 | total pts-3035, gt pts - 1894
# frame-96: Exported 2/7 | total pts-2351, gt pts - 1187
# frame-96: Exported 3/7 | total pts-462, gt pts - 0
# frame-96: Exported 4/7 | total pts-123, gt pts - 62
# frame-96: Exported 5/7 | total pts-194, gt pts - 106
# frame-96: Exported 6/7 | total pts-61, gt pts - 0
# frame-96: Exported 7/7 | total pts-25, gt pts - 0
# frame-97: Exported 1/3 | total pts-12, gt pts - 10
# frame-97: Exported 2/3 | total pts-13, gt pts - 12
# frame-97: Exported 3/3 | total pts-9, gt pts - 0
# frame-98: Exported 1/7 | total pts-935, gt pts - 594
# frame-98: Exported 2/7 | total pts-345, gt pts - 242
# frame-98: Exported 3/7 | total pts-392, gt pts - 262
# frame-98: Exported 4/7 | total pts-60, gt pts - 28
# frame-98: Exported 5/7 | total pts-34, gt pts - 26
# frame-98: Exported 6/7 | total pts-89, gt pts - 72
# frame-98: Exported 7/7 | total pts-18, gt pts - 2
# frame-99: Exported 1/16 | total pts-1770, gt pts - 541
# frame-99: Exported 2/16 | total pts-2033, gt pts - 1313
# frame-99: Exported 3/16 | total pts-1046, gt pts - 673
# frame-99: Exported 4/16 | total pts-853, gt pts - 681
# frame-99: Exported 5/16 | total pts-356, gt pts - 209
# frame-99: Exported 6/16 | total pts-201, gt pts - 160
# frame-99: Exported 7/16 | total pts-81, gt pts - 0
# frame-99: Exported 8/16 | total pts-390, gt pts - 242
# frame-99: Exported 9/16 | total pts-47, gt pts - 0
# frame-99: Exported 10/16 | total pts-10, gt pts - 0
# frame-99: Exported 11/16 | total pts-12, gt pts - 0
# frame-99: Exported 12/16 | total pts-17, gt pts - 4
# frame-99: Exported 13/16 | total pts-30, gt pts - 12
# frame-99: Exported 14/16 | total pts-33, gt pts - 0
# frame-99: Exported 15/16 | total pts-39, gt pts - 0
# frame-99: Exported 16/16 | total pts-14, gt pts - 0
# frame-101: Exported 1/5 | total pts-114, gt pts - 67
# frame-101: Exported 2/5 | total pts-178, gt pts - 77
# frame-101: Exported 3/5 | total pts-406, gt pts - 320
# frame-101: Exported 4/5 | total pts-9, gt pts - 0
# frame-101: Exported 5/5 | total pts-3, gt pts - 0
# frame-102: Exported 1/3 | total pts-268, gt pts - 42
# frame-102: Exported 2/3 | total pts-96, gt pts - 44
# frame-102: Exported 3/3 | total pts-44, gt pts - 12
# frame-104: Exported 1/7 | total pts-1152, gt pts - 395
# frame-104: Exported 2/7 | total pts-173, gt pts - 139
# frame-104: Exported 3/7 | total pts-229, gt pts - 118
# frame-104: Exported 4/7 | total pts-93, gt pts - 49
# frame-104: Exported 5/7 | total pts-23, gt pts - 4
# frame-104: Exported 6/7 | total pts-17, gt pts - 8
# frame-104: Exported 7/7 | total pts-7, gt pts - 0
# frame-105: Exported 1/5 | total pts-97, gt pts - 0
# frame-105: Exported 2/5 | total pts-51, gt pts - 0
# frame-105: Exported 3/5 | total pts-56, gt pts - 0
# frame-105: Exported 4/5 | total pts-7, gt pts - 7
# frame-105: Exported 5/5 | total pts-5, gt pts - 0
# frame-106: Exported 1/4 | total pts-910, gt pts - 360
# frame-106: Exported 2/4 | total pts-326, gt pts - 187
# frame-106: Exported 3/4 | total pts-44, gt pts - 15
# frame-106: Exported 4/4 | total pts-13, gt pts - 13
# frame-107: Exported 1/8 | total pts-2875, gt pts - 1551
# frame-107: Exported 2/8 | total pts-1272, gt pts - 627
# frame-107: Exported 3/8 | total pts-545, gt pts - 327
# frame-107: Exported 4/8 | total pts-323, gt pts - 219
# frame-107: Exported 5/8 | total pts-138, gt pts - 50
# frame-107: Exported 6/8 | total pts-80, gt pts - 56
# frame-107: Exported 7/8 | total pts-56, gt pts - 17
# frame-107: Exported 8/8 | total pts-71, gt pts - 34
# frame-108: Exported 1/1 | total pts-856, gt pts - 136
# frame-110: Exported 1/13 | total pts-1813, gt pts - 765
# frame-110: Exported 2/13 | total pts-640, gt pts - 432
# frame-110: Exported 3/13 | total pts-328, gt pts - 179
# frame-110: Exported 4/13 | total pts-499, gt pts - 353
# frame-110: Exported 5/13 | total pts-143, gt pts - 114
# frame-110: Exported 6/13 | total pts-75, gt pts - 0
# frame-110: Exported 7/13 | total pts-111, gt pts - 72
# frame-110: Exported 8/13 | total pts-33, gt pts - 17
# frame-110: Exported 9/13 | total pts-42, gt pts - 30
# frame-110: Exported 10/13 | total pts-45, gt pts - 40
# frame-110: Exported 11/13 | total pts-65, gt pts - 23
# frame-110: Exported 12/13 | total pts-15, gt pts - 3
# frame-110: Exported 13/13 | total pts-1, gt pts - 0
# frame-111: Exported 1/9 | total pts-1246, gt pts - 473
# frame-111: Exported 2/9 | total pts-182, gt pts - 70
# frame-111: Exported 3/9 | total pts-360, gt pts - 222
# frame-111: Exported 4/9 | total pts-211, gt pts - 136
# frame-111: Exported 5/9 | total pts-212, gt pts - 171
# frame-111: Exported 6/9 | total pts-199, gt pts - 34
# frame-111: Exported 7/9 | total pts-36, gt pts - 15
# frame-111: Exported 8/9 | total pts-2, gt pts - 0
# frame-111: Exported 9/9 | total pts-6, gt pts - 1
# frame-112: Exported 1/11 | total pts-1927, gt pts - 904
# frame-112: Exported 2/11 | total pts-1088, gt pts - 830
# frame-112: Exported 3/11 | total pts-210, gt pts - 150
# frame-112: Exported 4/11 | total pts-380, gt pts - 91
# frame-112: Exported 5/11 | total pts-647, gt pts - 314
# frame-112: Exported 6/11 | total pts-400, gt pts - 191
# frame-112: Exported 7/11 | total pts-179, gt pts - 66
# frame-112: Exported 8/11 | total pts-328, gt pts - 134
# frame-112: Exported 9/11 | total pts-179, gt pts - 101
# frame-112: Exported 10/11 | total pts-87, gt pts - 46
# frame-112: Exported 11/11 | total pts-57, gt pts - 11
# frame-113: Exported 1/8 | total pts-3045, gt pts - 1879
# frame-113: Exported 2/8 | total pts-472, gt pts - 319
# frame-113: Exported 3/8 | total pts-367, gt pts - 191
# frame-113: Exported 4/8 | total pts-219, gt pts - 155
# frame-113: Exported 5/8 | total pts-153, gt pts - 101
# frame-113: Exported 6/8 | total pts-176, gt pts - 82
# frame-113: Exported 7/8 | total pts-116, gt pts - 69
# frame-113: Exported 8/8 | total pts-68, gt pts - 39
# frame-114: Exported 1/11 | total pts-518, gt pts - 354
# frame-114: Exported 2/11 | total pts-190, gt pts - 0
# frame-114: Exported 3/11 | total pts-439, gt pts - 178
# frame-114: Exported 4/11 | total pts-188, gt pts - 123
# frame-114: Exported 5/11 | total pts-286, gt pts - 0
# frame-114: Exported 6/11 | total pts-61, gt pts - 1
# frame-114: Exported 7/11 | total pts-138, gt pts - 66
# frame-114: Exported 8/11 | total pts-59, gt pts - 32
# frame-114: Exported 9/11 | total pts-58, gt pts - 29
# frame-114: Exported 10/11 | total pts-38, gt pts - 19
# frame-114: Exported 11/11 | total pts-50, gt pts - 18
# frame-115: Exported 1/4 | total pts-86, gt pts - 33
# frame-115: Exported 2/4 | total pts-71, gt pts - 39
# frame-115: Exported 3/4 | total pts-25, gt pts - 0
# frame-115: Exported 4/4 | total pts-7, gt pts - 0
# frame-116: Exported 1/5 | total pts-3097, gt pts - 1501
# frame-116: Exported 2/5 | total pts-358, gt pts - 171
# frame-116: Exported 3/5 | total pts-179, gt pts - 91
# frame-116: Exported 4/5 | total pts-60, gt pts - 24
# frame-116: Exported 5/5 | total pts-49, gt pts - 17
# frame-117: Exported 1/12 | total pts-2468, gt pts - 1611
# frame-117: Exported 2/12 | total pts-1595, gt pts - 1239
# frame-117: Exported 3/12 | total pts-742, gt pts - 347
# frame-117: Exported 4/12 | total pts-549, gt pts - 229
# frame-117: Exported 5/12 | total pts-673, gt pts - 454
# frame-117: Exported 6/12 | total pts-268, gt pts - 151
# frame-117: Exported 7/12 | total pts-89, gt pts - 0
# frame-117: Exported 8/12 | total pts-63, gt pts - 0
# frame-117: Exported 9/12 | total pts-115, gt pts - 79
# frame-117: Exported 10/12 | total pts-62, gt pts - 34
# frame-117: Exported 11/12 | total pts-48, gt pts - 0
# frame-117: Exported 12/12 | total pts-2, gt pts - 0
# frame-119: Exported 1/4 | total pts-268, gt pts - 0
# frame-119: Exported 2/4 | total pts-572, gt pts - 387
# frame-119: Exported 3/4 | total pts-481, gt pts - 263
# frame-119: Exported 4/4 | total pts-1, gt pts - 0
# frame-120: Exported 1/12 | total pts-2863, gt pts - 1557
# frame-120: Exported 2/12 | total pts-1208, gt pts - 625
# frame-120: Exported 3/12 | total pts-724, gt pts - 391
# frame-120: Exported 4/12 | total pts-235, gt pts - 117
# frame-120: Exported 5/12 | total pts-186, gt pts - 119
# frame-120: Exported 6/12 | total pts-227, gt pts - 168
# frame-120: Exported 7/12 | total pts-205, gt pts - 46
# frame-120: Exported 8/12 | total pts-145, gt pts - 86
# frame-120: Exported 9/12 | total pts-117, gt pts - 57
# frame-120: Exported 10/12 | total pts-84, gt pts - 44
# frame-120: Exported 11/12 | total pts-41, gt pts - 13
# frame-120: Exported 12/12 | total pts-25, gt pts - 0
# frame-121: Exported 1/16 | total pts-117, gt pts - 51
# frame-121: Exported 2/16 | total pts-73, gt pts - 39
# frame-121: Exported 3/16 | total pts-49, gt pts - 21
# frame-121: Exported 4/16 | total pts-46, gt pts - 38
# frame-121: Exported 5/16 | total pts-21, gt pts - 0
# frame-121: Exported 6/16 | total pts-7, gt pts - 0
# frame-121: Exported 7/16 | total pts-6, gt pts - 0
# frame-121: Exported 8/16 | total pts-12, gt pts - 0
# frame-121: Exported 9/16 | total pts-3, gt pts - 0
# frame-121: Exported 10/16 | total pts-6, gt pts - 0
# frame-121: Exported 11/16 | total pts-7, gt pts - 0
# frame-121: Exported 12/16 | total pts-4, gt pts - 0
# frame-121: Exported 13/16 | total pts-4, gt pts - 0
# frame-121: Exported 14/16 | total pts-5, gt pts - 0
# frame-121: Exported 15/16 | total pts-2, gt pts - 1
# frame-121: Exported 16/16 | total pts-3, gt pts - 0
# frame-122: Exported 1/1 | total pts-350, gt pts - 89
# frame-123: Exported 1/1 | total pts-25, gt pts - 21
# frame-124: Exported 1/3 | total pts-45, gt pts - 18
# frame-124: Exported 2/3 | total pts-23, gt pts - 20
# frame-124: Exported 3/3 | total pts-5, gt pts - 0
# frame-125: Exported 1/6 | total pts-2950, gt pts - 2116
# frame-125: Exported 2/6 | total pts-96, gt pts - 9
# frame-125: Exported 3/6 | total pts-140, gt pts - 29
# frame-125: Exported 4/6 | total pts-136, gt pts - 102
# frame-125: Exported 5/6 | total pts-19, gt pts - 13
# frame-125: Exported 6/6 | total pts-32, gt pts - 13
# frame-126: Exported 1/3 | total pts-427, gt pts - 0
# frame-126: Exported 2/3 | total pts-656, gt pts - 377
# frame-126: Exported 3/3 | total pts-66, gt pts - 7
# frame-127: Exported 1/10 | total pts-1061, gt pts - 735
# frame-127: Exported 2/10 | total pts-110, gt pts - 30
# frame-127: Exported 3/10 | total pts-65, gt pts - 0
# frame-127: Exported 4/10 | total pts-35, gt pts - 28
# frame-127: Exported 5/10 | total pts-43, gt pts - 15
# frame-127: Exported 6/10 | total pts-47, gt pts - 8
# frame-127: Exported 7/10 | total pts-90, gt pts - 39
# frame-127: Exported 8/10 | total pts-39, gt pts - 0
# frame-127: Exported 9/10 | total pts-9, gt pts - 9
# frame-127: Exported 10/10 | total pts-20, gt pts - 0
# frame-128: Exported 1/2 | total pts-535, gt pts - 195
# frame-128: Exported 2/2 | total pts-9, gt pts - 0
# frame-129: Exported 1/7 | total pts-1020, gt pts - 466
# frame-129: Exported 2/7 | total pts-389, gt pts - 238
# frame-129: Exported 3/7 | total pts-123, gt pts - 51
# frame-129: Exported 4/7 | total pts-27, gt pts - 8
# frame-129: Exported 5/7 | total pts-38, gt pts - 16
# frame-129: Exported 6/7 | total pts-22, gt pts - 18
# frame-129: Exported 7/7 | total pts-4, gt pts - 1
# frame-131: Exported 1/16 | total pts-449, gt pts - 259
# frame-131: Exported 2/16 | total pts-122, gt pts - 0
# frame-131: Exported 3/16 | total pts-294, gt pts - 113
# frame-131: Exported 4/16 | total pts-86, gt pts - 55
# frame-131: Exported 5/16 | total pts-21, gt pts - 0
# frame-131: Exported 6/16 | total pts-40, gt pts - 11
# frame-131: Exported 7/16 | total pts-8, gt pts - 7
# frame-131: Exported 8/16 | total pts-6, gt pts - 0
# frame-131: Exported 9/16 | total pts-4, gt pts - 0
# frame-131: Exported 10/16 | total pts-1, gt pts - 0
# frame-131: Exported 11/16 | total pts-15, gt pts - 0
# frame-131: Exported 12/16 | total pts-5, gt pts - 0
# frame-131: Exported 13/16 | total pts-4, gt pts - 0
# frame-131: Exported 14/16 | total pts-15, gt pts - 0
# frame-131: Exported 15/16 | total pts-1, gt pts - 0
# frame-131: Exported 16/16 | total pts-4, gt pts - 0
# frame-132: Exported 1/2 | total pts-126, gt pts - 102
# frame-132: Exported 2/2 | total pts-2, gt pts - 2
# frame-133: Exported 1/5 | total pts-86, gt pts - 55
# frame-133: Exported 2/5 | total pts-47, gt pts - 37
# frame-133: Exported 3/5 | total pts-5, gt pts - 0
# frame-133: Exported 4/5 | total pts-15, gt pts - 12
# frame-133: Exported 5/5 | total pts-9, gt pts - 6
# frame-134: Exported 1/4 | total pts-1287, gt pts - 569
# frame-134: Exported 2/4 | total pts-124, gt pts - 11
# frame-134: Exported 3/4 | total pts-129, gt pts - 3
# frame-134: Exported 4/4 | total pts-20, gt pts - 0
# frame-135: Exported 1/12 | total pts-205, gt pts - 0
# frame-135: Exported 2/12 | total pts-391, gt pts - 239
# frame-135: Exported 3/12 | total pts-133, gt pts - 98
# frame-135: Exported 4/12 | total pts-259, gt pts - 134
# frame-135: Exported 5/12 | total pts-167, gt pts - 101
# frame-135: Exported 6/12 | total pts-63, gt pts - 31
# frame-135: Exported 7/12 | total pts-69, gt pts - 45
# frame-135: Exported 8/12 | total pts-66, gt pts - 0
# frame-135: Exported 9/12 | total pts-18, gt pts - 0
# frame-135: Exported 10/12 | total pts-24, gt pts - 1
# frame-135: Exported 11/12 | total pts-11, gt pts - 6
# frame-135: Exported 12/12 | total pts-6, gt pts - 0
# frame-136: Exported 1/7 | total pts-2276, gt pts - 1407
# frame-136: Exported 2/7 | total pts-195, gt pts - 108
# frame-136: Exported 3/7 | total pts-333, gt pts - 166
# frame-136: Exported 4/7 | total pts-102, gt pts - 35
# frame-136: Exported 5/7 | total pts-124, gt pts - 70
# frame-136: Exported 6/7 | total pts-38, gt pts - 16
# frame-136: Exported 7/7 | total pts-2, gt pts - 0
# frame-137: Exported 1/4 | total pts-76, gt pts - 25
# frame-137: Exported 2/4 | total pts-42, gt pts - 5
# frame-137: Exported 3/4 | total pts-17, gt pts - 1
# frame-137: Exported 4/4 | total pts-9, gt pts - 5
# frame-138: Exported 1/7 | total pts-645, gt pts - 435
# frame-138: Exported 2/7 | total pts-222, gt pts - 148
# frame-138: Exported 3/7 | total pts-34, gt pts - 21
# frame-138: Exported 4/7 | total pts-81, gt pts - 64
# frame-138: Exported 5/7 | total pts-69, gt pts - 39
# frame-138: Exported 6/7 | total pts-19, gt pts - 13
# frame-138: Exported 7/7 | total pts-13, gt pts - 11
# frame-139: Exported 1/2 | total pts-27, gt pts - 13
# frame-139: Exported 2/2 | total pts-15, gt pts - 0
# frame-140: Exported 1/4 | total pts-869, gt pts - 386
# frame-140: Exported 2/4 | total pts-429, gt pts - 226
# frame-140: Exported 3/4 | total pts-160, gt pts - 84
# frame-140: Exported 4/4 | total pts-105, gt pts - 30
# frame-141: Exported 1/1 | total pts-888, gt pts - 561
# frame-142: Exported 1/10 | total pts-2860, gt pts - 1947
# frame-142: Exported 2/10 | total pts-1431, gt pts - 529
# frame-142: Exported 3/10 | total pts-1277, gt pts - 706
# frame-142: Exported 4/10 | total pts-774, gt pts - 421
# frame-142: Exported 5/10 | total pts-580, gt pts - 169
# frame-142: Exported 6/10 | total pts-503, gt pts - 337
# frame-142: Exported 7/10 | total pts-491, gt pts - 274
# frame-142: Exported 8/10 | total pts-212, gt pts - 145
# frame-142: Exported 9/10 | total pts-51, gt pts - 35
# frame-142: Exported 10/10 | total pts-83, gt pts - 40
# frame-143: Exported 1/6 | total pts-130, gt pts - 11
# frame-143: Exported 2/6 | total pts-41, gt pts - 14
# frame-143: Exported 3/6 | total pts-40, gt pts - 28
# frame-143: Exported 4/6 | total pts-4, gt pts - 0
# frame-143: Exported 5/6 | total pts-2, gt pts - 0
# frame-143: Exported 6/6 | total pts-3, gt pts - 0
# frame-144: Exported 1/3 | total pts-1348, gt pts - 262
# frame-144: Exported 2/3 | total pts-2139, gt pts - 1473
# frame-144: Exported 3/3 | total pts-191, gt pts - 126
# frame-145: Exported 1/4 | total pts-195, gt pts - 109
# frame-145: Exported 2/4 | total pts-167, gt pts - 77
# frame-145: Exported 3/4 | total pts-130, gt pts - 57
# frame-145: Exported 4/4 | total pts-66, gt pts - 21
# frame-146: Exported 1/15 | total pts-2528, gt pts - 1344
# frame-146: Exported 2/15 | total pts-923, gt pts - 317
# frame-146: Exported 3/15 | total pts-2126, gt pts - 1200
# frame-146: Exported 4/15 | total pts-713, gt pts - 549
# frame-146: Exported 5/15 | total pts-390, gt pts - 169
# frame-146: Exported 6/15 | total pts-306, gt pts - 218
# frame-146: Exported 7/15 | total pts-228, gt pts - 161
# frame-146: Exported 8/15 | total pts-357, gt pts - 178
# frame-146: Exported 9/15 | total pts-249, gt pts - 86
# frame-146: Exported 10/15 | total pts-153, gt pts - 107
# frame-146: Exported 11/15 | total pts-231, gt pts - 69
# frame-146: Exported 12/15 | total pts-143, gt pts - 58
# frame-146: Exported 13/15 | total pts-56, gt pts - 12
# frame-146: Exported 14/15 | total pts-143, gt pts - 60
# frame-146: Exported 15/15 | total pts-12, gt pts - 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1814/1528493609.py in <module>
#      17             cropped_pcds.append(cropped)
#      18
# ---> 19         if max(num_pts_in_gt_for_mask) == 0:
#      20             labelled_pts = np.hstack([i_cloud, np.ones((len(i_cloud),0))])
#      21             box_pts = np.zeros((8,3))
#
# ValueError: max() arg is an empty sequence

# %%
export_tag = 'mask'
if export_tag == 'bbox':
    use_bbox = True

sample_idx = 8   
i_clouds = mesher.data_obj.get_mask_instance_clouds(sample_idx, append_labels=False, use_bbox=use_bbox)
pcd_gtboxes = mesher.get_pcd_gtboxes(sample_idx, add_ground_lift=False)

i_cloud = i_clouds[9]
mask_pcd = convert_to_o3dpcd(i_cloud)
cropped_pcds, num_pts_in_gt_for_mask = [], []
for i in range(len(pcd_gtboxes['gt_boxes'])):    
    cropped = mask_pcd.crop(pcd_gtboxes['gt_boxes'][i])
    num_pts_in_gt_for_mask.append(len(cropped.points))
    cropped_pcds.append(cropped)

if max(num_pts_in_gt_for_mask) == 0:
    labelled_pts = np.hstack([i_cloud, np.ones((len(i_cloud),0))])
    box_pts = np.zeros((8,3))
else:
    gtbox_idx = np.argmax(np.array(num_pts_in_gt_for_mask)) 
    cropped_np = np.array(cropped_pcds[gtbox_idx].points)
    obj_pts_labelled = np.hstack([cropped_np, np.ones((len(cropped_np),1))])

    dist = mask_pcd.compute_point_cloud_distance(cropped_pcds[gtbox_idx])
    cropped_inds = np.where(np.asarray(dist) < 0.01)[0]
    mask_without_obj = np.asarray(mask_pcd.select_by_index(cropped_inds, invert=True).points)
    mask_pts_labelled = np.hstack([mask_without_obj, np.zeros((len(mask_without_obj),1))])\

    labelled_pts = np.vstack([mask_pts_labelled, obj_pts_labelled])
    box_pts = np.asarray(pcd_gtboxes['gt_boxes'][gtbox_idx].get_box_points())

    if mesher.data_obj.dataset_name == 'nuscenes':
        fname = f'nsweeps-{mesher.data_obj.nsweeps}_frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'
    else:
        fname = f'frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'

    car_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data/points_in_{export_tag}/cars')
    car_dir.mkdir(parents=True, exist_ok=True)
    o3d.io.write_point_cloud(str(car_dir / f'{fname}.pcd'), object_pcd)

    box_dir = Path(f'{mesher.data_obj.root_dir}/exported/lidar_seg_data/points_in_{export_tag}/gt_bboxes')    
    box_dir.mkdir(parents=True, exist_ok=True)
    np.savetxt(str(box_dir / f'{fname}.txt'), box_pts, delimiter=' ')

    print(f"frame-{sample_idx}: Exported {object_id}/{len(pcd_gtboxes['gt_boxes'])} | car_pts-{len(object_pcd.points)}")
# Out:
# [0, 0, 0, 0, 0, 0]
# [Open3D WARNING] [KDTreeFlann::SetRawData] Failed due to no data.

# %%
msk_no_obj = convert_to_o3dpcd(mask_pts_labelled)
msk_no_obj.paint_uniform_color([0.85,0.85,0.85])
o3d.visualization.draw_geometries([msk_no_obj, convert_to_o3dpcd(obj_pts_labelled)])

# %%
vizpts = i_clouds[2]
vizpcd = convert_to_o3dpcd(vizpts)
vizpcd.colors = o3d.utility.Vector3dVector([[255*vizpts[i,4],0,0] for i in range(len(vizpts))])
o3d.visualization.draw_geometries([vizpcd] + gtboxes['gt_boxes'])

# %%
mesher.min_lidar_pts_to_mesh = 5

for sample_idx in range(mesher.data_obj.__len__()):
    i_clouds = mesher.data_obj.get_mask_instance_clouds(sample_idx, use_bbox=False)

    for i_cloud in i_clouds:    
        
        if len(i_cloud) < mesher.min_lidar_pts_to_mesh:
            continue

        box_pts = np.asarray(pcd_gtboxes['gt_boxes'][object_id].get_box_points())

        if mesher.data_obj.dataset_name == 'nuscenes':
            fname = f'nsweeps-{mesher.data_obj.nsweeps}_frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'
        else:
            fname = f'frame-{sample_idx}_object-{object_id}_car_pts-{len(object_pcd.points)}'

        car_dir = Path(f'{mesher.data_obj.root_dir}/exported/cars')
        car_dir.mkdir(parents=True, exist_ok=True)
        o3d.io.write_point_cloud(str(car_dir / f'{fname}.pcd'), object_pcd)

        box_dir = Path(f'{mesher.data_obj.root_dir}/exported/bboxes')    
        box_dir.mkdir(parents=True, exist_ok=True)
        np.savetxt(str(box_dir / f'{fname}.txt'), box_pts, delimiter=' ')

        print(f"frame-{sample_idx}: Exported {object_id}/{len(pcd_gtboxes['gt_boxes'])} | car_pts-{len(object_pcd.points)}")

# %% [markdown]
# # Export points in bbox

# %%
i_clouds = mesher.data_obj.get_mask_instance_clouds(21, use_bbox=True)
icloud_pcds = convert_to_o3dpcd(i_clouds)
o3d.visualization.draw_geometries(icloud_pcds)

# %%
i_clouds[0]
# Out:
# array([[ 2.50580006e+01,  4.67899990e+00,  4.99999989e-03,
#          2.00000000e+00,  1.00000000e+00],
#        [ 2.48780003e+01,  4.72599983e+00,  6.00000005e-03,
#          2.00000000e+00,  1.00000000e+00],
#        [ 2.48360004e+01,  4.79899979e+00,  7.00000022e-03,
#          2.00000000e+00,  1.00000000e+00],
#        ...,
#        [ 1.20419998e+01,  3.10599995e+00, -1.47800004e+00,
#          2.00000000e+00,  1.00000000e+00],
#        [ 1.20150003e+01,  3.13899994e+00, -1.47599995e+00,
#          2.00000000e+00,  1.00000000e+00],
#        [ 1.20439997e+01,  3.18700004e+00, -1.48099995e+00,
#          2.00000000e+00,  1.00000000e+00]])
